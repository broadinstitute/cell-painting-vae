# %%
import pandas as pd
import numpy as np
import os
from pycytominer.cyto_utils import infer_cp_features
import sys
import matplotlib.pyplot as plt
sys.path.insert(0, "../scripts")
from utils import load_data

# %%
data_dict = load_data(["complete"])
meta_features = infer_cp_features(data_dict["complete"], metadata=True)
cp_features = infer_cp_features(data_dict["complete"])

complete_features_df = data_dict["complete"].reindex(cp_features, axis="columns")
complete_meta_df = data_dict["complete"].reindex(meta_features, axis="columns")

# %%
#obtain only the moa column from the whole dataframe
df = pd.read_csv("repurposing_info_external_moa_map_resolved.tsv",sep='\t').set_index('broad_sample').reindex(index=complete_meta_df['Metadata_broad_sample']).reset_index().drop('Metadata_broad_sample',axis = 1)
moa = df.moa.dropna()
moa
# Out:
# 0        glucocorticoid receptor antagonist
# 1        glucocorticoid receptor antagonist
# 2        glucocorticoid receptor antagonist
# 3        glucocorticoid receptor antagonist
# 4        glucocorticoid receptor antagonist
#                         ...
# 10339      progesterone receptor antagonist
# 10340      progesterone receptor antagonist
# 10341      progesterone receptor antagonist
# 10342      progesterone receptor antagonist
# 10343      progesterone receptor antagonist
# Name: moa, Length: 9408, dtype: object

# %%
pipes = moa[moa.str.contains("\|")]
unique_pipes = pipes.drop_duplicates()
no_pipes = moa[~moa.str.contains("\|")]

# %%
#count the number of occurrences of each moa in each moa combination
moas_occurences_all_pipes = []
for pipe in unique_pipes:
    moas = pipe.split("|")
    moas_occurences = [pipes[pipes == pipe].count()]
    for moa in moas:
        moas_occurences.append(no_pipes[no_pipes == moa].count())
    moas_occurences_all_pipes.append(moas_occurences)
moas_occurrences_all_pipes_df = pd.DataFrame(data=moas_occurences_all_pipes, index = unique_pipes.index.values.tolist(), columns=["full moa occurrence","moa1 occurrence", "moa2 occurrence","moa3 occurrence", "moa4 occurrence", "moa5 occurrence", "moa6 occurrence"])
moas_occurrences_all_pipes_df
# Out:
#        full moa occurrence  moa1 occurrence  moa2 occurrence  moa3 occurrence  \
# 36                       6                6                0             42.0
# 48                      30               48               48              NaN
# 144                      6               18                6              NaN
# 156                     66              120               84              NaN
# 180                      6                6                6              NaN
# ...                    ...              ...              ...              ...
# 10104                   12                6                6              NaN
# 10134                    6               24                6             30.0
# 10164                    6               84               84              NaN
# 10224                    6               12                0              NaN
# 10332                    6              162                0              NaN
#
#        moa4 occurrence  moa5 occurrence  moa6 occurrence
# 36                 NaN              NaN              NaN
# 48                 NaN              NaN              NaN
# 144                NaN              NaN              NaN
# 156                NaN              NaN              NaN
# 180                NaN              NaN              NaN
# ...                ...              ...              ...
# 10104              NaN              NaN              NaN
# 10134              NaN              NaN              NaN
# 10164              NaN              NaN              NaN
# 10224              NaN              NaN              NaN
# 10332              NaN              NaN              NaN
#
# [170 rows x 7 columns]

# %%
moas_occurrence_df = pd.concat([unique_pipes, moas_occurrences_all_pipes_df],axis = 1)
moas_occurrence_df = moas_occurrence_df.sort_values("full moa occurrence", ascending = False)
moas_occurrence_df.index = moas_occurrence_df['moa']
moas_occurrence_df = moas_occurrence_df.drop('moa',axis =1)
moas_occurrence_df.to_csv("moas_occurrence.tsv", sep = "\t")
moas_occurrence_df.head(10)
# Out:
#                                                     full moa occurrence  \
# moa
# NFkB pathway inhibitor|proteasome inhibitor                         330
# dopamine receptor antagonist|serotonin receptor...                   66
# cyclooxygenase inhibitor|prostanoid receptor an...                   30
# mTOR inhibitor|PI3K inhibitor                                        30
# insulin sensitizer|PPAR receptor agonist                             24
# ...                                                                 ...
# acetylcholinesterase inhibitor|monoamine oxidas...                    6
# angiogenesis inhibitor|S100A9 inhibitor                               6
# cyclooxygenase inhibitor|NFkB pathway inhibitor                       6
# insulin sensitizer|PPAR receptor partial agonist                      6
# adrenergic receptor antagonist|prolactin inhibitor                    6
#
#                                                     moa1 occurrence  \
# moa
# NFkB pathway inhibitor|proteasome inhibitor                      30
# dopamine receptor antagonist|serotonin receptor...              120
# cyclooxygenase inhibitor|prostanoid receptor an...              168
# mTOR inhibitor|PI3K inhibitor                                    48
# insulin sensitizer|PPAR receptor agonist                         18
# ...                                                             ...
# acetylcholinesterase inhibitor|monoamine oxidas...               18
# angiogenesis inhibitor|S100A9 inhibitor                          24
# cyclooxygenase inhibitor|NFkB pathway inhibitor                 168
# insulin sensitizer|PPAR receptor partial agonist                 18
# adrenergic receptor antagonist|prolactin inhibitor              162
#
#                                                     moa2 occurrence  \
# moa
# NFkB pathway inhibitor|proteasome inhibitor                     354
# dopamine receptor antagonist|serotonin receptor...               84
# cyclooxygenase inhibitor|prostanoid receptor an...               24
# mTOR inhibitor|PI3K inhibitor                                    48
# insulin sensitizer|PPAR receptor agonist                         30
# ...                                                             ...
# acetylcholinesterase inhibitor|monoamine oxidas...               30
# angiogenesis inhibitor|S100A9 inhibitor                           0
# cyclooxygenase inhibitor|NFkB pathway inhibitor                  30
# insulin sensitizer|PPAR receptor partial agonist                  0
# adrenergic receptor antagonist|prolactin inhibitor                0
#
#                                                     moa3 occurrence  \
# moa
# NFkB pathway inhibitor|proteasome inhibitor                     NaN
# dopamine receptor antagonist|serotonin receptor...              NaN
# cyclooxygenase inhibitor|prostanoid receptor an...              NaN
# mTOR inhibitor|PI3K inhibitor                                   NaN
# insulin sensitizer|PPAR receptor agonist                        NaN
# ...                                                             ...
# acetylcholinesterase inhibitor|monoamine oxidas...              NaN
# angiogenesis inhibitor|S100A9 inhibitor                         NaN
# cyclooxygenase inhibitor|NFkB pathway inhibitor                 NaN
# insulin sensitizer|PPAR receptor partial agonist                NaN
# adrenergic receptor antagonist|prolactin inhibitor              NaN
#
#                                                     moa4 occurrence  \
# moa
# NFkB pathway inhibitor|proteasome inhibitor                     NaN
# dopamine receptor antagonist|serotonin receptor...              NaN
# cyclooxygenase inhibitor|prostanoid receptor an...              NaN
# mTOR inhibitor|PI3K inhibitor                                   NaN
# insulin sensitizer|PPAR receptor agonist                        NaN
# ...                                                             ...
# acetylcholinesterase inhibitor|monoamine oxidas...              NaN
# angiogenesis inhibitor|S100A9 inhibitor                         NaN
# cyclooxygenase inhibitor|NFkB pathway inhibitor                 NaN
# insulin sensitizer|PPAR receptor partial agonist                NaN
# adrenergic receptor antagonist|prolactin inhibitor              NaN
#
#                                                     moa5 occurrence  \
# moa
# NFkB pathway inhibitor|proteasome inhibitor                     NaN
# dopamine receptor antagonist|serotonin receptor...              NaN
# cyclooxygenase inhibitor|prostanoid receptor an...              NaN
# mTOR inhibitor|PI3K inhibitor                                   NaN
# insulin sensitizer|PPAR receptor agonist                        NaN
# ...                                                             ...
# acetylcholinesterase inhibitor|monoamine oxidas...              NaN
# angiogenesis inhibitor|S100A9 inhibitor                         NaN
# cyclooxygenase inhibitor|NFkB pathway inhibitor                 NaN
# insulin sensitizer|PPAR receptor partial agonist                NaN
# adrenergic receptor antagonist|prolactin inhibitor              NaN
#
#                                                     moa6 occurrence
# moa
# NFkB pathway inhibitor|proteasome inhibitor                     NaN
# dopamine receptor antagonist|serotonin receptor...              NaN
# cyclooxygenase inhibitor|prostanoid receptor an...              NaN
# mTOR inhibitor|PI3K inhibitor                                   NaN
# insulin sensitizer|PPAR receptor agonist                        NaN
# ...                                                             ...
# acetylcholinesterase inhibitor|monoamine oxidas...              NaN
# angiogenesis inhibitor|S100A9 inhibitor                         NaN
# cyclooxygenase inhibitor|NFkB pathway inhibitor                 NaN
# insulin sensitizer|PPAR receptor partial agonist                NaN
# adrenergic receptor antagonist|prolactin inhibitor              NaN
#
# [170 rows x 7 columns]
