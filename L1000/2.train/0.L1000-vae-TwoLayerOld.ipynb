# %% [markdown]
# # Train a VAE on L1000 Data

# %%
import sys
import pathlib
import numpy as np
import pandas as pd
sys.path.insert(0, "../../scripts")
from utils import load_data, infer_L1000_features
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from sklearn.decomposition import PCA

from tensorflow import keras


from vae import VAE
from tensorflow.keras.models import Model, Sequential
import seaborn
import tensorflow as tf

# %%
# np.random.seed(123)
# python_random.seed(123)
# tf.random.set_random_seed(1234)

# %%
data_splits = ["train", "valid", "test", "complete"]
# data_splits = ["train", "valid","test"]
data_dict = load_data(data_splits, dataset="L1000")
# data_dict["train"] = data_dict["train"][data_dict["train"].cell_id == "A549"].reset_index(drop = True)
# data_dict["valid"] = data_dict["valid"][data_dict["valid"].cell_id == "A549"].reset_index(drop = True)
# data_dict["test"] = data_dict["test"][data_dict["test"].cell_id == "A549"].reset_index(drop = True)
# data_dict["complete"] = data_dict["complete"][data_dict["complete"].cell_id == "A549"].reset_index(drop = True)

# %%
# Prepare data for training

meta_features = infer_L1000_features(data_dict["train"], metadata=True)
profile_features = infer_L1000_features(data_dict["train"])

train_features_df = data_dict["train"].reindex(profile_features, axis="columns")
train_meta_df = data_dict["train"].reindex(meta_features, axis="columns")

valid_features_df = data_dict["valid"].reindex(profile_features, axis="columns")
valid_meta_df = data_dict["valid"].reindex(meta_features, axis="columns")

test_features_df = data_dict["test"].reindex(profile_features, axis="columns")
test_meta_df = data_dict["test"].reindex(meta_features, axis="columns")

complete_features_df = data_dict["complete"].reindex(profile_features, axis="columns")
complete_meta_df = data_dict["complete"].reindex(meta_features, axis="columns")

# %%
#shuffle columns
def shuffle_each_column(df):
    columns = df.columns
    df_copy = df.copy()
    for column in columns:
        df_copy[column] = df_copy[column].sample(frac=1).reset_index(drop=True)
    return (df_copy)

# %%
# train_features_df = shuffle_each_column(train_features_df)
# valid_features_df = shuffle_each_column(valid_features_df)
# test_features_df = shuffle_each_column(test_features_df)

# %%
print(train_features_df.shape)
train_features_df.head(3)
# Out:
# (94440, 978)
#        780      7849      6193        23     9552      387    10921     10285  \
# 0  0.74578 -0.007757 -0.063908 -0.115210  0.83776 -0.80023 -0.25787 -0.621180
# 1 -0.29710 -0.180930  0.482090 -0.337130 -0.47045 -0.44483  0.38475 -0.566390
# 2 -0.75812 -0.283820  0.594330  0.089136 -0.85230 -0.78754  0.20291  0.018564
#
#        533      6194  ...     54681    11000     6915      6253      7264  \
# 0 -0.53313 -0.260430  ... -0.458550  0.51684  2.86550 -0.152210 -0.907810
# 1  0.27726  0.000645  ...  0.008161 -0.33238 -0.20174 -0.605390  0.024792
# 2 -0.22745 -0.839810  ...  0.289560  0.16598  0.54440 -0.053607  0.439350
#
#       5467     2767    23038    57048    79716
# 0  1.47600 -0.42918 -0.81612  0.28533  0.37183
# 1  0.60759  0.41555  0.50640  0.23908 -0.23696
# 2  0.42920 -0.37040 -0.51931 -0.21799 -1.29360
#
# [3 rows x 978 columns]

# %%
print(valid_features_df.shape)
valid_features_df.head(3)
# Out:
# (11805, 978)
#         780      7849      6193       23    9552      387    10921    10285  \
# 0 -0.534400  0.552700  0.000000 -0.95760 -0.3264 -0.25560  0.00000  0.00000
# 1 -0.029159  0.039928  0.045024  0.26740 -1.0234  0.58926  0.57561  0.60793
# 2  0.365290 -1.311300 -0.153500  0.72378 -1.1094 -0.38681  1.05910  0.12169
#
#        533     6194  ...    54681    11000      6915      6253     7264  \
# 0  1.88250  1.86290  ...  5.22050 -0.96970 -1.133800 -1.079700 -2.29810
# 1  0.33281 -0.65153  ... -0.25789  0.46169  0.022211 -0.035998  0.67575
# 2 -1.01300  0.83094  ... -0.22982 -0.21314 -0.088198  0.527700  0.49855
#
#      5467     2767    23038    57048    79716
# 0  0.8493  0.29560  0.84640  0.19020 -0.47540
# 1  2.2909  0.24359 -0.14676 -0.84884 -0.16919
# 2 -1.3877  1.00980 -0.21835  0.16329 -0.79029
#
# [3 rows x 978 columns]

# %%
print(test_features_df.shape)
test_features_df.head(3)
# Out:
# (11805, 978)
#        780    7849     6193       23     9552      387    10921    10285  \
# 0  0.28158  1.6038 -1.58650 -0.41677 -2.34260  3.12320 -0.10233  1.62600
# 1  0.77369  1.0853  0.75758  1.04900  1.18270  0.69324 -0.43503 -0.88949
# 2  0.63079  1.9072 -1.65190  0.26266  0.68423 -0.38400  1.63160  0.78741
#
#         533      6194  ...    54681    11000     6915     6253      7264  \
# 0  0.115840 -0.000233  ... -0.49069 -1.14930 -0.16539  0.49864  1.077800
# 1 -0.075833  0.208990  ...  0.10747  0.97814  0.85407  0.10528 -0.370430
# 2  0.732920 -2.431700  ... -1.83770 -0.56064  0.93692  0.96585 -0.036786
#
#       5467     2767    23038    57048    79716
# 0  1.66230 -1.66900 -0.49738  0.51629  1.08940
# 1  0.89069 -0.26969 -0.98646 -1.07350  0.48240
# 2  1.35430  2.15870 -0.28158  0.53111 -0.46053
#
# [3 rows x 978 columns]

# %%
print(complete_features_df.shape)
complete_features_df.head(3)
# Out:
# (118050, 978)
#        780      7849     6193       23     9552      387     10921    10285  \
# 0  4.26410  0.057249 -2.13930 -0.22178 -0.37656  1.91380  0.065576 -0.86895
# 1 -0.38221  0.304310 -0.99592 -0.67083 -0.64824  0.62161  0.889530  0.20376
# 2 -0.57171 -0.755000 -0.71011  0.42889  0.27261  0.31436 -1.545800  0.64195
#
#        533     6194  ...     54681     11000     6915      6253      7264  \
# 0 -0.10227  0.00000  ...  5.246200  0.057058 -1.25620 -0.025255  0.168860
# 1  0.19481 -0.45637  ...  0.206690 -0.010866 -0.87206 -0.223750  0.074144
# 2 -0.87685  0.00000  ... -0.005612  1.194500  0.17111  0.334370 -1.089300
#
#        5467     2767    23038    57048    79716
# 0 -1.639100  0.68510 -0.41942  1.71610 -0.47234
# 1  0.093595  0.32667  1.04810 -0.50518 -0.61832
# 2 -0.114640  0.30483 -0.24947 -0.42835  1.58500
#
# [3 rows x 978 columns]

# %%
# VAE of one layer
# 100
# encoder_architecture = [1000,1000]
# decoder_architecture = [1000,1000]
# encoder_architecture = [250,100]
# decoder_architecture = [100,250]
# encoder_architecture = [500,250,100]
# decoder_architecture = [100,250,500]
encoder_architecture = [500]
decoder_architecture = [500]

# %%
# model from optimal hyperparameters for onelayer obtained from 1.optimize
# L1000_vae = VAE(
#     input_dim=train_features_df.shape[1],
#     latent_dim=115,
#     batch_size=640,
#     encoder_batch_norm=False,
#     epochs=100,
#     learning_rate=0.001,
#     encoder_architecture=encoder_architecture,
#     decoder_architecture=decoder_architecture,
#     beta=1,
#     verbose=True,
# )
# L1000_vae = VAE(
#     input_dim=train_features_df.shape[1],
#     latent_dim=100,
#     batch_size=320,
#     encoder_batch_norm=True,
#     epochs= 30,
#     learning_rate=0.001,
#     encoder_architecture=encoder_architecture,
#     decoder_architecture=decoder_architecture,
#     beta=5,
#     verbose=True,
# )

# # what ive been using as control 
L1000_vae = VAE(
    input_dim=train_features_df.shape[1],
    latent_dim=75,
    batch_size=576,
    encoder_batch_norm=True,
    epochs= 100,
    learning_rate=0.001,
    encoder_architecture=encoder_architecture,
    decoder_architecture=decoder_architecture,
    beta=50,
    verbose=True,
)


# L1000_vae = VAE(
#     input_dim=train_features_df.shape[1],
#     latent_dim=40,
#     batch_size=256,
#     encoder_batch_norm=True,
#     epochs= 10,
#     learning_rate=0.0001,
#     encoder_architecture=encoder_architecture,
#     decoder_architecture=decoder_architecture,
#     beta=70,
#     verbose=True,
# )
# -batch_size: 256
#  |-encoder_batch_norm: True
#  |-epochs: 10
#  |-latent_dim: 40
#  |-learning_rate: 0.0001

# what gives an error
# |-batch_size: 512
# |-encoder_batch_norm: False
# |-epochs: 50
# |-latent_dim: 90
# |-learning_rate: 0.01
#FROM THE PAPER
# L1000_vae = VAE(
#     input_dim=train_features_df.shape[1],
#     latent_dim=100,
#     batch_size=512,
#     encoder_batch_norm=False,
#     epochs=20,
#     learning_rate=0.001,
#     encoder_architecture=encoder_architecture,
#     decoder_architecture=decoder_architecture,
#     beta=1,
#     verbose=True,
# )

# L1000_vae = VAE(
#     input_dim=train_features_df.shape[1],
#     latent_dim=20,
#     batch_size=64,
#     encoder_batch_norm=False,
#     epochs=20,
#     learning_rate=0.001,
#     encoder_architecture=encoder_architecture,
#     decoder_architecture=decoder_architecture,
#     beta=1,
#     verbose=True,
# )
L1000_vae.compile_vae()
#1495

# %%
L1000_vae.train(x_train=train_features_df, x_test=valid_features_df)
# Out:
# Epoch 1/100
# 164/164 [==============================] - 7s 31ms/step - loss: 2573.4400 - val_loss: 1928.6268
# Epoch 2/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1825.2718 - val_loss: 1766.3303
# Epoch 3/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1733.8371 - val_loss: 1701.6224
# Epoch 4/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1694.2372 - val_loss: 1669.8906
# Epoch 5/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1661.8315 - val_loss: 1641.8075
# Epoch 6/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1629.7549 - val_loss: 1624.8353
# Epoch 7/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1611.6602 - val_loss: 1597.4576
# Epoch 8/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1604.6835 - val_loss: 1587.7302
# Epoch 9/100
# 164/164 [==============================] - 4s 27ms/step - loss: 1583.3730 - val_loss: 1581.0104
# Epoch 10/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1574.8551 - val_loss: 1572.9436
# Epoch 11/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1572.5273 - val_loss: 1564.6722
# Epoch 12/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1555.9883 - val_loss: 1561.0393
# Epoch 13/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1555.4299 - val_loss: 1553.8822
# Epoch 14/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1543.0775 - val_loss: 1545.2648
# Epoch 15/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1543.7058 - val_loss: 1545.0105
# Epoch 16/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1540.0740 - val_loss: 1539.6808
# Epoch 17/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1533.5029 - val_loss: 1535.0404
# Epoch 18/100
# 164/164 [==============================] - 4s 25ms/step - loss: 1528.7769 - val_loss: 1532.9657
# Epoch 19/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1528.8155 - val_loss: 1529.4919
# Epoch 20/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1524.5115 - val_loss: 1526.1846
# Epoch 21/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1523.7824 - val_loss: 1518.7115
# Epoch 22/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1523.0257 - val_loss: 1516.5933
# Epoch 23/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1517.7965 - val_loss: 1512.3811
# Epoch 24/100
# 164/164 [==============================] - 4s 25ms/step - loss: 1512.1527 - val_loss: 1509.9851
# Epoch 25/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1502.0758 - val_loss: 1508.2107
# Epoch 26/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1503.5885 - val_loss: 1505.5043
# Epoch 27/100
# 164/164 [==============================] - 4s 25ms/step - loss: 1495.1950 - val_loss: 1499.4752
# Epoch 28/100
# 164/164 [==============================] - 4s 25ms/step - loss: 1493.5749 - val_loss: 1497.8967
# Epoch 29/100
# 164/164 [==============================] - 4s 25ms/step - loss: 1487.9607 - val_loss: 1494.7400
# Epoch 30/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1496.4412 - val_loss: 1491.6644
# Epoch 31/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1494.2829 - val_loss: 1487.5090
# Epoch 32/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1485.5599 - val_loss: 1487.8334
# Epoch 33/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1479.6883 - val_loss: 1478.5631
# Epoch 34/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1475.2124 - val_loss: 1485.0564
# Epoch 35/100
# 164/164 [==============================] - 4s 25ms/step - loss: 1476.0751 - val_loss: 1473.6682
# Epoch 36/100
# 164/164 [==============================] - 4s 25ms/step - loss: 1468.7744 - val_loss: 1470.0247
# Epoch 37/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1465.7658 - val_loss: 1463.7181
# Epoch 38/100
# 164/164 [==============================] - 4s 25ms/step - loss: 1472.1666 - val_loss: 1461.2815
# Epoch 39/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1457.8362 - val_loss: 1458.6221
# Epoch 40/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1459.7661 - val_loss: 1454.5159
# Epoch 41/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1457.7881 - val_loss: 1454.9100
# Epoch 42/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1451.1985 - val_loss: 1448.4261
# Epoch 43/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1449.0378 - val_loss: 1457.3795
# Epoch 44/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1454.8674 - val_loss: 1446.5461
# Epoch 45/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1448.2455 - val_loss: 1446.1719
# Epoch 46/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1435.0066 - val_loss: 1443.5374
# Epoch 47/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1440.6320 - val_loss: 1442.0253
# Epoch 48/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1430.1279 - val_loss: 1443.3323
# Epoch 49/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1436.2269 - val_loss: 1439.8207
# Epoch 50/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1436.6248 - val_loss: 1436.5179
# Epoch 51/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1437.6696 - val_loss: 1433.8672
# Epoch 52/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1424.1561 - val_loss: 1431.3733
# Epoch 53/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1433.0512 - val_loss: 1431.4166
# Epoch 54/100
# 164/164 [==============================] - 4s 25ms/step - loss: 1428.9270 - val_loss: 1429.0090
# Epoch 55/100
# 164/164 [==============================] - 4s 25ms/step - loss: 1419.4049 - val_loss: 1429.7294
# Epoch 56/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1427.1434 - val_loss: 1426.9088
# Epoch 57/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1424.0313 - val_loss: 1426.4255
# Epoch 58/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1424.1404 - val_loss: 1423.8907
# Epoch 59/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1421.6732 - val_loss: 1423.3392
# Epoch 60/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1422.0205 - val_loss: 1422.6674
# Epoch 61/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1431.6034 - val_loss: 1423.1583
# Epoch 62/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1422.6838 - val_loss: 1423.4628
# Epoch 63/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1415.8966 - val_loss: 1419.1311
# Epoch 64/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1415.5387 - val_loss: 1421.8949
# Epoch 65/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1418.8483 - val_loss: 1418.2783
# Epoch 66/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1421.5825 - val_loss: 1418.0142
# Epoch 67/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1416.5333 - val_loss: 1418.5244
# Epoch 68/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1414.7657 - val_loss: 1414.0331
# Epoch 69/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1422.4273 - val_loss: 1414.1439
# Epoch 70/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1414.4194 - val_loss: 1416.1057
# Epoch 71/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1413.8696 - val_loss: 1414.2701
# Epoch 72/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1415.2549 - val_loss: 1417.4312
# Epoch 73/100
# 164/164 [==============================] - 4s 27ms/step - loss: 1412.5340 - val_loss: 1420.3915
# Epoch 74/100
# 164/164 [==============================] - 4s 27ms/step - loss: 1413.6350 - val_loss: 1415.2866
# Epoch 75/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1406.9125 - val_loss: 1413.8604
# Epoch 76/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1408.9871 - val_loss: 1415.9797
# Epoch 77/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1415.9269 - val_loss: 1412.3450
# Epoch 78/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1401.1775 - val_loss: 1412.1792
# Epoch 79/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1406.4738 - val_loss: 1414.7078
# Epoch 80/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1407.6583 - val_loss: 1410.9226
# Epoch 81/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1399.7026 - val_loss: 1409.1808
# Epoch 82/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1407.2559 - val_loss: 1410.4089
# Epoch 83/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1401.3842 - val_loss: 1407.8323
# Epoch 84/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1402.7606 - val_loss: 1408.7635
# Epoch 85/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1411.1598 - val_loss: 1407.2830
# Epoch 86/100
# 164/164 [==============================] - 4s 27ms/step - loss: 1396.4844 - val_loss: 1410.3467
# Epoch 87/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1398.8523 - val_loss: 1406.9946
# Epoch 88/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1404.1736 - val_loss: 1403.6138
# Epoch 89/100
# 164/164 [==============================] - 4s 27ms/step - loss: 1404.4914 - val_loss: 1406.4884
# Epoch 90/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1399.6171 - val_loss: 1405.8213
# Epoch 91/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1399.7662 - val_loss: 1405.6074
# Epoch 92/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1402.0444 - val_loss: 1405.6443
# Epoch 93/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1401.9276 - val_loss: 1404.1572
# Epoch 94/100
# 164/164 [==============================] - 4s 25ms/step - loss: 1391.8340 - val_loss: 1403.2446
# Epoch 95/100
# 164/164 [==============================] - 4s 27ms/step - loss: 1398.8769 - val_loss: 1402.8287
# Epoch 96/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1398.1597 - val_loss: 1404.4017
# Epoch 97/100
# 164/164 [==============================] - 4s 27ms/step - loss: 1398.6367 - val_loss: 1405.9032
# Epoch 98/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1394.7468 - val_loss: 1399.7260
# Epoch 99/100
# 164/164 [==============================] - 4s 26ms/step - loss: 1393.6094 - val_loss: 1400.9835
# Epoch 100/100
# 164/164 [==============================] - 4s 27ms/step - loss: 1393.4632 - val_loss: 1404.1768

# %%
L1000_vae.vae

# %%
# Save training performance
history_df = pd.DataFrame(L1000_vae.vae.history.history)
history_df
#1067 for level 1
# Out:
#            loss     val_loss
# 0   2134.395996  1928.626831
# 1   1801.213989  1766.330322
# 2   1723.035767  1701.622437
# 3   1681.637207  1669.890625
# 4   1651.199463  1641.807495
# ..          ...          ...
# 95  1398.751465  1404.401733
# 96  1398.821289  1405.903198
# 97  1396.892212  1399.725952
# 98  1397.356201  1400.983521
# 99  1396.353149  1404.176758
#
# [100 rows x 2 columns]

# %%
history_df.to_csv('twolayer_training.csv')

# %%
plt.figure(figsize=(10, 5))
plt.plot(history_df["loss"], label="Training data")
plt.plot(history_df["val_loss"], label="Validation data")
plt.title("Loss for VAE training on L1000 data")
# plt.ylabel("Binary cross entropy + KL Divergence")
plt.ylabel("Loss")
plt.xlabel("No. Epoch")
plt.legend()
plt.show()

# %%
# evaluating performance using test set
L1000_vae.vae.evaluate(test_features_df)
# Out:
# 369/369 [==============================] - 1s 2ms/step - loss: 1390.8757
# 1390.875732421875

# %%
reconstruction = pd.DataFrame(
    L1000_vae.vae.predict(test_features_df), columns=profile_features
)
(sum(sum((np.array(test_features_df) - np.array(reconstruction)) ** 2))) ** 0.5
# Out:
# 3837.2681777562284

# %%
# latent space heatmap
fig, ax = plt.subplots(figsize=(10, 10))
encoder = L1000_vae.encoder_block["encoder"]
latent = np.array(encoder.predict(test_features_df)[2])
seaborn.heatmap(latent, ax=ax)
# Out:
# <AxesSubplot:>

# %%
# original vs reconstructed heatmap

#use these 3 lines if you need to regenerate it
encoder = keras.models.load_model("L1000twolayerEncoder")
decoder = keras.models.load_model("L1000twolayerDecoder")
reconstruction = pd.DataFrame(decoder.predict(encoder.predict(test_features_df)[2]), columns=profile_features)


# reconstruction = pd.DataFrame(
#     L1000_vae.vae.predict(test_features_df), columns=profile_features
# )

pca = PCA(n_components=2).fit(test_features_df)
pca_reconstructed_latent_df = pd.DataFrame(pca.transform(reconstruction))
pca_test_latent_df = pd.DataFrame(pca.transform(test_features_df))
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))
# seaborn.heatmap(test_features_df, ax=ax1)
# seaborn.heatmap(reconstruction, ax=ax2)
# plt.show()
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
figure(figsize=(10, 10), dpi=80)
plt.scatter(pca_test_latent_df[0],pca_test_latent_df[1], marker = ".", alpha = 0.5)
plt.scatter(pca_reconstructed_latent_df[0],pca_reconstructed_latent_df[1], marker = ".", alpha = 0.5)

# %%
decoder = L1000_vae.decoder_block["decoder"]

# %%
simulated_df = pd.DataFrame(np.random.normal(size=(10000, 75)), columns=np.arange(0,75))
reconstruction_of_simulated = decoder.predict(simulated_df)
pca_reconstruction_of_simulated = pd.DataFrame(pca.transform(reconstruction_of_simulated))
fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(16,8), sharey = True, sharex = True)
ax1.scatter(pca_test_latent_df[0],pca_test_latent_df[1], marker = ".", alpha = 0.5)
ax2.scatter(pca_reconstruction_of_simulated[0],pca_reconstruction_of_simulated[1], marker = ".", alpha = 0.5)

# %%
#NOTE: IF YOU RUN THIS, YOU WILL NOT BE ABLE TO REPRODUCE THE EXACT RESULTS IN THE EXPERIMENT
latent_complete = np.array(encoder.predict(complete_features_df)[2])
latent_df = pd.DataFrame(latent_complete)
latent_df.to_csv("../3.application/latentTwoLayer.csv")

# %%
#NOTE: IF YOU RUN THIS, YOU WILL NOT BE ABLE TO REPRODUCE THE EXACT RESULTS IN THE EXPERIMENT
decoder.save('./L1000twolayerDecoder')
# Out:
# INFO:tensorflow:Assets written to: ./L1000twolayerDecoder/assets

# %%
#NOTE: IF YOU RUN THIS, YOU WILL NOT BE ABLE TO REPRODUCE THE EXACT RESULTS IN THE EXPERIMENT
encoder.save('./L1000twolayerEncoder')
# Out:
# INFO:tensorflow:Assets written to: ./L1000twolayerEncoder/assets
