# %% [markdown]
# # Train a VAE on L1000 Data

# %%
import sys
import pathlib
import numpy as np
import pandas as pd
sys.path.insert(0, "../../scripts")
from utils import load_data, infer_L1000_features
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from sklearn.decomposition import PCA

from tensorflow import keras


from vae import VAE
from tensorflow.keras.models import Model, Sequential
import seaborn
import tensorflow as tf

# %%
# np.random.seed(123)
# python_random.seed(123)
# tf.random.set_random_seed(1234)

# %%
data_splits = ["train", "valid", "test", "complete"]
# data_splits = ["train", "valid","test"]
data_dict = load_data(data_splits, dataset="L1000")
# data_dict["train"] = data_dict["train"][data_dict["train"].cell_id == "A549"].reset_index(drop = True)
# data_dict["valid"] = data_dict["valid"][data_dict["valid"].cell_id == "A549"].reset_index(drop = True)
# data_dict["test"] = data_dict["test"][data_dict["test"].cell_id == "A549"].reset_index(drop = True)
# data_dict["complete"] = data_dict["complete"][data_dict["complete"].cell_id == "A549"].reset_index(drop = True)

# %%
# Prepare data for training

meta_features = infer_L1000_features(data_dict["train"], metadata=True)
profile_features = infer_L1000_features(data_dict["train"])

train_features_df = data_dict["train"].reindex(profile_features, axis="columns")
train_meta_df = data_dict["train"].reindex(meta_features, axis="columns")

valid_features_df = data_dict["valid"].reindex(profile_features, axis="columns")
valid_meta_df = data_dict["valid"].reindex(meta_features, axis="columns")

test_features_df = data_dict["test"].reindex(profile_features, axis="columns")
test_meta_df = data_dict["test"].reindex(meta_features, axis="columns")

complete_features_df = data_dict["complete"].reindex(profile_features, axis="columns")
complete_meta_df = data_dict["complete"].reindex(meta_features, axis="columns")

# %%
#shuffle columns
def shuffle_each_column(df):
    columns = df.columns
    df_copy = df.copy()
    for column in columns:
        df_copy[column] = df_copy[column].sample(frac=1).reset_index(drop=True)
    return (df_copy)

# %%
# train_features_df = shuffle_each_column(train_features_df)
# valid_features_df = shuffle_each_column(valid_features_df)
# test_features_df = shuffle_each_column(test_features_df)

# %%
print(train_features_df.shape)
train_features_df.head(3)
# Out:
# (94440, 978)
#        780      7849      6193        23     9552      387    10921     10285  \
# 0  0.74578 -0.007757 -0.063908 -0.115210  0.83776 -0.80023 -0.25787 -0.621180
# 1 -0.29710 -0.180930  0.482090 -0.337130 -0.47045 -0.44483  0.38475 -0.566390
# 2 -0.75812 -0.283820  0.594330  0.089136 -0.85230 -0.78754  0.20291  0.018564
#
#        533      6194  ...     54681    11000     6915      6253      7264  \
# 0 -0.53313 -0.260430  ... -0.458550  0.51684  2.86550 -0.152210 -0.907810
# 1  0.27726  0.000645  ...  0.008161 -0.33238 -0.20174 -0.605390  0.024792
# 2 -0.22745 -0.839810  ...  0.289560  0.16598  0.54440 -0.053607  0.439350
#
#       5467     2767    23038    57048    79716
# 0  1.47600 -0.42918 -0.81612  0.28533  0.37183
# 1  0.60759  0.41555  0.50640  0.23908 -0.23696
# 2  0.42920 -0.37040 -0.51931 -0.21799 -1.29360
#
# [3 rows x 978 columns]

# %%
print(valid_features_df.shape)
valid_features_df.head(3)
# Out:
# (11805, 978)
#         780      7849      6193       23    9552      387    10921    10285  \
# 0 -0.534400  0.552700  0.000000 -0.95760 -0.3264 -0.25560  0.00000  0.00000
# 1 -0.029159  0.039928  0.045024  0.26740 -1.0234  0.58926  0.57561  0.60793
# 2  0.365290 -1.311300 -0.153500  0.72378 -1.1094 -0.38681  1.05910  0.12169
#
#        533     6194  ...    54681    11000      6915      6253     7264  \
# 0  1.88250  1.86290  ...  5.22050 -0.96970 -1.133800 -1.079700 -2.29810
# 1  0.33281 -0.65153  ... -0.25789  0.46169  0.022211 -0.035998  0.67575
# 2 -1.01300  0.83094  ... -0.22982 -0.21314 -0.088198  0.527700  0.49855
#
#      5467     2767    23038    57048    79716
# 0  0.8493  0.29560  0.84640  0.19020 -0.47540
# 1  2.2909  0.24359 -0.14676 -0.84884 -0.16919
# 2 -1.3877  1.00980 -0.21835  0.16329 -0.79029
#
# [3 rows x 978 columns]

# %%
print(test_features_df.shape)
test_features_df.head(3)
# Out:
# (11805, 978)
#        780    7849     6193       23     9552      387    10921    10285  \
# 0  0.28158  1.6038 -1.58650 -0.41677 -2.34260  3.12320 -0.10233  1.62600
# 1  0.77369  1.0853  0.75758  1.04900  1.18270  0.69324 -0.43503 -0.88949
# 2  0.63079  1.9072 -1.65190  0.26266  0.68423 -0.38400  1.63160  0.78741
#
#         533      6194  ...    54681    11000     6915     6253      7264  \
# 0  0.115840 -0.000233  ... -0.49069 -1.14930 -0.16539  0.49864  1.077800
# 1 -0.075833  0.208990  ...  0.10747  0.97814  0.85407  0.10528 -0.370430
# 2  0.732920 -2.431700  ... -1.83770 -0.56064  0.93692  0.96585 -0.036786
#
#       5467     2767    23038    57048    79716
# 0  1.66230 -1.66900 -0.49738  0.51629  1.08940
# 1  0.89069 -0.26969 -0.98646 -1.07350  0.48240
# 2  1.35430  2.15870 -0.28158  0.53111 -0.46053
#
# [3 rows x 978 columns]

# %%
print(complete_features_df.shape)
complete_features_df.head(3)
# Out:
# (118050, 978)
#        780      7849     6193       23     9552      387     10921    10285  \
# 0  4.26410  0.057249 -2.13930 -0.22178 -0.37656  1.91380  0.065576 -0.86895
# 1 -0.38221  0.304310 -0.99592 -0.67083 -0.64824  0.62161  0.889530  0.20376
# 2 -0.57171 -0.755000 -0.71011  0.42889  0.27261  0.31436 -1.545800  0.64195
#
#        533     6194  ...     54681     11000     6915      6253      7264  \
# 0 -0.10227  0.00000  ...  5.246200  0.057058 -1.25620 -0.025255  0.168860
# 1  0.19481 -0.45637  ...  0.206690 -0.010866 -0.87206 -0.223750  0.074144
# 2 -0.87685  0.00000  ... -0.005612  1.194500  0.17111  0.334370 -1.089300
#
#        5467     2767    23038    57048    79716
# 0 -1.639100  0.68510 -0.41942  1.71610 -0.47234
# 1  0.093595  0.32667  1.04810 -0.50518 -0.61832
# 2 -0.114640  0.30483 -0.24947 -0.42835  1.58500
#
# [3 rows x 978 columns]

# %%
# VAE of one layer
# 100
# encoder_architecture = [1000,1000]
# decoder_architecture = [1000,1000]
# encoder_architecture = [250,100]
# decoder_architecture = [100,250]
# encoder_architecture = [500,250,100]
# decoder_architecture = [100,250,500]
encoder_architecture = []
decoder_architecture = []

# %%
# model from optimal hyperparameters for onelayer obtained from 1.optimize
# L1000_vae = VAE(
#     input_dim=train_features_df.shape[1],
#     latent_dim=115,
#     batch_size=640,
#     encoder_batch_norm=False,
#     epochs=100,
#     learning_rate=0.001,
#     encoder_architecture=encoder_architecture,
#     decoder_architecture=decoder_architecture,
#     beta=1,
#     verbose=True,
# )
# L1000_vae = VAE(
#     input_dim=train_features_df.shape[1],
#     latent_dim=100,
#     batch_size=320,
#     encoder_batch_norm=True,
#     epochs= 30,
#     learning_rate=0.001,
#     encoder_architecture=encoder_architecture,
#     decoder_architecture=decoder_architecture,
#     beta=5,
#     verbose=True,
# )

# # what ive been using as control 
# L1000_vae = VAE(
#     input_dim=train_features_df.shape[1],
#     latent_dim=50,
#     batch_size=320,
#     encoder_batch_norm=True,
#     epochs= 50,
#     learning_rate=0.001,
#     encoder_architecture=encoder_architecture,
#     decoder_architecture=decoder_architecture,
#     beta=20,
#     verbose=True,
# )
L1000_vae = VAE(
    input_dim=train_features_df.shape[1],
    latent_dim=135,
    batch_size=736,
    encoder_batch_norm=True,
    epochs= 100,
    learning_rate=0.001,
    encoder_architecture=encoder_architecture,
    decoder_architecture=decoder_architecture,
    beta=20,
    verbose=True,
)

# L1000_vae = VAE(
#     input_dim=train_features_df.shape[1],
#     latent_dim=40,
#     batch_size=256,
#     encoder_batch_norm=True,
#     epochs= 10,
#     learning_rate=0.0001,
#     encoder_architecture=encoder_architecture,
#     decoder_architecture=decoder_architecture,
#     beta=70,
#     verbose=True,
# )
# -batch_size: 256
#  |-encoder_batch_norm: True
#  |-epochs: 10
#  |-latent_dim: 40
#  |-learning_rate: 0.0001

# what gives an error
# |-batch_size: 512
# |-encoder_batch_norm: False
# |-epochs: 50
# |-latent_dim: 90
# |-learning_rate: 0.01
#FROM THE PAPER
# L1000_vae = VAE(
#     input_dim=train_features_df.shape[1],
#     latent_dim=100,
#     batch_size=512,
#     encoder_batch_norm=False,
#     epochs=20,
#     learning_rate=0.001,
#     encoder_architecture=encoder_architecture,
#     decoder_architecture=decoder_architecture,
#     beta=1,
#     verbose=True,
# )

# L1000_vae = VAE(
#     input_dim=train_features_df.shape[1],
#     latent_dim=20,
#     batch_size=64,
#     encoder_batch_norm=False,
#     epochs=20,
#     learning_rate=0.001,
#     encoder_architecture=encoder_architecture,
#     decoder_architecture=decoder_architecture,
#     beta=1,
#     verbose=True,
# )
L1000_vae.compile_vae()
#1663

# %%
L1000_vae.train(x_train=train_features_df, x_test=valid_features_df)
# Out:
# Epoch 1/100
# 129/129 [==============================] - 4s 22ms/step - loss: 2852.0587 - val_loss: 1943.7516
# Epoch 2/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1859.2575 - val_loss: 1778.9590
# Epoch 3/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1762.9219 - val_loss: 1734.3784
# Epoch 4/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1728.3040 - val_loss: 1708.7399
# Epoch 5/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1703.8985 - val_loss: 1696.5105
# Epoch 6/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1708.0718 - val_loss: 1687.1820
# Epoch 7/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1693.6990 - val_loss: 1686.0298
# Epoch 8/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1689.9521 - val_loss: 1676.2605
# Epoch 9/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1678.3744 - val_loss: 1673.5172
# Epoch 10/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1670.0471 - val_loss: 1666.7455
# Epoch 11/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1671.7511 - val_loss: 1665.0995
# Epoch 12/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1673.5597 - val_loss: 1663.3837
# Epoch 13/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1674.1796 - val_loss: 1657.6768
# Epoch 14/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1674.1752 - val_loss: 1657.1781
# Epoch 15/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1662.6965 - val_loss: 1656.5870
# Epoch 16/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1654.5038 - val_loss: 1652.4990
# Epoch 17/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1654.1808 - val_loss: 1649.9259
# Epoch 18/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1652.9960 - val_loss: 1644.0853
# Epoch 19/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1654.6701 - val_loss: 1642.8580
# Epoch 20/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1645.1024 - val_loss: 1636.9716
# Epoch 21/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1648.5593 - val_loss: 1635.3818
# Epoch 22/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1643.6768 - val_loss: 1633.6376
# Epoch 23/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1639.7121 - val_loss: 1628.4835
# Epoch 24/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1629.0591 - val_loss: 1620.4475
# Epoch 25/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1624.5745 - val_loss: 1613.0803
# Epoch 26/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1627.7074 - val_loss: 1611.2866
# Epoch 27/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1609.5811 - val_loss: 1604.2433
# Epoch 28/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1620.5070 - val_loss: 1601.2367
# Epoch 29/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1608.8020 - val_loss: 1597.1687
# Epoch 30/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1610.2121 - val_loss: 1591.5978
# Epoch 31/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1597.0222 - val_loss: 1585.5088
# Epoch 32/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1591.4377 - val_loss: 1583.2957
# Epoch 33/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1600.3495 - val_loss: 1580.5432
# Epoch 34/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1587.9954 - val_loss: 1576.1019
# Epoch 35/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1590.3356 - val_loss: 1575.3615
# Epoch 36/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1585.7076 - val_loss: 1571.1007
# Epoch 37/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1589.4817 - val_loss: 1573.0457
# Epoch 38/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1576.3771 - val_loss: 1568.7460
# Epoch 39/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1580.9240 - val_loss: 1566.5725
# Epoch 40/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1574.6813 - val_loss: 1563.3466
# Epoch 41/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1576.5511 - val_loss: 1562.6270
# Epoch 42/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1571.6369 - val_loss: 1562.1390
# Epoch 43/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1571.7959 - val_loss: 1560.5190
# Epoch 44/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1561.9213 - val_loss: 1559.8583
# Epoch 45/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1567.1597 - val_loss: 1557.6702
# Epoch 46/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1564.6070 - val_loss: 1554.3352
# Epoch 47/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1567.2934 - val_loss: 1555.4941
# Epoch 48/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1560.0252 - val_loss: 1553.7061
# Epoch 49/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1569.8679 - val_loss: 1552.9747
# Epoch 50/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1564.7109 - val_loss: 1552.8914
# Epoch 51/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1558.8625 - val_loss: 1551.3912
# Epoch 52/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1558.0041 - val_loss: 1551.5165
# Epoch 53/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1563.7962 - val_loss: 1551.2568
# Epoch 54/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1562.0046 - val_loss: 1551.7134
# Epoch 55/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1559.8872 - val_loss: 1549.6306
# Epoch 56/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1569.1742 - val_loss: 1549.8851
# Epoch 57/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1568.7120 - val_loss: 1548.8584
# Epoch 58/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1562.7562 - val_loss: 1547.3960
# Epoch 59/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1551.6792 - val_loss: 1546.7120
# Epoch 60/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1558.9374 - val_loss: 1546.4598
# Epoch 61/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1560.9258 - val_loss: 1546.2606
# Epoch 62/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1552.3983 - val_loss: 1547.4772
# Epoch 63/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1554.0357 - val_loss: 1546.8888
# Epoch 64/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1553.6046 - val_loss: 1545.2983
# Epoch 65/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1546.9979 - val_loss: 1546.3138
# Epoch 66/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1557.1408 - val_loss: 1544.1479
# Epoch 67/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1557.2268 - val_loss: 1544.8376
# Epoch 68/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1553.7066 - val_loss: 1544.0283
# Epoch 69/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1555.6811 - val_loss: 1544.0801
# Epoch 70/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1557.2880 - val_loss: 1543.2855
# Epoch 71/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1549.9646 - val_loss: 1543.1135
# Epoch 72/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1552.8687 - val_loss: 1542.2062
# Epoch 73/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1551.0517 - val_loss: 1543.5181
# Epoch 74/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1559.5926 - val_loss: 1541.2385
# Epoch 75/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1553.7099 - val_loss: 1541.2312
# Epoch 76/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1544.8826 - val_loss: 1541.0609
# Epoch 77/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1552.1134 - val_loss: 1541.3451
# Epoch 78/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1549.5619 - val_loss: 1539.3285
# Epoch 79/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1554.8012 - val_loss: 1540.9972
# Epoch 80/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1548.7895 - val_loss: 1540.4581
# Epoch 81/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1540.9896 - val_loss: 1539.6787
# Epoch 82/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1549.7021 - val_loss: 1540.4716
# Epoch 83/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1549.5779 - val_loss: 1540.4669
# Epoch 84/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1557.9348 - val_loss: 1539.7284
# Epoch 85/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1550.5139 - val_loss: 1540.0219
# Epoch 86/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1551.0703 - val_loss: 1539.5167
# Epoch 87/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1552.7653 - val_loss: 1539.3224
# Epoch 88/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1544.7798 - val_loss: 1539.8191
# Epoch 89/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1554.4878 - val_loss: 1540.3807
# Epoch 90/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1553.8137 - val_loss: 1540.3315
# Epoch 91/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1544.6882 - val_loss: 1540.7485
# Epoch 92/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1555.6513 - val_loss: 1540.4604
# Epoch 93/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1547.9972 - val_loss: 1538.5616
# Epoch 94/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1552.5803 - val_loss: 1540.0955
# Epoch 95/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1554.4204 - val_loss: 1539.2161
# Epoch 96/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1552.2017 - val_loss: 1539.3600
# Epoch 97/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1551.0160 - val_loss: 1537.8677
# Epoch 98/100
# 129/129 [==============================] - 2s 16ms/step - loss: 1550.3262 - val_loss: 1538.5641
# Epoch 99/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1550.2208 - val_loss: 1539.5558
# Epoch 100/100
# 129/129 [==============================] - 2s 15ms/step - loss: 1554.6948 - val_loss: 1538.3888

# %%
L1000_vae.vae

# %%
# Save training performance
history_df = pd.DataFrame(L1000_vae.vae.history.history)
history_df
#1067 for level 1
# Out:
#            loss     val_loss
# 0   2318.266602  1943.751587
# 1   1827.750977  1778.958984
# 2   1752.685181  1734.378418
# 3   1721.327271  1708.739868
# 4   1706.833130  1696.510498
# ..          ...          ...
# 95  1547.856812  1539.359985
# 96  1547.928101  1537.867676
# 97  1548.849854  1538.564087
# 98  1549.117676  1539.555786
# 99  1548.240479  1538.388794
#
# [100 rows x 2 columns]

# %%
history_df.to_csv('onelayer_training.csv')

# %%
plt.figure(figsize=(10, 5))
plt.plot(history_df["loss"], label="Training data")
plt.plot(history_df["val_loss"], label="Validation data")
plt.title("Loss for VAE training on L1000 data")
# plt.ylabel("Binary cross entropy + KL Divergence")
plt.ylabel("Loss")
plt.xlabel("No. Epoch")
plt.legend()
plt.show()

# %%
# evaluating performance using test set
L1000_vae.vae.evaluate(test_features_df)
# Out:
# 369/369 [==============================] - 1s 1ms/step - loss: 1538.0928
# 1538.0927734375

# %%
reconstruction = pd.DataFrame(
    L1000_vae.vae.predict(test_features_df), columns=profile_features
)
(sum(sum((np.array(test_features_df) - np.array(reconstruction)) ** 2))) ** 0.5
# Out:
# 4008.4514587408726

# %%
# latent space heatmap
fig, ax = plt.subplots(figsize=(10, 10))
encoder = L1000_vae.encoder_block["encoder"]
latent = np.array(encoder.predict(test_features_df)[2])
seaborn.heatmap(latent, ax=ax)
# Out:
# <AxesSubplot:>

# %%
# original vs reconstructed heatmap
reconstruction = pd.DataFrame(
    L1000_vae.vae.predict(test_features_df), columns=profile_features
)
pca = PCA(n_components=2)
pca_reconstructed_latent_df = pd.DataFrame(pca.fit_transform(reconstruction))
pca_test_latent_df = pd.DataFrame(pca.fit_transform(test_features_df))
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))
# seaborn.heatmap(test_features_df, ax=ax1)
# seaborn.heatmap(reconstruction, ax=ax2)
# plt.show()

# %%
figure(figsize=(10, 10), dpi=80)
plt.scatter(pca_test_latent_df[0],pca_test_latent_df[1], marker = ".", alpha = 0.5)
plt.scatter(pca_reconstructed_latent_df[0],pca_reconstructed_latent_df[1], marker = ".", alpha = 0.5)

# %%
decoder = L1000_vae.decoder_block["decoder"]

# %%
simulated_df = pd.DataFrame(np.random.normal(size=(10000, 135)), columns=np.arange(0,135))
reconstruction_of_simulated = decoder.predict(simulated_df)
pca_reconstruction_of_simulated = pd.DataFrame(pca.fit_transform(reconstruction_of_simulated))
fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(16,8), sharey = True, sharex = True)
ax1.scatter(pca_test_latent_df[0],pca_test_latent_df[1], marker = ".", alpha = 0.5)
ax2.scatter(pca_reconstruction_of_simulated[0],pca_reconstruction_of_simulated[1], marker = ".", alpha = 0.5)

# %%
#NOTE: IF YOU RUN THIS, YOU WILL NOT BE ABLE TO REPRODUCE THE EXACT RESULTS IN THE EXPERIMENT
latent_complete = np.array(encoder.predict(complete_features_df)[2])
latent_df = pd.DataFrame(latent_complete)
latent_df.to_csv("../3.application/latentOneLayer.csv")

# %%
#NOTE: IF YOU RUN THIS, YOU WILL NOT BE ABLE TO REPRODUCE THE EXACT RESULTS IN THE EXPERIMENT
decoder.save('./L1000onelayerDecoder')
# Out:
# INFO:tensorflow:Assets written to: ./L1000onelayerDecoder/assets

# %%
#NOTE: IF YOU RUN THIS, YOU WILL NOT BE ABLE TO REPRODUCE THE EXACT RESULTS IN THE EXPERIMENT
encoder.save('./L1000onelayerEncoder')
# Out:
# INFO:tensorflow:Assets written to: ./L1000onelayerEncoder/assets
