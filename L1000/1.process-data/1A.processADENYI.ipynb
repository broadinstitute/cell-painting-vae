# %%
import pandas as pd
import cmapPy.pandasGEXpress.parse as parse
import numpy as np
import matplotlib.pyplot as plt

# %%
input_dir = '../0.download-data/data/'
output_dir = 'data/'

# %%
phase2_gctoo = parse.parse(input_dir + 'level_4_zspc_n27837x978.gctx')

# %%
phase2_data_df = phase2_gctoo.data_df.transpose()

# %%
phase2_data_df
# Out:
# rid                           200814_at  222103_at  201453_x_at  204131_s_at  \
# cid
# REP.A001_A549_24H_X1_B27:A03     0.3547    -0.4940      -0.1721      -0.0339
# REP.A001_A549_24H_X1_B27:A04    -0.2130     0.4931      -0.8768      -0.6968
# REP.A001_A549_24H_X1_B27:A05    -0.3280    -0.4555       0.3819      -1.1447
# REP.A001_A549_24H_X1_B27:A06     0.1175    -0.9678      -0.3185       0.4623
# REP.A001_A549_24H_X1_B27:A07     0.5254     0.0000      -0.4691       0.3652
# ...                                 ...        ...          ...          ...
# REP.A028_A549_24H_X3_B29:P20    -1.4560    -1.0966       0.8633      -0.4426
# REP.A028_A549_24H_X3_B29:P21     0.5672     0.2946      -1.9837      -0.6680
# REP.A028_A549_24H_X3_B29:P22    -0.9993    -0.6982       0.1973      -0.6394
# REP.A028_A549_24H_X3_B29:P23     0.3532    -0.7262      -0.1420       0.6304
# REP.A028_A549_24H_X3_B29:P24    -1.0144    -1.0432      -1.1501      -0.9659
#
# rid                           200059_s_at  205067_at  213702_x_at  \
# cid
# REP.A001_A549_24H_X1_B27:A03      -0.4355     1.8263      -0.1316
# REP.A001_A549_24H_X1_B27:A04      -1.7018    -0.3779      -0.6745
# REP.A001_A549_24H_X1_B27:A05       0.0951    -0.5498      -0.6745
# REP.A001_A549_24H_X1_B27:A06      -0.2842    -0.9202      -0.8413
# REP.A001_A549_24H_X1_B27:A07      -1.0688     0.0793      -1.1123
# ...                                   ...        ...          ...
# REP.A028_A549_24H_X3_B29:P20       2.3494    -0.0464       0.3133
# REP.A028_A549_24H_X3_B29:P21       0.5777     0.0080      -0.8276
# REP.A028_A549_24H_X3_B29:P22       0.1946    -0.2364      -0.4217
# REP.A028_A549_24H_X3_B29:P23       1.0234     0.1308      -0.4872
# REP.A028_A549_24H_X3_B29:P24       0.0658    -0.2523       0.3206
#
# rid                           214435_x_at  201334_s_at  213721_at  ...  \
# cid                                                                ...
# REP.A001_A549_24H_X1_B27:A03       0.0853      -0.4660    -0.3113  ...
# REP.A001_A549_24H_X1_B27:A04      -1.9799      -1.1429    -1.3309  ...
# REP.A001_A549_24H_X1_B27:A05      -0.0950      -0.2946    -0.6920  ...
# REP.A001_A549_24H_X1_B27:A06       0.7160       0.3384    -0.6643  ...
# REP.A001_A549_24H_X1_B27:A07       0.1908      -0.8249    -0.6920  ...
# ...                                   ...          ...        ...  ...
# REP.A028_A549_24H_X3_B29:P20       0.0838      -0.3306    -0.2687  ...
# REP.A028_A549_24H_X3_B29:P21       0.5831       0.5613    -0.1022  ...
# REP.A028_A549_24H_X3_B29:P22      -0.4877      -1.8497     1.1008  ...
# REP.A028_A549_24H_X3_B29:P23       0.7299       0.4346     1.3856  ...
# REP.A028_A549_24H_X3_B29:P24      -0.7915       0.8230    -1.2931  ...
#
# rid                           204662_at  203047_at  203343_at  217995_at  \
# cid
# REP.A001_A549_24H_X1_B27:A03    -0.1345  -0.142300     0.1349     0.3684
# REP.A001_A549_24H_X1_B27:A04     0.5892   3.273700   -15.1256     0.5294
# REP.A001_A549_24H_X1_B27:A05    -0.2690  -1.074500     0.1349    -0.1003
# REP.A001_A549_24H_X1_B27:A06    -0.5354  -0.902900   -15.0048    -0.2428
# REP.A001_A549_24H_X1_B27:A07    -0.6069   0.359000   -15.3090    -0.0670
# ...                                 ...        ...        ...        ...
# REP.A028_A549_24H_X3_B29:P20    -7.1483  -0.426100     0.3652     0.1355
# REP.A028_A549_24H_X3_B29:P21     0.6573   1.565700     0.0000     0.5617
# REP.A028_A549_24H_X3_B29:P22    -0.8957  22.866699     0.6745    -2.2712
# REP.A028_A549_24H_X3_B29:P23     0.0000  22.514900    -0.3457    -2.4435
# REP.A028_A549_24H_X3_B29:P24     0.2250   0.371600     0.6745    -2.4380
#
# rid                           218450_at  212536_at  218529_at  211071_s_at  \
# cid
# REP.A001_A549_24H_X1_B27:A03    -3.1025    -0.6226    -3.7452      -1.3157
# REP.A001_A549_24H_X1_B27:A04    -0.6672     3.7304     0.6153      -1.4900
# REP.A001_A549_24H_X1_B27:A05    -2.3632    -0.2763     0.4857       0.1338
# REP.A001_A549_24H_X1_B27:A06     0.0595    -0.1896     0.8919      -1.2058
# REP.A001_A549_24H_X1_B27:A07    -0.7765    -0.3680     0.9602      -1.4851
# ...                                 ...        ...        ...          ...
# REP.A028_A549_24H_X3_B29:P20     0.3702    -0.1814     0.3243      -1.0863
# REP.A028_A549_24H_X3_B29:P21     3.0291     0.7556     1.0516      -0.5138
# REP.A028_A549_24H_X3_B29:P22    -0.6611    -0.4919    -0.1620      -0.6346
# REP.A028_A549_24H_X3_B29:P23     0.4236     0.0097     0.3827       0.2203
# REP.A028_A549_24H_X3_B29:P24     0.5414    -0.1997    -1.1070      -0.0273
#
# rid                           203341_at  205379_at
# cid
# REP.A001_A549_24H_X1_B27:A03     1.0145     0.1046
# REP.A001_A549_24H_X1_B27:A04     0.9750    -1.8243
# REP.A001_A549_24H_X1_B27:A05    -0.2992     1.1796
# REP.A001_A549_24H_X1_B27:A06    -0.2843     0.2155
# REP.A001_A549_24H_X1_B27:A07    -0.3904    -0.3328
# ...                                 ...        ...
# REP.A028_A549_24H_X3_B29:P20   -12.9015     0.1211
# REP.A028_A549_24H_X3_B29:P21     0.4044    -0.3258
# REP.A028_A549_24H_X3_B29:P22    -0.9292    -0.0825
# REP.A028_A549_24H_X3_B29:P23    -0.4916    -4.8720
# REP.A028_A549_24H_X3_B29:P24    -0.8496    -0.1651
#
# [27837 rows x 978 columns]

# %%
metadata = pd.read_csv(input_dir + "col_meta_level_3_REP.A_A549_only_n27837.txt", sep = "\t")
metadata
# Out:
#                           distil_id bead_batch bead_revision   bead_set  \
# 0      REP.A001_A549_24H_X1_B27:A03        b27            r2  dp52,dp53
# 1      REP.A001_A549_24H_X1_B27:A04        b27            r2  dp52,dp53
# 2      REP.A001_A549_24H_X1_B27:A05        b27            r2  dp52,dp53
# 3      REP.A001_A549_24H_X1_B27:A06        b27            r2  dp52,dp53
# 4      REP.A001_A549_24H_X1_B27:A07        b27            r2  dp52,dp53
# ...                             ...        ...           ...        ...
# 27832  REP.A028_A549_24H_X3_B29:P20        b29            r2  dp52,dp53
# 27833  REP.A028_A549_24H_X3_B29:P21        b29            r2  dp52,dp53
# 27834  REP.A028_A549_24H_X3_B29:P22        b29            r2  dp52,dp53
# 27835  REP.A028_A549_24H_X3_B29:P23        b29            r2  dp52,dp53
# 27836  REP.A028_A549_24H_X3_B29:P24        b29            r2  dp52,dp53
#
#       cell_id  count_cv  count_mean det_mode                 det_plate  \
# 0        A549        39          93      duo  REP.A001_A549_24H_X1_B27
# 1        A549        41          67      duo  REP.A001_A549_24H_X1_B27
# 2        A549        39         109      duo  REP.A001_A549_24H_X1_B27
# 3        A549        38         117      duo  REP.A001_A549_24H_X1_B27
# 4        A549        40          89      duo  REP.A001_A549_24H_X1_B27
# ...       ...       ...         ...      ...                       ...
# 27832    A549        27          64      duo  REP.A028_A549_24H_X3_B29
# 27833    A549        27          54      duo  REP.A028_A549_24H_X3_B29
# 27834    A549        28          55      duo  REP.A028_A549_24H_X3_B29
# 27835    A549        26          59      duo  REP.A028_A549_24H_X3_B29
# 27836    A549        26          62      duo  REP.A028_A549_24H_X3_B29
#
#       det_well  ... x_mg_per_ml x_mmoles_per_liter  x_purity  \
# 0          A03  ... -666.000000        -666.000000   -666.00
# 1          A04  ... -666.000000        -666.000000   -666.00
# 2          A05  ... -666.000000        -666.000000   -666.00
# 3          A06  ... -666.000000        -666.000000   -666.00
# 4          A07  ...    1.105460          10.000000    100.00
# ...        ...  ...         ...                ...       ...
# 27832      P20  ...    4.521240           3.333330     97.22
# 27833      P21  ...    1.507080           1.111110     97.22
# 27834      P22  ...    0.502360           0.370370     97.22
# 27835      P23  ...    0.167453           0.123457     97.22
# 27836      P24  ...    0.055818           0.041152     97.22
#
#                                                 x_smiles x_volume_ul  \
# 0                                                   -666          13
# 1                                                   -666          13
# 2                                                   -666          13
# 3                                                   -666          13
# 4                                               NNC(N)=N          13
# ...                                                  ...         ...
# 27832  C[C@H](CNC(=O)CC[C@]1(C)[C@@H](CC(N)=O)[C@@H]2...          13
# 27833  C[C@H](CNC(=O)CC[C@]1(C)[C@@H](CC(N)=O)[C@@H]2...          13
# 27834  C[C@H](CNC(=O)CC[C@]1(C)[C@@H](CC(N)=O)[C@@H]2...          13
# 27835  C[C@H](CNC(=O)CC[C@]1(C)[C@@H](CC(N)=O)[C@@H]2...          13
# 27836  C[C@H](CNC(=O)CC[C@]1(C)[C@@H](CC(N)=O)[C@@H]2...          13
#
#       pert_plate  batch nearest_dose        brew_prefix               group_id
# 0       REP.A001  REP.A      -666.00  REP.A001_A549_24H  REP.A001_A549_24H:A03
# 1       REP.A001  REP.A      -666.00  REP.A001_A549_24H  REP.A001_A549_24H:A04
# 2       REP.A001  REP.A      -666.00  REP.A001_A549_24H  REP.A001_A549_24H:A05
# 3       REP.A001  REP.A      -666.00  REP.A001_A549_24H  REP.A001_A549_24H:A06
# 4       REP.A001  REP.A        10.00  REP.A001_A549_24H  REP.A001_A549_24H:A07
# ...          ...    ...          ...                ...                    ...
# 27832   REP.A028  REP.A         3.33  REP.A028_A549_24H  REP.A028_A549_24H:P20
# 27833   REP.A028  REP.A         1.11  REP.A028_A549_24H  REP.A028_A549_24H:P21
# 27834   REP.A028  REP.A         0.37  REP.A028_A549_24H  REP.A028_A549_24H:P22
# 27835   REP.A028  REP.A         0.12  REP.A028_A549_24H  REP.A028_A549_24H:P23
# 27836   REP.A028  REP.A         0.04  REP.A028_A549_24H  REP.A028_A549_24H:P24
#
# [27837 rows x 45 columns]

# %%
# gene_info = pd.read_csv(input_dir + 'GSE92742_Broad_LINCS_gene_info.txt.gz', sep = "\t")
# landmark_genes = np.char.mod('%d',gene_info[gene_info.pr_is_lm == 1].pr_gene_id)

# %%
# landmark_genes

# %%
#slicing the dataframe to only include landmark genes
# phase2_data_df = phase2_data_df.loc[:,phase2_data_df.columns.isin(landmark_genes)]

# %%
#add pert_id and cell_id metadata column to phase1_data_df

# %%
#add pert_id and cell_id metadata column to phase2_data_df
# phase2_sig_info = pd.read_csv(input_dir + 'GSE70138_Broad_LINCS_sig_info_2017-03-06.txt.gz', sep = "\t").set_index('sig_id').reindex(index=phase2_data_df.index)
# phase2_sig_info = phase2_sig_info.loc[:,phase2_sig_info.columns.isin(['pert_id','cell_id'])]
# phase2_df = pd.concat([phase2_sig_info,phase2_data_df], axis=1).reset_index()
# phase2_df.head()
# pd.read_csv(input_dir + 'GSE70138_Broad_LINCS_sig_info_2017-03-06.txt.gz', sep = "\t")

# %%
# np.max(phase2_df['780'])

# %%
# print(phase2_df.shape)
# phase2_df.groupby('cell_id').count().sort_values('cid')

# %%
#add inchikey metadata column to phase2_data_df
# phase2_pert_info = pd.read_csv(input_dir + "GSE70138_Broad_LINCS_pert_info.txt.gz", sep = '\t').set_index('pert_id').reindex(index=phase2_df.pert_id)
# phase2_pert_info = phase2_pert_info.loc[:,phase2_pert_info.columns == 'inchi_key']
# phase2_pert_info['inchi_key'] = phase2_pert_info.inchi_key.str.split("-").str[0]
# phase2_pert_info = phase2_pert_info.rename(columns={"inchi_key": "inchi_key_prefix"})
# phase2_df = phase2_df.set_index("pert_id")
# phase2_df = pd.concat([phase2_pert_info, phase2_df], axis=1).reset_index()
# phase2_df.head()

# %%
#combine phase1 and phase 2, and add rna_plate metadata feature
# combined_df = pd.concat([phase1_df,phase2_df])
# phase2_df['cid'] = phase2_df.cid.str.split(":").str[0]
# phase2_df = phase2_df.rename(columns={"cid": "rna_plate"})
# print(combined_df.shape)
# combined_df.head()

# %%
# cell_painting_df = pd.read_csv('https://github.com/yuenler/cell-painting-vae/raw/master/0.preprocessing/data/cell_painting_complete.tsv.gz', sep = "\t")
# cell_painting_pert_id = cell_painting_df.Metadata_broad_sample.to_list()
# for i in range(len(cell_painting_pert_id)):
#     if cell_painting_pert_id[i][:3] == "BRD":
#         cell_painting_pert_id[i] = cell_painting_pert_id[i][:13]

# %%
# # ids = pd.read_csv("data/repurposing_samples_20200324.txt", sep = "\t").loc[:,['broad_id','deprecated_broad_id']].dropna().reset_index(drop = True)
# cell_painting_inchi = pd.read_csv("https://github.com/broadinstitute/lincs-cell-painting/raw/master/metadata/moa/repurposing_info_external_moa_map_resolved.tsv", sep = "\t").loc[:,['broad_sample','InChIKey14']].dropna().set_index('broad_sample').reindex(index = cell_painting_df.Metadata_broad_sample)
# cell_painting_df = cell_painting_df.set_index("Metadata_broad_sample")
# cell_painting_df = pd.concat([cell_painting_inchi, cell_painting_df], axis=1).reset_index()
# # temp_ids = pd.DataFrame(columns = ['broad_id','deprecated_broad_id'])

# # for index, row in ids.iterrows():
# #     split_rows = row.deprecated_broad_id.split("|")
# #     for split_row in split_rows:
# #         temp_ids = temp_ids.append({'broad_id':row.broad_id, 'deprecated_broad_id':split_row}, ignore_index = True)

# # ids = pd.DataFrame(temp_ids)

# # ids.broad_id = ids.broad_id.apply(lambda x: str(x)[:13]).to_list()
# # ids.deprecated_broad_id = ids.deprecated_broad_id.apply(lambda x: str(x)[:13]).to_list()
# # ids = ids.set_index('deprecated_broad_id').to_dict()['broad_id']
# # len(ids)
# cell_painting_df

# %%
# combined_df = combined_df.replace({"pert_id": ids})

# %%
# for i in range(len(cell_painting_pert_id)):
#     if cell_painting_pert_id[i] in ids.keys():
#         cell_painting_pert_id[i] = ids[cell_painting_pert_id[i]]

# %%
# cell_painting_inchi = cell_painting_df.InChIKey14.to_list()
# overlapped_df = combined_df[combined_df.inchi_key_prefix.isin(cell_painting_inchi)].reset_index(drop = True)
# print(overlapped_df.shape)
# overlapped_df.head()
# overlapped_df
# # overlapped_df = combined_df[combined_df.pert_id.isin(cell_painting_pert_id)].reset_index(drop = True)
# # print(overlapped_df.shape)
# # overlapped_df.head()
# # overlapped_df

# %%
# A549_overlapped_df = overlapped_df[overlapped_df.cell_id == "A549"]
# print(A549_overlapped_df.shape)
# A549_overlapped_df.head()

# %%
# hi = np.unique(overlapped_df.inchi_key_prefix.to_list())
# unique_cell= np.unique(cell_painting_inchi)
# count = 0
# nah = 0
# for i in range(len(unique_cell)):
#     if unique_cell[i] in hi:
#         count += 1
#     else:
#         nah += 1
# # cell_painting_pert_id
# print(count)
# print(nah)
# len(hi)
# len(np.unique(hi))

# %%
# np.sort(cell_line_grouping.pert_id)

# %%
# # overlap the right one when calculating
# highest_perts = cell_line_grouping.pert_id[cell_line_grouping.pert_id > 10000]
# highest_perts.plot.bar()

# %%
# highest_inchi = cell_line_grouping.inchi_key_prefix[cell_line_grouping.inchi_key_prefix > 3500]
# highest_inchi.plot.bar()

# %%
# cell_line_grouping_overlap = overlapped_df.groupby('cell_id').nunique()

# %%
# cell_line_grouping_overlap.inchi_key_prefix

# %%
# highest_perts_overlap = cell_line_grouping_overlap.pert_id[cell_line_grouping.pert_id > 10000]
# highest_perts_overlap.plot.bar()

# %%
# highest_inchi_overlap = cell_line_grouping_overlap.inchi_key_prefix[cell_line_grouping_overlap.inchi_key_prefix > 700]
# highest_inchi_overlap.plot.bar()

# %%
# A549_overlapped_df.to_csv(output_dir + 'L1000_A549_overlap.tsv.gz', sep = '\t', index = False)

# %%
# overlapped_df.to_csv(output_dir + 'L1000_overlap.tsv.gz', sep = '\t', index = False)

# %%
phase2_data_df.to_csv(output_dir + 'L1000_adenyi.tsv.gz', sep = '\t', index = False)
