# %% [markdown]
# ## Compile per MOA p value for shuffled comparison

# %%
import pathlib
import numpy as np
import pandas as pd
import scipy.stats

# %%
# Load L2 distances per MOA
cp_l2_file = pathlib.Path("..", "cell-painting", "3.application", "L2_distances_with_moas.csv")
cp_l2_df = pd.read_csv(cp_l2_file).assign(shuffled="real")

cp_l2_df.loc[cp_l2_df.Model.str.contains("Shuffled"), "shuffled"] = "shuffled"
cp_l2_df = cp_l2_df.assign(
    architecture=[x[-1] for x in cp_l2_df.Model.str.split(" ")],
    assay="CellPainting",
    metric="L2 distance"
).rename(columns={"L2 Distance": "metric_value"})

print(cp_l2_df.shape)
cp_l2_df.head()
# Out:
# (4620, 7)
#      Model  metric_value                                                MOA  \
# 0  Vanilla      2.752688        NFkB pathway inhibitor|proteasome inhibitor
# 1  Vanilla      0.276543  dopamine receptor antagonist|serotonin recepto...
# 2  Vanilla      0.307135  cyclooxygenase inhibitor|prostanoid receptor a...
# 3  Vanilla      1.839651                      mTOR inhibitor|PI3K inhibitor
# 4  Vanilla      0.481039           insulin sensitizer|PPAR receptor agonist
#
#   shuffled architecture         assay       metric
# 0     real      Vanilla  CellPainting  L2 distance
# 1     real      Vanilla  CellPainting  L2 distance
# 2     real      Vanilla  CellPainting  L2 distance
# 3     real      Vanilla  CellPainting  L2 distance
# 4     real      Vanilla  CellPainting  L2 distance

# %%
# Load Pearson correlations per MOA
cp_file = pathlib.Path("..", "cell-painting", "3.application", "pearson_with_moas.csv")
cp_pearson_df = pd.read_csv(cp_file).assign(shuffled="real")

cp_pearson_df.loc[cp_pearson_df.Model.str.contains("Shuffled"), "shuffled"] = "shuffled"
cp_pearson_df = cp_pearson_df.assign(
    architecture=[x[-1] for x in cp_pearson_df.Model.str.split(" ")],
    assay="CellPainting",
    metric="Pearson correlation"
).rename(columns={"Pearson": "metric_value"})

print(cp_pearson_df.shape)
cp_pearson_df.head()
# Out:
# (4620, 7)
#      Model  metric_value                                                MOA  \
# 0  Vanilla      0.800048        NFkB pathway inhibitor|proteasome inhibitor
# 1  Vanilla      0.997168  dopamine receptor antagonist|serotonin recepto...
# 2  Vanilla      0.996387  cyclooxygenase inhibitor|prostanoid receptor a...
# 3  Vanilla      0.854243                      mTOR inhibitor|PI3K inhibitor
# 4  Vanilla      0.990826           insulin sensitizer|PPAR receptor agonist
#
#   shuffled architecture         assay               metric
# 0     real      Vanilla  CellPainting  Pearson correlation
# 1     real      Vanilla  CellPainting  Pearson correlation
# 2     real      Vanilla  CellPainting  Pearson correlation
# 3     real      Vanilla  CellPainting  Pearson correlation
# 4     real      Vanilla  CellPainting  Pearson correlation

# %%
# Combine data
cp_df = pd.concat([cp_l2_df, cp_pearson_df]).reset_index(drop=True)

print(cp_df.shape)
cp_df.head()
# Out:
# (9240, 7)
#      Model  metric_value                                                MOA  \
# 0  Vanilla      2.752688        NFkB pathway inhibitor|proteasome inhibitor
# 1  Vanilla      0.276543  dopamine receptor antagonist|serotonin recepto...
# 2  Vanilla      0.307135  cyclooxygenase inhibitor|prostanoid receptor a...
# 3  Vanilla      1.839651                      mTOR inhibitor|PI3K inhibitor
# 4  Vanilla      0.481039           insulin sensitizer|PPAR receptor agonist
#
#   shuffled architecture         assay       metric
# 0     real      Vanilla  CellPainting  L2 distance
# 1     real      Vanilla  CellPainting  L2 distance
# 2     real      Vanilla  CellPainting  L2 distance
# 3     real      Vanilla  CellPainting  L2 distance
# 4     real      Vanilla  CellPainting  L2 distance

# %%
all_moas = cp_df.MOA.unique().tolist()
print(len(all_moas))
all_metrics = cp_df.metric.unique().tolist()
all_architectures = cp_df.architecture.unique().tolist()
all_architectures
# Out:
# 84
# ['Vanilla', 'Beta', 'MMD', 'PCA', 'Complete']

# %%
results_df = []
for metric in all_metrics:
    for moa in all_moas:
        for arch in all_architectures:
            # subset data to include moa per architecture
            sub_cp_df = (
                cp_df
                .query(f"metric == '{metric}'")
                .query(f"architecture == '{arch}'")
                .query(f"MOA == '{moa}'")
                .reset_index(drop=True)
            )

            real_ = sub_cp_df.query("shuffled == 'real'").loc[:, "metric_value"].tolist()
            shuff_ = sub_cp_df.query("shuffled != 'real'").loc[:, "metric_value"].tolist()

            # Calculate zscore consistently with other experiments
            zscore_result = scipy.stats.zscore(shuff_ + real_)[-1]
            results_df.append([moa, arch, zscore_result, metric])

# Compile results
results_df = pd.DataFrame(results_df, columns=["MOA", "model", "zscore", "metric"])

print(results_df.shape)
results_df.head()
# Out:
# (840, 4)
#                                            MOA     model    zscore  \
# 0  NFkB pathway inhibitor|proteasome inhibitor   Vanilla -3.153561
# 1  NFkB pathway inhibitor|proteasome inhibitor      Beta -3.143671
# 2  NFkB pathway inhibitor|proteasome inhibitor       MMD -3.153877
# 3  NFkB pathway inhibitor|proteasome inhibitor       PCA -2.970405
# 4  NFkB pathway inhibitor|proteasome inhibitor  Complete -2.806738
#
#         metric
# 0  L2 distance
# 1  L2 distance
# 2  L2 distance
# 3  L2 distance
# 4  L2 distance

# %%
# Output data
output_file = pathlib.Path("data", "MOA_LSA_metrics.tsv")
results_df.to_csv(output_file, sep="\t", index=False)
