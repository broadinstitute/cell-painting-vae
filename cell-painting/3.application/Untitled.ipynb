# %%
import pandas as pd

# %%
a = pd.read_csv('per_moa_performance/level5_vanilla_moa_performance.csv')
a[a['zscore'] < 0]
# Out:
#     Unnamed: 0                                                MOA    zscore  \
# 0            0        NFkB pathway inhibitor|proteasome inhibitor -3.153561
# 1           17  microtubule inhibitor|tubulin polymerization i... -3.133868
# 2           58              Aurora kinase inhibitor|JAK inhibitor -3.112438
# 3           46              DNA inhibitor|topoisomerase inhibitor -3.058326
# 4            3                      mTOR inhibitor|PI3K inhibitor -2.954679
# 5           56    RNA synthesis inhibitor|topoisomerase inhibitor -2.821347
# 6           23                       AKT inhibitor|mTOR inhibitor -2.739848
# 7           22  phosphodiesterase inhibitor|sodium channel blo... -2.535679
# 8           50    cyclooxygenase inhibitor|lipoxygenase inhibitor -2.354261
# 9           18       DNA alkylating agent|DNA synthesis inhibitor -2.162669
# 10          39  serotonin receptor antagonist|sodium channel b... -1.833324
# ...
