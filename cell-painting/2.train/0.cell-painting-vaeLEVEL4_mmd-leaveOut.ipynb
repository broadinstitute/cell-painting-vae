# %% [markdown]
# # Train a VAE on Cell Painting LINCS Data

# %%
import sys
import pathlib
import numpy as np
import pandas as pd
sys.path.insert(0, "../../scripts")
from utils import load_data


from pycytominer.cyto_utils import infer_cp_features


import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

from sklearn.decomposition import PCA
from tensorflow import keras

from vae import VAE

from tensorflow.keras.models import Model, Sequential
import seaborn
import random as python_random
import tensorflow as tf

# %%
def remove_moa(df):
    pipes = ['benzodiazepine receptor agonist|HDAC inhibitor'
         'CDK inhibitor|glycogen synthase kinase inhibitor',
             'DNA synthesis inhibitor|microtubule inhibitor',
             'antiviral|RNA synthesis inhibitor',
            'AKT inhibitor|mTOR inhibitor']    
    moas =  []
    for pipe in pipes:
        moas.append(pipe)
        moas.append(pipe.split('|')[0])
        moas.append(pipe.split('|')[1])
    return df[~df.moa.isin(moas)]

# %%
data_splits = ["train", "test", "valid","complete"]
data_dict = load_data(data_splits)
# Out:
# /home/ubuntu/miniconda3/envs/cell-painting-vae/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3361: DtypeWarning: Columns (18,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
# Prepare data for training
meta_features = infer_cp_features(data_dict["train"], metadata=True)
cp_features = infer_cp_features(data_dict["train"])

moa_df_train = pd.read_csv("../3.application/repurposing_info_external_moa_map_resolved.tsv",sep='\t').set_index('broad_sample').reindex(index=data_dict['train']['Metadata_broad_sample']).reset_index().drop('Metadata_broad_sample',axis = 1)
data_dict['train'] = pd.concat([moa_df_train,data_dict['train']], axis=1)

moa_df_valid = pd.read_csv("../3.application/repurposing_info_external_moa_map_resolved.tsv",sep='\t').set_index('broad_sample').reindex(index=data_dict['valid']['Metadata_broad_sample']).reset_index().drop('Metadata_broad_sample',axis = 1)
data_dict['valid'] = pd.concat([moa_df_valid,data_dict['valid']], axis=1)

data_dict['train'] = remove_moa(data_dict['train'])
data_dict['valid'] = remove_moa(data_dict['valid'])

train_features_df = data_dict["train"].reindex(cp_features, axis="columns")
train_meta_df = data_dict["train"].reindex(meta_features, axis="columns")

test_features_df = data_dict["test"].reindex(cp_features, axis="columns")
test_meta_df = data_dict["test"].reindex(meta_features, axis="columns")

valid_features_df = data_dict["valid"].reindex(cp_features, axis="columns")
valid_meta_df = data_dict["valid"].reindex(meta_features, axis="columns")

complete_features_df = data_dict["complete"].reindex(cp_features, axis="columns")
complete_meta_df = data_dict["complete"].reindex(meta_features, axis="columns")

# %%
print(train_features_df.shape)
train_features_df.head(3)
# Out:
# (39473, 685)
#    Cells_AreaShape_Compactness  Cells_AreaShape_Eccentricity  \
# 0                      0.19790                       0.69605
# 1                      0.18605                       0.68873
# 2                      0.19083                       0.66276
#
#    Cells_AreaShape_Extent  Cells_AreaShape_FormFactor  \
# 0                 0.40400                     0.30834
# 1                 0.41051                     0.31982
# 2                 0.38585                     0.31437
#
#    Cells_AreaShape_MedianRadius  Cells_AreaShape_Orientation  \
# 0                       0.19317                      0.71895
# 1                       0.19885                      0.72510
# 2                       0.20415                      0.71380
#
#    Cells_AreaShape_Solidity  Cells_AreaShape_Zernike_0_0  \
# 0                   0.38837                      0.38668
# 1                   0.39552                      0.38362
# 2                   0.38701                      0.36699
#
#    Cells_AreaShape_Zernike_1_1  Cells_AreaShape_Zernike_2_0  ...  \
# 0                      0.62494                      0.87362  ...
# 1                      0.65094                      0.89679  ...
# 2                      0.60932                      0.88492  ...
#
#    Nuclei_Texture_SumEntropy_DNA_5_0  Nuclei_Texture_SumEntropy_Mito_5_0  \
# 0                            0.61045                             0.41907
# 1                            0.61393                             0.38269
# 2                            0.60850                             0.41850
#
#    Nuclei_Texture_SumEntropy_RNA_20_0  Nuclei_Texture_SumEntropy_RNA_5_0  \
# 0                             0.64945                            0.65199
# 1                             0.63814                            0.68204
# 2                             0.63529                            0.65208
#
#    Nuclei_Texture_SumVariance_DNA_20_0  Nuclei_Texture_SumVariance_RNA_20_0  \
# 0                              0.22660                              0.32108
# 1                              0.23700                              0.32808
# 2                              0.22852                              0.32710
#
#    Nuclei_Texture_Variance_DNA_20_0  Nuclei_Texture_Variance_ER_20_0  \
# 0                           0.29776                          0.26173
# 1                           0.27981                          0.26893
# 2                           0.29371                          0.27159
#
#    Nuclei_Texture_Variance_RNA_10_0  Nuclei_Texture_Variance_RNA_20_0
# 0                           0.34524                           0.32151
# 1                           0.34938                           0.33179
# 2                           0.33871                           0.31965
#
# [3 rows x 685 columns]

# %%
print(test_features_df.shape)
test_features_df.head(3)
# Out:
# (5030, 685)
#    Cells_AreaShape_Compactness  Cells_AreaShape_Eccentricity  \
# 0                      0.19050                       0.68937
# 1                      0.18661                       0.67731
# 2                      0.18626                       0.67036
#
#    Cells_AreaShape_Extent  Cells_AreaShape_FormFactor  \
# 0                 0.39383                     0.33072
# 1                 0.39621                     0.32318
# 2                 0.41101                     0.31863
#
#    Cells_AreaShape_MedianRadius  Cells_AreaShape_Orientation  \
# 0                       0.20185                      0.72292
# 1                       0.20716                      0.70964
# 2                       0.20182                      0.71139
#
#    Cells_AreaShape_Solidity  Cells_AreaShape_Zernike_0_0  \
# 0                   0.38085                      0.37504
# 1                   0.39401                      0.37779
# 2                   0.40302                      0.38979
#
#    Cells_AreaShape_Zernike_1_1  Cells_AreaShape_Zernike_2_0  ...  \
# 0                      0.61905                      0.88361  ...
# 1                      0.60275                      0.88912  ...
# 2                      0.59188                      0.86857  ...
#
#    Nuclei_Texture_SumEntropy_DNA_5_0  Nuclei_Texture_SumEntropy_Mito_5_0  \
# 0                            0.60356                             0.39345
# 1                            0.60936                             0.40380
# 2                            0.61009                             0.40904
#
#    Nuclei_Texture_SumEntropy_RNA_20_0  Nuclei_Texture_SumEntropy_RNA_5_0  \
# 0                             0.63470                            0.63406
# 1                             0.64406                            0.64859
# 2                             0.64250                            0.63285
#
#    Nuclei_Texture_SumVariance_DNA_20_0  Nuclei_Texture_SumVariance_RNA_20_0  \
# 0                              0.23588                              0.36061
# 1                              0.22752                              0.29811
# 2                              0.23931                              0.33179
#
#    Nuclei_Texture_Variance_DNA_20_0  Nuclei_Texture_Variance_ER_20_0  \
# 0                           0.30092                          0.23638
# 1                           0.29430                          0.25475
# 2                           0.28571                          0.24980
#
#    Nuclei_Texture_Variance_RNA_10_0  Nuclei_Texture_Variance_RNA_20_0
# 0                           0.36015                           0.32779
# 1                           0.34154                           0.32013
# 2                           0.34516                           0.32968
#
# [3 rows x 685 columns]

# %%
print(complete_features_df.shape)
complete_features_df.head(3)
# Out:
# (50303, 685)
#    Cells_AreaShape_Compactness  Cells_AreaShape_Eccentricity  \
# 0                      0.19575                       0.67566
# 1                      0.18472                       0.66556
# 2                      0.18254                       0.69650
#
#    Cells_AreaShape_Extent  Cells_AreaShape_FormFactor  \
# 0                 0.40288                     0.32633
# 1                 0.39721                     0.30968
# 2                 0.39596                     0.33502
#
#    Cells_AreaShape_MedianRadius  Cells_AreaShape_Orientation  \
# 0                       0.20267                      0.71477
# 1                       0.20009                      0.71345
# 2                       0.20420                      0.72770
#
#    Cells_AreaShape_Solidity  Cells_AreaShape_Zernike_0_0  \
# 0                   0.39122                      0.38048
# 1                   0.39953                      0.37314
# 2                   0.39590                      0.37023
#
#    Cells_AreaShape_Zernike_1_1  Cells_AreaShape_Zernike_2_0  ...  \
# 0                      0.61184                      0.88375  ...
# 1                      0.61074                      0.87695  ...
# 2                      0.60264                      0.88038  ...
#
#    Nuclei_Texture_SumEntropy_DNA_5_0  Nuclei_Texture_SumEntropy_Mito_5_0  \
# 0                            0.60865                             0.38869
# 1                            0.60682                             0.39779
# 2                            0.60665                             0.39705
#
#    Nuclei_Texture_SumEntropy_RNA_20_0  Nuclei_Texture_SumEntropy_RNA_5_0  \
# 0                             0.65364                            0.65716
# 1                             0.64013                            0.63120
# 2                             0.66616                            0.62889
#
#    Nuclei_Texture_SumVariance_DNA_20_0  Nuclei_Texture_SumVariance_RNA_20_0  \
# 0                              0.24912                              0.33129
# 1                              0.24380                              0.30471
# 2                              0.25125                              0.33549
#
#    Nuclei_Texture_Variance_DNA_20_0  Nuclei_Texture_Variance_ER_20_0  \
# 0                           0.28864                          0.27106
# 1                           0.28554                          0.27852
# 2                           0.29656                          0.25706
#
#    Nuclei_Texture_Variance_RNA_10_0  Nuclei_Texture_Variance_RNA_20_0
# 0                           0.35254                           0.32675
# 1                           0.35157                           0.31637
# 2                           0.33868                           0.31901
#
# [3 rows x 685 columns]

# %%
# VAE of one layer

encoder_architecture = [250]
decoder_architecture = [250]

# %%
cp_vae = VAE(
    input_dim=train_features_df.shape[1],
    latent_dim=90,
    batch_size=32,
    encoder_batch_norm=True,
    epochs=50,
    learning_rate=0.0001,
    encoder_architecture=encoder_architecture,
    decoder_architecture=decoder_architecture,
    beta=0,
    lam=10000,
    verbose=True,
)


cp_vae.compile_vae()

# %%
cp_vae.train(x_train=train_features_df, x_test=valid_features_df)
# Out:
# Epoch 1/50
# 1234/1234 [==============================] - 9s 6ms/step - loss: 139.3907 - recon: 56.3837 - kl: 0.0000e+00 - mmd: 18.4200 - val_loss: 39.3186 - val_recon: 12.5756 - val_kl: 0.0000e+00 - val_mmd: 27.2772
# Epoch 2/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 25.2227 - recon: 7.5704 - kl: 0.0000e+00 - mmd: 15.9756 - val_loss: 24.1150 - val_recon: 5.5070 - val_kl: 0.0000e+00 - val_mmd: 18.6508
# Epoch 3/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 19.8130 - recon: 4.4619 - kl: 0.0000e+00 - mmd: 14.8029 - val_loss: 37.1259 - val_recon: 4.7650 - val_kl: 0.0000e+00 - val_mmd: 32.1840
# Epoch 4/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 17.4621 - recon: 3.0334 - kl: 0.0000e+00 - mmd: 14.1204 - val_loss: 32.2422 - val_recon: 2.6386 - val_kl: 0.0000e+00 - val_mmd: 29.2642
# Epoch 5/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 16.0987 - recon: 2.1711 - kl: 0.0000e+00 - mmd: 13.7078 - val_loss: 23.9517 - val_recon: 1.9519 - val_kl: 0.0000e+00 - val_mmd: 22.1481
# Epoch 6/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 15.3412 - recon: 1.6305 - kl: 0.0000e+00 - mmd: 13.5482 - val_loss: 26.9802 - val_recon: 1.4730 - val_kl: 0.0000e+00 - val_mmd: 25.8937
# Epoch 7/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 14.7916 - recon: 1.3088 - kl: 0.0000e+00 - mmd: 13.3714 - val_loss: 23.5554 - val_recon: 1.2075 - val_kl: 0.0000e+00 - val_mmd: 21.8593
# Epoch 8/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 14.4116 - recon: 1.1096 - kl: 0.0000e+00 - mmd: 13.2504 - val_loss: 27.7219 - val_recon: 1.0535 - val_kl: 0.0000e+00 - val_mmd: 26.7259
# Epoch 9/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 14.1047 - recon: 0.9776 - kl: 0.0000e+00 - mmd: 13.1827 - val_loss: 30.0145 - val_recon: 0.9379 - val_kl: 0.0000e+00 - val_mmd: 29.2235
# Epoch 10/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 14.1100 - recon: 0.9018 - kl: 0.0000e+00 - mmd: 13.1063 - val_loss: 32.1210 - val_recon: 0.8364 - val_kl: 0.0000e+00 - val_mmd: 31.3306
# Epoch 11/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 13.6993 - recon: 0.8425 - kl: 0.0000e+00 - mmd: 12.9003 - val_loss: 24.1640 - val_recon: 0.7582 - val_kl: 0.0000e+00 - val_mmd: 23.4552
# Epoch 12/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 13.7919 - recon: 0.8025 - kl: 0.0000e+00 - mmd: 12.8409 - val_loss: 33.1557 - val_recon: 0.7378 - val_kl: 0.0000e+00 - val_mmd: 31.8793
# Epoch 13/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 13.5673 - recon: 0.7727 - kl: 0.0000e+00 - mmd: 12.8230 - val_loss: 23.5928 - val_recon: 0.7085 - val_kl: 0.0000e+00 - val_mmd: 22.7407
# Epoch 14/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 13.4965 - recon: 0.7522 - kl: 0.0000e+00 - mmd: 12.6040 - val_loss: 24.6025 - val_recon: 0.7032 - val_kl: 0.0000e+00 - val_mmd: 24.1043
# Epoch 15/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 13.2336 - recon: 0.7310 - kl: 0.0000e+00 - mmd: 12.4725 - val_loss: 21.5961 - val_recon: 0.6626 - val_kl: 0.0000e+00 - val_mmd: 21.3920
# Epoch 16/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 13.1434 - recon: 0.7124 - kl: 0.0000e+00 - mmd: 12.3860 - val_loss: 21.1822 - val_recon: 0.6391 - val_kl: 0.0000e+00 - val_mmd: 20.8511
# Epoch 17/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 12.9912 - recon: 0.6972 - kl: 0.0000e+00 - mmd: 12.3080 - val_loss: 22.8985 - val_recon: 0.6390 - val_kl: 0.0000e+00 - val_mmd: 22.6281
# Epoch 18/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 12.8300 - recon: 0.6801 - kl: 0.0000e+00 - mmd: 12.2849 - val_loss: 19.7487 - val_recon: 0.6209 - val_kl: 0.0000e+00 - val_mmd: 19.3882
# Epoch 19/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 12.8198 - recon: 0.6692 - kl: 0.0000e+00 - mmd: 12.1603 - val_loss: 20.4054 - val_recon: 0.6034 - val_kl: 0.0000e+00 - val_mmd: 19.6446
# Epoch 20/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 12.6568 - recon: 0.6597 - kl: 0.0000e+00 - mmd: 12.0871 - val_loss: 25.2507 - val_recon: 0.6158 - val_kl: 0.0000e+00 - val_mmd: 24.1115
# Epoch 21/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 12.6024 - recon: 0.6508 - kl: 0.0000e+00 - mmd: 12.0288 - val_loss: 20.6682 - val_recon: 0.5976 - val_kl: 0.0000e+00 - val_mmd: 20.2465
# Epoch 22/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 12.6060 - recon: 0.6414 - kl: 0.0000e+00 - mmd: 12.0489 - val_loss: 17.6486 - val_recon: 0.5895 - val_kl: 0.0000e+00 - val_mmd: 17.0527
# Epoch 23/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 12.4777 - recon: 0.6346 - kl: 0.0000e+00 - mmd: 11.8957 - val_loss: 21.9309 - val_recon: 0.5864 - val_kl: 0.0000e+00 - val_mmd: 21.4740
# Epoch 24/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 12.5230 - recon: 0.6308 - kl: 0.0000e+00 - mmd: 11.7985 - val_loss: 19.6705 - val_recon: 0.5764 - val_kl: 0.0000e+00 - val_mmd: 18.9124
# Epoch 25/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 12.3213 - recon: 0.6185 - kl: 0.0000e+00 - mmd: 11.7784 - val_loss: 26.3264 - val_recon: 0.5922 - val_kl: 0.0000e+00 - val_mmd: 25.6634
# Epoch 26/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 12.3166 - recon: 0.6160 - kl: 0.0000e+00 - mmd: 11.6268 - val_loss: 22.1489 - val_recon: 0.5684 - val_kl: 0.0000e+00 - val_mmd: 21.4347
# Epoch 27/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 12.1280 - recon: 0.6125 - kl: 0.0000e+00 - mmd: 11.6144 - val_loss: 17.6155 - val_recon: 0.5650 - val_kl: 0.0000e+00 - val_mmd: 16.5085
# Epoch 28/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 12.0170 - recon: 0.6062 - kl: 0.0000e+00 - mmd: 11.4207 - val_loss: 17.7628 - val_recon: 0.5641 - val_kl: 0.0000e+00 - val_mmd: 16.8905
# Epoch 29/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 11.9532 - recon: 0.6027 - kl: 0.0000e+00 - mmd: 11.3655 - val_loss: 20.3561 - val_recon: 0.5564 - val_kl: 0.0000e+00 - val_mmd: 19.9588
# Epoch 30/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 12.0320 - recon: 0.5971 - kl: 0.0000e+00 - mmd: 11.3520 - val_loss: 17.9592 - val_recon: 0.5578 - val_kl: 0.0000e+00 - val_mmd: 17.2493
# Epoch 31/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 11.7848 - recon: 0.5906 - kl: 0.0000e+00 - mmd: 11.4062 - val_loss: 18.8915 - val_recon: 0.5570 - val_kl: 0.0000e+00 - val_mmd: 18.1948
# Epoch 32/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 11.8078 - recon: 0.5887 - kl: 0.0000e+00 - mmd: 11.3700 - val_loss: 19.1014 - val_recon: 0.5456 - val_kl: 0.0000e+00 - val_mmd: 18.6188
# Epoch 33/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 11.8354 - recon: 0.5832 - kl: 0.0000e+00 - mmd: 11.1528 - val_loss: 16.5022 - val_recon: 0.5405 - val_kl: 0.0000e+00 - val_mmd: 15.8370
# Epoch 34/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 11.7690 - recon: 0.5790 - kl: 0.0000e+00 - mmd: 11.1601 - val_loss: 18.9931 - val_recon: 0.5395 - val_kl: 0.0000e+00 - val_mmd: 18.1851
# Epoch 35/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 11.6147 - recon: 0.5776 - kl: 0.0000e+00 - mmd: 11.0943 - val_loss: 20.8382 - val_recon: 0.5364 - val_kl: 0.0000e+00 - val_mmd: 20.2559
# Epoch 36/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 11.5522 - recon: 0.5738 - kl: 0.0000e+00 - mmd: 11.0332 - val_loss: 16.3279 - val_recon: 0.5340 - val_kl: 0.0000e+00 - val_mmd: 15.6579
# Epoch 37/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 11.5972 - recon: 0.5718 - kl: 0.0000e+00 - mmd: 11.0238 - val_loss: 22.2192 - val_recon: 0.5500 - val_kl: 0.0000e+00 - val_mmd: 21.6612
# Epoch 38/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 11.5779 - recon: 0.5672 - kl: 0.0000e+00 - mmd: 10.9426 - val_loss: 16.4355 - val_recon: 0.5324 - val_kl: 0.0000e+00 - val_mmd: 15.8462
# Epoch 39/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 11.4235 - recon: 0.5650 - kl: 0.0000e+00 - mmd: 10.8450 - val_loss: 15.6206 - val_recon: 0.5242 - val_kl: 0.0000e+00 - val_mmd: 15.2023
# Epoch 40/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 11.4481 - recon: 0.5604 - kl: 0.0000e+00 - mmd: 10.8485 - val_loss: 16.4255 - val_recon: 0.5213 - val_kl: 0.0000e+00 - val_mmd: 15.7641
# Epoch 41/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 11.3143 - recon: 0.5579 - kl: 0.0000e+00 - mmd: 10.7218 - val_loss: 14.4330 - val_recon: 0.5161 - val_kl: 0.0000e+00 - val_mmd: 14.1774
# Epoch 42/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 11.3015 - recon: 0.5527 - kl: 0.0000e+00 - mmd: 10.7390 - val_loss: 18.2599 - val_recon: 0.5144 - val_kl: 0.0000e+00 - val_mmd: 17.4880
# Epoch 43/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 11.2966 - recon: 0.5509 - kl: 0.0000e+00 - mmd: 10.6978 - val_loss: 17.1249 - val_recon: 0.5135 - val_kl: 0.0000e+00 - val_mmd: 16.6290
# Epoch 44/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 11.1405 - recon: 0.5460 - kl: 0.0000e+00 - mmd: 10.6111 - val_loss: 15.3470 - val_recon: 0.5146 - val_kl: 0.0000e+00 - val_mmd: 14.6935
# Epoch 45/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 10.9911 - recon: 0.5445 - kl: 0.0000e+00 - mmd: 10.4966 - val_loss: 14.6646 - val_recon: 0.5127 - val_kl: 0.0000e+00 - val_mmd: 14.0959
# Epoch 46/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 11.1775 - recon: 0.5413 - kl: 0.0000e+00 - mmd: 10.5597 - val_loss: 14.3011 - val_recon: 0.5184 - val_kl: 0.0000e+00 - val_mmd: 14.0935
# Epoch 47/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 11.0505 - recon: 0.5400 - kl: 0.0000e+00 - mmd: 10.5391 - val_loss: 15.3341 - val_recon: 0.5098 - val_kl: 0.0000e+00 - val_mmd: 14.9982
# Epoch 48/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 11.0105 - recon: 0.5380 - kl: 0.0000e+00 - mmd: 10.4693 - val_loss: 15.9993 - val_recon: 0.5049 - val_kl: 0.0000e+00 - val_mmd: 15.5528
# Epoch 49/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 10.9375 - recon: 0.5355 - kl: 0.0000e+00 - mmd: 10.3687 - val_loss: 16.2676 - val_recon: 0.5047 - val_kl: 0.0000e+00 - val_mmd: 15.9239
# Epoch 50/50
# 1234/1234 [==============================] - 6s 5ms/step - loss: 10.9091 - recon: 0.5324 - kl: 0.0000e+00 - mmd: 10.3183 - val_loss: 17.6683 - val_recon: 0.5061 - val_kl: 0.0000e+00 - val_mmd: 17.2685

# %%
cp_vae.vae

# %%
# Save training performance
history_df = pd.DataFrame(cp_vae.vae.history.history)
history_df
# Out:
#          loss      recon   kl        mmd   val_loss  val_recon  val_kl  \
# 0   74.863663  56.383678  0.0  18.420048  39.318588  12.575617     0.0
# 1   23.334579   7.570421  0.0  15.975617  24.114958   5.507032     0.0
# 2   19.221558   4.461895  0.0  14.802872  37.125950   4.765013     0.0
# 3   17.180372   3.033413  0.0  14.120376  32.242188   2.638580     0.0
# 4   15.898522   2.171108  0.0  13.707837  23.951651   1.951921     0.0
# 5   15.234391   1.630502  0.0  13.548157  26.980156   1.473006     0.0
# 6   14.757110   1.308802  0.0  13.371398  23.555387   1.207477     0.0
# 7   14.402693   1.109632  0.0  13.250370  27.721931   1.053477     0.0
# 8   14.067601   0.977579  0.0  13.182675  30.014460   0.937918     0.0
# 9   14.051779   0.901837  0.0  13.106303  32.121037   0.836444     0.0
# 10  13.713290   0.842474  0.0  12.900305  24.164003   0.758155     0.0
# 11  13.713178   0.802479  0.0  12.840920  33.155697   0.737806     0.0
# 12  13.499480   0.772656  0.0  12.822998  23.592815   0.708521     0.0
# 13  13.465622   0.752190  0.0  12.604036  24.602537   0.703249     0.0
# 14  13.247313   0.730961  0.0  12.472520  21.596142   0.662584     0.0
# 15  13.064538   0.712417  0.0  12.385996  21.182209   0.639052     0.0
# 16  12.989850   0.697187  0.0  12.308044  22.898464   0.639023     0.0
# 17  12.811316   0.680093  0.0  12.284884  19.748695   0.620941     0.0
# 18  12.838857   0.669171  0.0  12.160336  20.405354   0.603373     0.0
# 19  12.759196   0.659736  0.0  12.087065  25.250702   0.615834     0.0
# 20  12.647817   0.650774  0.0  12.028816  20.668154   0.597562     0.0
# 21  12.596972   0.641378  0.0  12.048882  17.648556   0.589483     0.0
# 22  12.488384   0.634599  0.0  11.895728  21.930918   0.586432     0.0
# 23  12.483671   0.630822  0.0  11.798517  19.670465   0.576370     0.0
# 24  12.365849   0.618528  0.0  11.778385  26.326384   0.592177     0.0
# 25  12.264295   0.615955  0.0  11.626840  22.148878   0.568424     0.0
# 26  12.165095   0.612486  0.0  11.614381  17.615541   0.564955     0.0
# 27  12.057256   0.606180  0.0  11.420697  17.762777   0.564127     0.0
# 28  11.996856   0.602740  0.0  11.365506  20.356102   0.556416     0.0
# 29  11.960091   0.597057  0.0  11.351996  17.959221   0.557799     0.0
# 30  11.887204   0.590575  0.0  11.406203  18.891472   0.557049     0.0
# 31  11.877678   0.588670  0.0  11.369957  19.101442   0.545555     0.0
# 32  11.830996   0.583240  0.0  11.152771  16.502230   0.540528     0.0
# 33  11.614733   0.579040  0.0  11.160147  18.993149   0.539543     0.0
# 34  11.618712   0.577601  0.0  11.094254  20.838161   0.536412     0.0
# 35  11.547133   0.573820  0.0  11.033182  16.327946   0.533965     0.0
# 36  11.588076   0.571797  0.0  11.023840  22.219210   0.550029     0.0
# 37  11.537999   0.567217  0.0  10.942595  16.435530   0.532439     0.0
# 38  11.426112   0.564971  0.0  10.844975  15.620569   0.524239     0.0
# 39  11.394621   0.560405  0.0  10.848524  16.425451   0.521330     0.0
# 40  11.335004   0.557890  0.0  10.721763  14.433022   0.516124     0.0
# 41  11.263408   0.552744  0.0  10.738996  18.259918   0.514436     0.0
# 42  11.278672   0.550949  0.0  10.697755  17.124882   0.513519     0.0
# 43  11.092880   0.546005  0.0  10.611076  15.346977   0.514634     0.0
# 44  11.043202   0.544472  0.0  10.496553  14.664571   0.512747     0.0
# 45  11.092697   0.541350  0.0  10.559703  14.301115   0.518411     0.0
# 46  11.045910   0.540009  0.0  10.539098  15.334096   0.509837     0.0
# 47  11.006393   0.538011  0.0  10.469330  15.999311   0.504905     0.0
# 48  10.916415   0.535494  0.0  10.368719  16.267572   0.504651     0.0
# 49  10.923532   0.532443  0.0  10.318336  17.668299   0.506108     0.0
#
#       val_mmd
# 0   27.277248
# 1   18.650755
# 2   32.184040
# 3   29.264250
# 4   22.148098
# 5   25.893681
# 6   21.859282
# 7   26.725868
# 8   29.223497
# 9   31.330608
# 10  23.455217
# 11  31.879322
# 12  22.740746
# 13  24.104271
# 14  21.392010
# 15  20.851051
# 16  22.628107
# 17  19.388174
# 18  19.644566
# 19  24.111515
# 20  20.246515
# 21  17.052742
# 22  21.474001
# 23  18.912354
# 24  25.663366
# 25  21.434668
# 26  16.508507
# 27  16.890490
# 28  19.958792
# 29  17.249281
# 30  18.194811
# 31  18.618752
# 32  15.837034
# 33  18.185116
# 34  20.255909
# 35  15.657921
# 36  21.661175
# 37  15.846241
# 38  15.202273
# 39  15.764071
# 40  14.177416
# 41  17.487986
# 42  16.629032
# 43  14.693472
# 44  14.095925
# 45  14.093542
# 46  14.998183
# 47  15.552785
# 48  15.923924
# 49  17.268496

# %%
history_df.to_csv('training_data/level4_training_mmd_leaveOut.csv')

# %%
plt.figure(figsize=(10, 5))
plt.plot(history_df["loss"], label="Training data")
plt.plot(history_df["val_loss"], label="Validation data")
plt.title("Loss for VAE training on Cell Painting Level 4 data")
plt.ylabel("MSE + MMD")
plt.xlabel("No. Epoch")
plt.legend()
plt.show()

# %%
cp_vae.vae.evaluate(test_features_df)
# Out:
# 158/158 [==============================] - 0s 2ms/step - loss: 17.5727 - recon: 0.5121 - kl: 0.0000e+00 - mmd: 17.4159
# [17.572721481323242, 0.5121245384216309, 0.0, 17.41594123840332]

# %%
reconstruction = pd.DataFrame(cp_vae.vae.predict(test_features_df), columns=cp_features)
(sum(sum((np.array(test_features_df) - np.array(reconstruction)) ** 2))) ** 0.5
# Out:
# 50.73478833415922

# %%
#latent space heatmap
fig, ax = plt.subplots(figsize=(10, 10))
encoder = cp_vae.encoder_block["encoder"]
latent = np.array(encoder.predict(test_features_df)[2])
seaborn.heatmap(latent, ax=ax)
# Out:
# <AxesSubplot:>

# %%
reconstruction = pd.DataFrame(cp_vae.vae.predict(test_features_df), columns=cp_features)
pca = PCA(n_components=2).fit(test_features_df)
pca_reconstructed_latent_df = pd.DataFrame(pca.transform(reconstruction))
pca_test_latent_df = pd.DataFrame(pca.transform(test_features_df))

# %%
figure(figsize=(10, 10), dpi=80)
plt.scatter(pca_test_latent_df[0],pca_test_latent_df[1], marker = ".", alpha = 0.5)
plt.scatter(pca_reconstructed_latent_df[0],pca_reconstructed_latent_df[1], marker = ".", alpha = 0.5)

# %%
decoder = cp_vae.decoder_block["decoder"]

# %%
pca_training = PCA(n_components=2).fit(train_features_df)

simulated_df = pd.DataFrame(np.random.normal(size=(40242, 90)), columns=np.arange(0,90))
reconstruction_of_simulated = decoder.predict(simulated_df)
pca_reconstruction_of_simulated = pd.DataFrame(pca_training.transform(reconstruction_of_simulated))
pca_train_latent_df = pd.DataFrame(pca_training.transform(train_features_df))

fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(16,8), sharey = True, sharex = True)
ax1.scatter(pca_train_latent_df[0],pca_train_latent_df[1], marker = ".", alpha = 0.5)
ax2.scatter(pca_reconstruction_of_simulated[0],pca_reconstruction_of_simulated[1], marker = ".", alpha = 0.5)

# %%
from scipy.spatial.distance import directed_hausdorff
max(directed_hausdorff(reconstruction_of_simulated, train_features_df)[0],directed_hausdorff(train_features_df,reconstruction_of_simulated)[0])
# Out:
# 8.876286746699929

# %%
#NOTE: IF YOU RUN THIS, YOU WILL NOT BE ABLE TO REPRODUCE THE EXACT RESULTS IN THE EXPERIMENT
latent_complete = np.array(encoder.predict(complete_features_df)[2])
latent_df = pd.DataFrame(latent)
latent_df.to_csv("../3.application/level4Latent_mmd_leaveOut.csv")

# %%
#NOTE: IF YOU RUN THIS, YOU WILL NOT BE ABLE TO REPRODUCE THE EXACT RESULTS IN THE EXPERIMENT
decoder.save("models/level4Decoder_mmd_leaveOut")
# Out:
# INFO:tensorflow:Assets written to: level4Decoder_mmd_leaveOut/assets

# %%
encoder.save("models/level4Encoder_mmd_leaveOut")
# Out:
# INFO:tensorflow:Assets written to: level4Encoder_mmd_leaveOut/assets
