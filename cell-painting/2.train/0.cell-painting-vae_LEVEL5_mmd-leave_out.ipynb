# %% [markdown]
# # Train a VAE on Cell Painting LINCS Data

# %%
import sys
import pathlib
import numpy as np
import pandas as pd
sys.path.insert(0, "../../scripts")
from utils import load_data


from pycytominer.cyto_utils import infer_cp_features


import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

from sklearn.decomposition import PCA
from tensorflow import keras

from vae import VAE

from tensorflow.keras.models import Model, Sequential
import seaborn
import random as python_random
import tensorflow as tf
import umap

# %%
# %load_ext nb_black

# %%
# np.random.seed(123)
# python_random.seed(123)
# tf.random.set_random_seed(1234)

# %%
data_splits = ["train", "test", "valid", "complete"]
data_dict = load_data(data_splits)

# %%
def remove_moa(df):
    pipes = ['EGFR inhibitor|protein tyrosine kinase inhibitor',
             'cyclooxygenase inhibitor|prostanoid receptor',
             'aromatase inhibitor|TRPV antagonist',
             'DNA synthesis inhibitor|thymidylate synthase inhibitor',
            'apoptosis stimulant|ribonucleotide reductase inhibitor']    
    moas =  []
    for pipe in pipes:
        moas.append(pipe)
        moas.append(pipe.split('|')[0])
        moas.append(pipe.split('|')[1])
    return df[~df.moa.isin(moas)]

# %%
# Prepare data for training
meta_features = infer_cp_features(data_dict["train"], metadata=True)
cp_features = infer_cp_features(data_dict["train"])

moa_df_train = pd.read_csv("../3.application/repurposing_info_external_moa_map_resolved.tsv",sep='\t').set_index('broad_sample').reindex(index=data_dict['train']['Metadata_broad_sample']).reset_index().drop('Metadata_broad_sample',axis = 1)
data_dict['train'] = pd.concat([moa_df_train,data_dict['train']], axis=1)

moa_df_valid = pd.read_csv("../3.application/repurposing_info_external_moa_map_resolved.tsv",sep='\t').set_index('broad_sample').reindex(index=data_dict['valid']['Metadata_broad_sample']).reset_index().drop('Metadata_broad_sample',axis = 1)
data_dict['valid'] = pd.concat([moa_df_valid,data_dict['valid']], axis=1)

data_dict['train'] = remove_moa(data_dict['train'])
data_dict['valid'] = remove_moa(data_dict['valid'])

train_features_df = data_dict["train"].reindex(cp_features, axis="columns")
train_meta_df = data_dict["train"].reindex(meta_features, axis="columns")

test_features_df = data_dict["test"].reindex(cp_features, axis="columns")
test_meta_df = data_dict["test"].reindex(meta_features, axis="columns")

valid_features_df = data_dict["valid"].reindex(cp_features, axis="columns")
valid_meta_df = data_dict["valid"].reindex(meta_features, axis="columns")

complete_features_df = data_dict["complete"].reindex(cp_features, axis="columns")
complete_meta_df = data_dict["complete"].reindex(meta_features, axis="columns")

# %%
print(train_features_df.shape)
train_features_df.head(3)
# Out:
# (7961, 588)
#    Cells_AreaShape_FormFactor  Cells_AreaShape_Orientation  \
# 0                     0.56071                      0.63708
# 1                     0.59702                      0.55453
# 2                     0.64623                      0.59825
#
#    Cells_AreaShape_Zernike_2_2  Cells_AreaShape_Zernike_3_1  \
# 0                      0.57961                      0.51030
# 1                      0.62561                      0.47959
# 2                      0.62822                      0.52100
#
#    Cells_AreaShape_Zernike_5_1  Cells_AreaShape_Zernike_6_2  \
# 0                      0.61695                      0.30869
# 1                      0.59022                      0.33269
# 2                      0.57452                      0.26367
#
#    Cells_AreaShape_Zernike_7_1  Cells_AreaShape_Zernike_7_7  \
# 0                      0.43981                      0.79826
# 1                      0.49875                      0.88042
# 2                      0.48172                      0.86322
#
#    Cells_AreaShape_Zernike_9_3  Cells_Correlation_Correlation_DNA_AGP  ...  \
# 0                      0.72477                                0.68589  ...
# 1                      0.67159                                0.61703  ...
# 2                      0.67588                                0.69732  ...
#
#    Nuclei_Texture_SumAverage_AGP_5_0  Nuclei_Texture_SumEntropy_AGP_10_0  \
# 0                            0.17858                             0.29336
# 1                            0.09030                             0.15088
# 2                            0.18125                             0.23244
#
#    Nuclei_Texture_SumEntropy_AGP_20_0  Nuclei_Texture_SumEntropy_AGP_5_0  \
# 0                             0.26447                            0.30197
# 1                             0.13334                            0.14052
# 2                             0.20723                            0.24062
#
#    Nuclei_Texture_SumEntropy_DNA_10_0  Nuclei_Texture_SumEntropy_DNA_20_0  \
# 0                             0.64786                             0.49525
# 1                             0.59229                             0.49294
# 2                             0.54642                             0.43920
#
#    Nuclei_Texture_SumEntropy_Mito_5_0  Nuclei_Texture_SumVariance_DNA_5_0  \
# 0                             0.53512                             0.40495
# 1                             0.43221                             0.33969
# 2                             0.41183                             0.30375
#
#    Nuclei_Texture_Variance_DNA_20_0  Nuclei_Texture_Variance_DNA_5_0
# 0                           0.46056                          0.43647
# 1                           0.39208                          0.36205
# 2                           0.35385                          0.33266
#
# [3 rows x 588 columns]

# %%
print(test_features_df.shape)
test_features_df.head(3)
# Out:
# (1037, 588)
#    Cells_AreaShape_FormFactor  Cells_AreaShape_Orientation  \
# 0                     0.52664                      0.59293
# 1                     0.61343                      0.57882
# 2                     0.55123                      0.61050
#
#    Cells_AreaShape_Zernike_2_2  Cells_AreaShape_Zernike_3_1  \
# 0                      0.51636                      0.52824
# 1                      0.62454                      0.51049
# 2                      0.53085                      0.65280
#
#    Cells_AreaShape_Zernike_5_1  Cells_AreaShape_Zernike_6_2  \
# 0                      0.54415                      0.23948
# 1                      0.57508                      0.31691
# 2                      0.54356                      0.16767
#
#    Cells_AreaShape_Zernike_7_1  Cells_AreaShape_Zernike_7_7  \
# 0                      0.53361                      0.84625
# 1                      0.49077                      0.89145
# 2                      0.50521                      0.93703
#
#    Cells_AreaShape_Zernike_9_3  Cells_Correlation_Correlation_DNA_AGP  ...  \
# 0                      0.65881                                0.86971  ...
# 1                      0.65811                                0.66082  ...
# 2                      0.77958                                0.63413  ...
#
#    Nuclei_Texture_SumAverage_AGP_5_0  Nuclei_Texture_SumEntropy_AGP_10_0  \
# 0                            0.74413                             0.58353
# 1                            0.12499                             0.20488
# 2                            0.19249                             0.13665
#
#    Nuclei_Texture_SumEntropy_AGP_20_0  Nuclei_Texture_SumEntropy_AGP_5_0  \
# 0                             0.54654                            0.63600
# 1                             0.18676                            0.20580
# 2                             0.13293                            0.13816
#
#    Nuclei_Texture_SumEntropy_DNA_10_0  Nuclei_Texture_SumEntropy_DNA_20_0  \
# 0                             0.50501                             0.39338
# 1                             0.58773                             0.47783
# 2                             0.58333                             0.52931
#
#    Nuclei_Texture_SumEntropy_Mito_5_0  Nuclei_Texture_SumVariance_DNA_5_0  \
# 0                             0.46080                             0.25924
# 1                             0.42619                             0.34683
# 2                             0.31068                             0.40967
#
#    Nuclei_Texture_Variance_DNA_20_0  Nuclei_Texture_Variance_DNA_5_0
# 0                           0.29724                          0.27556
# 1                           0.39642                          0.37092
# 2                           0.48646                          0.45058
#
# [3 rows x 588 columns]

# %%
print(complete_features_df.shape)
complete_features_df.head(3)
# Out:
# (10368, 588)
#    Cells_AreaShape_FormFactor  Cells_AreaShape_Orientation  \
# 0                     0.57016                      0.59500
# 1                     0.54840                      0.53949
# 2                     0.56057                      0.59621
#
#    Cells_AreaShape_Zernike_2_2  Cells_AreaShape_Zernike_3_1  \
# 0                      0.57370                      0.50690
# 1                      0.58096                      0.53694
# 2                      0.59116                      0.50418
#
#    Cells_AreaShape_Zernike_5_1  Cells_AreaShape_Zernike_6_2  \
# 0                      0.56160                      0.27321
# 1                      0.55009                      0.28114
# 2                      0.55679                      0.29305
#
#    Cells_AreaShape_Zernike_7_1  Cells_AreaShape_Zernike_7_7  \
# 0                      0.45448                      0.83747
# 1                      0.53594                      0.86929
# 2                      0.49221                      0.87813
#
#    Cells_AreaShape_Zernike_9_3  Cells_Correlation_Correlation_DNA_AGP  ...  \
# 0                      0.68635                                0.68973  ...
# 1                      0.66026                                0.71317  ...
# 2                      0.71747                                0.72229  ...
#
#    Nuclei_Texture_SumAverage_AGP_5_0  Nuclei_Texture_SumEntropy_AGP_10_0  \
# 0                            0.16426                             0.22701
# 1                            0.18411                             0.23932
# 2                            0.17564                             0.23366
#
#    Nuclei_Texture_SumEntropy_AGP_20_0  Nuclei_Texture_SumEntropy_AGP_5_0  \
# 0                             0.20854                            0.22897
# 1                             0.21854                            0.24763
# 2                             0.21743                            0.23448
#
#    Nuclei_Texture_SumEntropy_DNA_10_0  Nuclei_Texture_SumEntropy_DNA_20_0  \
# 0                             0.53738                             0.43547
# 1                             0.56995                             0.47084
# 2                             0.56980                             0.47254
#
#    Nuclei_Texture_SumEntropy_Mito_5_0  Nuclei_Texture_SumVariance_DNA_5_0  \
# 0                             0.41635                             0.28933
# 1                             0.37764                             0.32148
# 2                             0.39575                             0.31969
#
#    Nuclei_Texture_Variance_DNA_20_0  Nuclei_Texture_Variance_DNA_5_0
# 0                           0.34017                          0.31368
# 1                           0.36964                          0.34328
# 2                           0.36626                          0.34086
#
# [3 rows x 588 columns]

# %%
# VAE of one layer
encoder_architecture = [250]
decoder_architecture = [250]

# %%
# model from optimal hyperparameters for onelayer obtained from 1.optimize
cp_vae = VAE(
    input_dim=train_features_df.shape[1],
    latent_dim=10,
    batch_size=96,
    encoder_batch_norm=True,
    epochs=30,
    learning_rate=0.001,
    encoder_architecture=encoder_architecture,
    decoder_architecture=decoder_architecture,
    beta=0,
    lam=1000,
    verbose=True,
)
#100000
#10000
#200 ep 1000000 results in 1.20
cp_vae.compile_vae()

# %%
cp_vae.train(x_train=train_features_df, x_test=valid_features_df)
# Out:
# Epoch 1/30
# 83/83 [==============================] - 4s 17ms/step - loss: 80.3286 - recon: 30.7550 - kl: 0.0000e+00 - mmd: 11.5791 - val_loss: 44.5638 - val_recon: 12.7566 - val_kl: 0.0000e+00 - val_mmd: 30.1584
# Epoch 2/30
# 83/83 [==============================] - 0s 6ms/step - loss: 17.0356 - recon: 8.1249 - kl: 0.0000e+00 - mmd: 6.9009 - val_loss: 51.7024 - val_recon: 9.1511 - val_kl: 0.0000e+00 - val_mmd: 45.5026
# Epoch 3/30
# 83/83 [==============================] - 0s 6ms/step - loss: 12.2032 - recon: 6.3632 - kl: 0.0000e+00 - mmd: 5.1322 - val_loss: 29.5038 - val_recon: 6.4826 - val_kl: 0.0000e+00 - val_mmd: 24.1827
# Epoch 4/30
# 83/83 [==============================] - 0s 6ms/step - loss: 9.9519 - recon: 5.4022 - kl: 0.0000e+00 - mmd: 4.3118 - val_loss: 30.5950 - val_recon: 5.7874 - val_kl: 0.0000e+00 - val_mmd: 23.2930
# Epoch 5/30
# 83/83 [==============================] - 0s 6ms/step - loss: 8.5374 - recon: 4.6813 - kl: 0.0000e+00 - mmd: 4.2753 - val_loss: 19.7993 - val_recon: 4.1329 - val_kl: 0.0000e+00 - val_mmd: 16.4397
# Epoch 6/30
# 83/83 [==============================] - 0s 6ms/step - loss: 8.4050 - recon: 4.3114 - kl: 0.0000e+00 - mmd: 3.9025 - val_loss: 19.2957 - val_recon: 3.9346 - val_kl: 0.0000e+00 - val_mmd: 14.5358
# Epoch 7/30
# 83/83 [==============================] - 0s 6ms/step - loss: 7.6841 - recon: 4.0680 - kl: 0.0000e+00 - mmd: 3.7344 - val_loss: 25.6816 - val_recon: 3.8652 - val_kl: 0.0000e+00 - val_mmd: 24.0400
# Epoch 8/30
# 83/83 [==============================] - 0s 6ms/step - loss: 7.8918 - recon: 3.9224 - kl: 0.0000e+00 - mmd: 3.8074 - val_loss: 10.4265 - val_recon: 3.6575 - val_kl: 0.0000e+00 - val_mmd: 8.0327
# Epoch 9/30
# 83/83 [==============================] - 0s 6ms/step - loss: 8.0956 - recon: 3.8644 - kl: 0.0000e+00 - mmd: 4.0576 - val_loss: 10.3937 - val_recon: 3.7940 - val_kl: 0.0000e+00 - val_mmd: 7.9119
# Epoch 10/30
# 83/83 [==============================] - 0s 6ms/step - loss: 8.1723 - recon: 3.8946 - kl: 0.0000e+00 - mmd: 3.9169 - val_loss: 21.4042 - val_recon: 3.6371 - val_kl: 0.0000e+00 - val_mmd: 17.0855
# Epoch 11/30
# 83/83 [==============================] - 0s 6ms/step - loss: 7.1043 - recon: 3.7337 - kl: 0.0000e+00 - mmd: 3.6621 - val_loss: 8.8791 - val_recon: 3.4978 - val_kl: 0.0000e+00 - val_mmd: 6.8609
# Epoch 12/30
# 83/83 [==============================] - 0s 6ms/step - loss: 7.6090 - recon: 3.7542 - kl: 0.0000e+00 - mmd: 3.9300 - val_loss: 10.8318 - val_recon: 3.5312 - val_kl: 0.0000e+00 - val_mmd: 6.7298
# Epoch 13/30
# 83/83 [==============================] - 0s 5ms/step - loss: 7.7744 - recon: 3.7152 - kl: 0.0000e+00 - mmd: 4.1438 - val_loss: 12.0867 - val_recon: 3.5253 - val_kl: 0.0000e+00 - val_mmd: 9.2655
# Epoch 14/30
# 83/83 [==============================] - 0s 6ms/step - loss: 7.7792 - recon: 3.6868 - kl: 0.0000e+00 - mmd: 3.6104 - val_loss: 9.8144 - val_recon: 3.2848 - val_kl: 0.0000e+00 - val_mmd: 6.4192
# Epoch 15/30
# 83/83 [==============================] - 0s 6ms/step - loss: 7.2680 - recon: 3.6192 - kl: 0.0000e+00 - mmd: 3.8636 - val_loss: 8.1813 - val_recon: 3.5176 - val_kl: 0.0000e+00 - val_mmd: 6.9879
# Epoch 16/30
# 83/83 [==============================] - 0s 6ms/step - loss: 7.6115 - recon: 3.5321 - kl: 0.0000e+00 - mmd: 3.8250 - val_loss: 7.9067 - val_recon: 3.4017 - val_kl: 0.0000e+00 - val_mmd: 4.0431
# Epoch 17/30
# 83/83 [==============================] - 0s 6ms/step - loss: 7.1518 - recon: 3.5204 - kl: 0.0000e+00 - mmd: 3.6507 - val_loss: 8.3185 - val_recon: 3.3245 - val_kl: 0.0000e+00 - val_mmd: 5.9158
# Epoch 18/30
# 83/83 [==============================] - 0s 6ms/step - loss: 7.3025 - recon: 3.5302 - kl: 0.0000e+00 - mmd: 3.6156 - val_loss: 9.2448 - val_recon: 3.3864 - val_kl: 0.0000e+00 - val_mmd: 6.5927
# Epoch 19/30
# 83/83 [==============================] - 0s 6ms/step - loss: 6.9699 - recon: 3.4541 - kl: 0.0000e+00 - mmd: 3.6644 - val_loss: 8.5402 - val_recon: 3.3196 - val_kl: 0.0000e+00 - val_mmd: 4.7962
# Epoch 20/30
# 83/83 [==============================] - 0s 6ms/step - loss: 6.9853 - recon: 3.3676 - kl: 0.0000e+00 - mmd: 3.5065 - val_loss: 7.3772 - val_recon: 3.2935 - val_kl: 0.0000e+00 - val_mmd: 4.9149
# Epoch 21/30
# 83/83 [==============================] - 0s 6ms/step - loss: 6.9452 - recon: 3.4559 - kl: 0.0000e+00 - mmd: 3.7843 - val_loss: 8.1619 - val_recon: 3.2222 - val_kl: 0.0000e+00 - val_mmd: 4.6687
# Epoch 22/30
# 83/83 [==============================] - 0s 6ms/step - loss: 7.1902 - recon: 3.4163 - kl: 0.0000e+00 - mmd: 3.6137 - val_loss: 10.2694 - val_recon: 3.1217 - val_kl: 0.0000e+00 - val_mmd: 8.1916
# Epoch 23/30
# 83/83 [==============================] - 0s 6ms/step - loss: 6.8801 - recon: 3.3913 - kl: 0.0000e+00 - mmd: 3.7621 - val_loss: 19.5354 - val_recon: 3.0248 - val_kl: 0.0000e+00 - val_mmd: 17.3575
# Epoch 24/30
# 83/83 [==============================] - 0s 6ms/step - loss: 7.1446 - recon: 3.3592 - kl: 0.0000e+00 - mmd: 3.4359 - val_loss: 9.6760 - val_recon: 3.0195 - val_kl: 0.0000e+00 - val_mmd: 7.3234
# Epoch 25/30
# 83/83 [==============================] - 0s 6ms/step - loss: 6.3579 - recon: 3.2675 - kl: 0.0000e+00 - mmd: 3.2091 - val_loss: 9.5488 - val_recon: 3.2184 - val_kl: 0.0000e+00 - val_mmd: 8.4051
# Epoch 26/30
# 83/83 [==============================] - 0s 6ms/step - loss: 6.5704 - recon: 3.2934 - kl: 0.0000e+00 - mmd: 3.6224 - val_loss: 8.5054 - val_recon: 3.1657 - val_kl: 0.0000e+00 - val_mmd: 5.5315
# Epoch 27/30
# 83/83 [==============================] - 0s 6ms/step - loss: 7.1894 - recon: 3.2411 - kl: 0.0000e+00 - mmd: 3.4563 - val_loss: 8.9061 - val_recon: 3.1545 - val_kl: 0.0000e+00 - val_mmd: 6.2233
# Epoch 28/30
# 83/83 [==============================] - 0s 6ms/step - loss: 6.8791 - recon: 3.2205 - kl: 0.0000e+00 - mmd: 3.6426 - val_loss: 7.1157 - val_recon: 3.0048 - val_kl: 0.0000e+00 - val_mmd: 5.8630
# Epoch 29/30
# 83/83 [==============================] - 0s 6ms/step - loss: 6.6903 - recon: 3.2261 - kl: 0.0000e+00 - mmd: 3.4194 - val_loss: 8.9932 - val_recon: 3.0520 - val_kl: 0.0000e+00 - val_mmd: 4.7114
# Epoch 30/30
# 83/83 [==============================] - 0s 6ms/step - loss: 6.7966 - recon: 3.1896 - kl: 0.0000e+00 - mmd: 3.3579 - val_loss: 7.7141 - val_recon: 2.9308 - val_kl: 0.0000e+00 - val_mmd: 7.7600

# %%
cp_vae.vae

# %%
# cp_vae.vae.evaluate(test_features_df)

# %%
# Save training performance
history_df = pd.DataFrame(cp_vae.vae.history.history)
history_df
# Out:
#          loss      recon   kl        mmd   val_loss  val_recon  val_kl  \
# 0   42.147285  30.755041  0.0  11.579074  44.563797  12.756624     0.0
# 1   15.204253   8.124857  0.0   6.900898  51.702374   9.151106     0.0
# 2   11.394036   6.363245  0.0   5.132244  29.503759   6.482577     0.0
# 3    9.836094   5.402174  0.0   4.311791  30.594952   5.787410     0.0
# 4    8.888240   4.681338  0.0   4.275317  19.799259   4.132949     0.0
# 5    8.354700   4.311398  0.0   3.902535  19.295710   3.934570     0.0
# 6    7.787882   4.068022  0.0   3.734396  25.681631   3.865150     0.0
# 7    7.648081   3.922436  0.0   3.807351  10.426530   3.657510     0.0
# 8    8.087871   3.864417  0.0   4.057618  10.393656   3.793966     0.0
# 9    7.885864   3.894584  0.0   3.916855  21.404190   3.637060     0.0
# 10   7.403133   3.733715  0.0   3.662127   8.879087   3.497792     0.0
# 11   7.417059   3.754215  0.0   3.930036  10.831775   3.531190     0.0
# 12   7.632691   3.715157  0.0   4.143761  12.086667   3.525302     0.0
# 13   7.644550   3.686829  0.0   3.610424   9.814445   3.284833     0.0
# 14   7.349600   3.619230  0.0   3.863637   8.181346   3.517610     0.0
# 15   7.602018   3.532137  0.0   3.825013   7.906721   3.401685     0.0
# 16   7.253582   3.520438  0.0   3.650677   8.318473   3.324484     0.0
# 17   7.420139   3.530215  0.0   3.615577   9.244803   3.386413     0.0
# 18   7.187267   3.454130  0.0   3.664403   8.540214   3.319582     0.0
# 19   6.879731   3.367612  0.0   3.506474   7.377201   3.293494     0.0
# 20   7.172760   3.455881  0.0   3.784328   8.161862   3.222241     0.0
# 21   7.022264   3.416308  0.0   3.613719  10.269368   3.121683     0.0
# 22   6.997400   3.391344  0.0   3.762120  19.535398   3.024827     0.0
# 23   7.045812   3.359231  0.0   3.435904   9.675965   3.019503     0.0
# 24   6.519632   3.267535  0.0   3.209113   9.548767   3.218371     0.0
# 25   6.586625   3.293387  0.0   3.622444   8.505360   3.165744     0.0
# 26   6.940580   3.241068  0.0   3.456308   8.906100   3.154489     0.0
# 27   6.954885   3.220550  0.0   3.642599   7.115733   3.004792     0.0
# 28   6.587243   3.226086  0.0   3.419366   8.993207   3.052033     0.0
# 29   6.673457   3.189557  0.0   3.357886   7.714057   2.930788     0.0
#
#       val_mmd
# 0   30.158400
# 1   45.502617
# 2   24.182709
# 3   23.292986
# 4   16.439730
# 5   14.535816
# 6   24.039972
# 7    8.032680
# 8    7.911876
# 9   17.085451
# 10   6.860886
# 11   6.729754
# 12   9.265466
# 13   6.419237
# 14   6.987940
# 15   4.043080
# 16   5.915815
# 17   6.592740
# 18   4.796180
# 19   4.914945
# 20   4.668691
# 21   8.191564
# 22  17.357546
# 23   7.323363
# 24   8.405068
# 25   5.531463
# 26   6.223299
# 27   5.863005
# 28   4.711444
# 29   7.759993

# %%
history_df.to_csv('level5_training_mmd_leaveOut.csv')

# %%
# history_df = pd.read_csv('level5_training.csv')

# %%
plt.figure(figsize=(10, 5))
plt.plot(history_df["loss"], label="Training data")
plt.plot(history_df["val_loss"], label="Validation data")
plt.title("Loss for VAE training on Cell Painting Level 5 data")
plt.ylabel("MSE + MMD")
plt.xlabel("No. Epoch")
plt.legend()
plt.show()

# %%
reconstruction = pd.DataFrame(cp_vae.vae.predict(test_features_df), columns=cp_features)
(sum(sum((np.array(test_features_df) - np.array(reconstruction)) ** 2))) ** 0.5
# Out:
# 54.34379114386869

# %%
#latent space heatmap
fig, ax = plt.subplots(figsize=(10, 10))
encoder = cp_vae.encoder_block["encoder"]
latent = np.array(encoder.predict(test_features_df)[2])
seaborn.heatmap(latent, ax=ax)
# Out:
# <AxesSubplot:>

# %%
pd.DataFrame(encoder.predict(test_features_df)[2]).mean()
# Out:
# 0    0.020184
# 1   -0.034880
# 2    0.252691
# 3   -0.037009
# 4   -0.048139
# 5    0.064951
# 6   -0.016192
# 7    0.020511
# 8   -0.121525
# 9    0.054545
# dtype: float32

# %%
#original vs reconstructed heatmap
reconstruction = pd.DataFrame(cp_vae.vae.predict(test_features_df), columns=cp_features)
pca = PCA(n_components=2).fit(test_features_df)
pca_reconstructed_latent_df = pd.DataFrame(pca.transform(reconstruction))
pca_test_latent_df = pd.DataFrame(pca.transform(test_features_df))
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))
# seaborn.heatmap(test_features_df, ax=ax1)
# seaborn.heatmap(reconstruction, ax=ax2)
# plt.show()

# %%
figure(figsize=(10, 10), dpi=80)
plt.scatter(pca_test_latent_df[0],pca_test_latent_df[1], marker = ".", alpha = 0.5)
plt.scatter(pca_reconstructed_latent_df[0],pca_reconstructed_latent_df[1], marker = ".", alpha = 0.5)

# %%
pca = PCA(n_components=50).fit(test_features_df)
pca_reconstructed_latent_df = pd.DataFrame(pca.transform(reconstruction))
pca_test_latent_df = pd.DataFrame(pca.transform(test_features_df))

# %%
figure(figsize=(10, 10), dpi=80)
plt.scatter(pca_test_latent_df[2],pca_test_latent_df[3], marker = ".", alpha = 0.5)
plt.scatter(pca_reconstructed_latent_df[2],pca_reconstructed_latent_df[3], marker = ".", alpha = 0.5)

# %%
# decoder = keras.models.load_model("level5Decoder")
# encoder = keras.models.load_model("level5Encoder")

# %%
# reconstruction = decoder.predict(encoder.predict(test_features_df)[2])

# %%
import umap
reducer = umap.UMAP().fit(test_features_df)
original_test_embedding = reducer.transform(test_features_df)
reconstructed_test_embedding = reducer.transform(reconstruction)

# %%
figure(figsize=(10, 10), dpi=80)
plt.scatter(original_test_embedding[:,0],original_test_embedding[:,1], marker = ".", alpha = 0.5)
plt.scatter(reconstructed_test_embedding[:,0],reconstructed_test_embedding[:,1], marker = ".", alpha = 0.5)

# %%
#difference between original and reconstructed heatmap
difference = abs(reconstruction - test_features_df)
fig, ax = plt.subplots(figsize=(10, 10))
seaborn.heatmap(difference, ax=ax, cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
#encoder heatmap
weights = cp_vae.encoder_block["encoder"].get_weights()
fig, ax = plt.subplots(figsize=(10, 10))
seaborn.heatmap(weights[0], ax=ax)
# Out:
# <AxesSubplot:>

# %%
decoder = cp_vae.decoder_block["decoder"]

# %%
pca_training = PCA(n_components=2).fit(train_features_df)

simulated_df = pd.DataFrame(np.random.normal(size=(8294, 10)), columns=np.arange(0,10))
reconstruction_of_simulated = decoder.predict(simulated_df)
pca_reconstruction_of_simulated = pd.DataFrame(pca_training.transform(reconstruction_of_simulated))
pca_train_latent_df = pd.DataFrame(pca_training.transform(train_features_df))

fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(16,8), sharey = True, sharex = True)
ax1.scatter(pca_train_latent_df[0],pca_train_latent_df[1], marker = ".", alpha = 0.5)
ax2.scatter(pca_reconstruction_of_simulated[0],pca_reconstruction_of_simulated[1], marker = ".", alpha = 0.5)

# %%
from scipy.spatial.distance import directed_hausdorff
max(directed_hausdorff(train_features_df, reconstruction_of_simulated)[0],directed_hausdorff(reconstruction_of_simulated,train_features_df)[0])
# Out:
# 6.121585586286412

# %%
# decoder = keras.models.load_model("level5Decoder")

# %%
import umap
reducer = umap.UMAP()
original_test_embedding = reducer.fit_transform(test_features_df)

# %%
simulated_test_df = pd.DataFrame(np.random.normal(size=(1037, 10)), columns=np.arange(0,10))
reconstruction_of_simulated_test = decoder.predict(simulated_test_df)

# %%
simulated_embedding = reducer.transform(reconstruction_of_simulated_test)

# %%
figure(figsize=(10, 10), dpi=80)
plt.scatter(
    original_test_embedding[:, 0],
    original_test_embedding[:, 1],
#     c=[sns.color_palette()[x] for x in penguins.species_short.map({"Adelie":0, "Chinstrap":1, "Gentoo":2})]
    marker = '.'
)
plt.scatter(
    simulated_embedding[:, 0],
    simulated_embedding[:, 1],
#     c=[sns.color_palette()[x] for x in penguins.species_short.map({"Adelie":0, "Chinstrap":1, "Gentoo":2})]
    marker = '.'
)
# plt.gca().set_aspect('equal', 'datalim')
# plt.title('UMAP projection of the cell painting level 5 test set')

# %%
#NOTE: IF YOU RUN THIS, YOU WILL NOT BE ABLE TO REPRODUCE THE EXACT RESULTS IN THE EXPERIMENT
latent_complete = np.array(encoder.predict(complete_features_df)[2])
latent_df = pd.DataFrame(latent_complete)
latent_df.to_csv("../3.application/level5Latent_mmd_leaveOut.csv")

# %%
reducer = umap.UMAP()
latent_embedding = reducer.fit_transform(latent_df)

# %%
figure(figsize=(10, 10), dpi=80)
plt.scatter(
    latent_embedding[:, 0],
    latent_embedding[:, 1],
    marker = '.'
)

# %%
#NOTE: IF YOU RUN THIS, YOU WILL NOT BE ABLE TO REPRODUCE THE EXACT RESULTS IN THE EXPERIMENT
decoder.save("level5Decoder_mmd_leaveOut")
# Out:
# INFO:tensorflow:Assets written to: level5Decoder_mmd_leaveOut/assets

# %%
encoder.save("level5Encoder_mmd_leaveOut")
# Out:
# INFO:tensorflow:Assets written to: level5Encoder_mmd_leaveOut/assets
