# %% [markdown]
# # Train a VAE on Cell Painting LINCS Data

# %%
import sys
import pathlib
import numpy as np
import pandas as pd
sys.path.insert(0, "../../scripts")
from utils import load_data


from pycytominer.cyto_utils import infer_cp_features


import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

from sklearn.decomposition import PCA
from tensorflow import keras

from vae import VAE

from tensorflow.keras.models import Model, Sequential
import seaborn
import random as python_random
import tensorflow as tf
import umap

# %%
# %load_ext nb_black

# %%
# np.random.seed(123)
# python_random.seed(123)
# tf.random.set_random_seed(1234)

# %%
data_splits = ["train", "test", "valid", "complete"]
data_dict = load_data(data_splits)

# %%
def remove_moa(df):
    pipes = ['NFkB pathway inhibitor|proteasome inhibitor',
             'DNA inhibitor|topoisomerase inhibitor',
             'microtubule inhibitor|tubulin polymerization inhibitor',
             'SRC inhibitor|tubulin polymerization inhibitor',
            'Aurora kinase inhibitor|JAK inhibitor']    
    moas =  []
    for pipe in pipes:
        moas.append(pipe)
        moas.append(pipe.split('|')[0])
        moas.append(pipe.split('|')[1])
    return df[~df.moa.isin(moas)]

# %%
# Prepare data for training
meta_features = infer_cp_features(data_dict["train"], metadata=True)
cp_features = infer_cp_features(data_dict["train"])

moa_df_train = pd.read_csv("../3.application/repurposing_info_external_moa_map_resolved.tsv",sep='\t').set_index('broad_sample').reindex(index=data_dict['train']['Metadata_broad_sample']).reset_index().drop('Metadata_broad_sample',axis = 1)
data_dict['train'] = pd.concat([moa_df_train,data_dict['train']], axis=1)

moa_df_valid = pd.read_csv("../3.application/repurposing_info_external_moa_map_resolved.tsv",sep='\t').set_index('broad_sample').reindex(index=data_dict['valid']['Metadata_broad_sample']).reset_index().drop('Metadata_broad_sample',axis = 1)
data_dict['valid'] = pd.concat([moa_df_valid,data_dict['valid']], axis=1)

data_dict['train'] = remove_moa(data_dict['train'])
data_dict['valid'] = remove_moa(data_dict['valid'])

train_features_df = data_dict["train"].reindex(cp_features, axis="columns")
train_meta_df = data_dict["train"].reindex(meta_features, axis="columns")

test_features_df = data_dict["test"].reindex(cp_features, axis="columns")
test_meta_df = data_dict["test"].reindex(meta_features, axis="columns")

valid_features_df = data_dict["valid"].reindex(cp_features, axis="columns")
valid_meta_df = data_dict["valid"].reindex(meta_features, axis="columns")

complete_features_df = data_dict["complete"].reindex(cp_features, axis="columns")
complete_meta_df = data_dict["complete"].reindex(meta_features, axis="columns")

# %%
print(train_features_df.shape)
train_features_df.head(3)
# Out:
# (7459, 588)
#    Cells_AreaShape_FormFactor  Cells_AreaShape_Orientation  \
# 0                     0.56071                      0.63708
# 1                     0.59702                      0.55453
# 2                     0.64623                      0.59825
#
#    Cells_AreaShape_Zernike_2_2  Cells_AreaShape_Zernike_3_1  \
# 0                      0.57961                      0.51030
# 1                      0.62561                      0.47959
# 2                      0.62822                      0.52100
#
#    Cells_AreaShape_Zernike_5_1  Cells_AreaShape_Zernike_6_2  \
# 0                      0.61695                      0.30869
# 1                      0.59022                      0.33269
# 2                      0.57452                      0.26367
#
#    Cells_AreaShape_Zernike_7_1  Cells_AreaShape_Zernike_7_7  \
# 0                      0.43981                      0.79826
# 1                      0.49875                      0.88042
# 2                      0.48172                      0.86322
#
#    Cells_AreaShape_Zernike_9_3  Cells_Correlation_Correlation_DNA_AGP  ...  \
# 0                      0.72477                                0.68589  ...
# 1                      0.67159                                0.61703  ...
# 2                      0.67588                                0.69732  ...
#
#    Nuclei_Texture_SumAverage_AGP_5_0  Nuclei_Texture_SumEntropy_AGP_10_0  \
# 0                            0.17858                             0.29336
# 1                            0.09030                             0.15088
# 2                            0.18125                             0.23244
#
#    Nuclei_Texture_SumEntropy_AGP_20_0  Nuclei_Texture_SumEntropy_AGP_5_0  \
# 0                             0.26447                            0.30197
# 1                             0.13334                            0.14052
# 2                             0.20723                            0.24062
#
#    Nuclei_Texture_SumEntropy_DNA_10_0  Nuclei_Texture_SumEntropy_DNA_20_0  \
# 0                             0.64786                             0.49525
# 1                             0.59229                             0.49294
# 2                             0.54642                             0.43920
#
#    Nuclei_Texture_SumEntropy_Mito_5_0  Nuclei_Texture_SumVariance_DNA_5_0  \
# 0                             0.53512                             0.40495
# 1                             0.43221                             0.33969
# 2                             0.41183                             0.30375
#
#    Nuclei_Texture_Variance_DNA_20_0  Nuclei_Texture_Variance_DNA_5_0
# 0                           0.46056                          0.43647
# 1                           0.39208                          0.36205
# 2                           0.35385                          0.33266
#
# [3 rows x 588 columns]

# %%
print(test_features_df.shape)
test_features_df.head(3)
# Out:
# (1037, 588)
#    Cells_AreaShape_FormFactor  Cells_AreaShape_Orientation  \
# 0                     0.52664                      0.59293
# 1                     0.61343                      0.57882
# 2                     0.55123                      0.61050
#
#    Cells_AreaShape_Zernike_2_2  Cells_AreaShape_Zernike_3_1  \
# 0                      0.51636                      0.52824
# 1                      0.62454                      0.51049
# 2                      0.53085                      0.65280
#
#    Cells_AreaShape_Zernike_5_1  Cells_AreaShape_Zernike_6_2  \
# 0                      0.54415                      0.23948
# 1                      0.57508                      0.31691
# 2                      0.54356                      0.16767
#
#    Cells_AreaShape_Zernike_7_1  Cells_AreaShape_Zernike_7_7  \
# 0                      0.53361                      0.84625
# 1                      0.49077                      0.89145
# 2                      0.50521                      0.93703
#
#    Cells_AreaShape_Zernike_9_3  Cells_Correlation_Correlation_DNA_AGP  ...  \
# 0                      0.65881                                0.86971  ...
# 1                      0.65811                                0.66082  ...
# 2                      0.77958                                0.63413  ...
#
#    Nuclei_Texture_SumAverage_AGP_5_0  Nuclei_Texture_SumEntropy_AGP_10_0  \
# 0                            0.74413                             0.58353
# 1                            0.12499                             0.20488
# 2                            0.19249                             0.13665
#
#    Nuclei_Texture_SumEntropy_AGP_20_0  Nuclei_Texture_SumEntropy_AGP_5_0  \
# 0                             0.54654                            0.63600
# 1                             0.18676                            0.20580
# 2                             0.13293                            0.13816
#
#    Nuclei_Texture_SumEntropy_DNA_10_0  Nuclei_Texture_SumEntropy_DNA_20_0  \
# 0                             0.50501                             0.39338
# 1                             0.58773                             0.47783
# 2                             0.58333                             0.52931
#
#    Nuclei_Texture_SumEntropy_Mito_5_0  Nuclei_Texture_SumVariance_DNA_5_0  \
# 0                             0.46080                             0.25924
# 1                             0.42619                             0.34683
# 2                             0.31068                             0.40967
#
#    Nuclei_Texture_Variance_DNA_20_0  Nuclei_Texture_Variance_DNA_5_0
# 0                           0.29724                          0.27556
# 1                           0.39642                          0.37092
# 2                           0.48646                          0.45058
#
# [3 rows x 588 columns]

# %%
print(complete_features_df.shape)
complete_features_df.head(3)
# Out:
# (10368, 588)
#    Cells_AreaShape_FormFactor  Cells_AreaShape_Orientation  \
# 0                     0.57016                      0.59500
# 1                     0.54840                      0.53949
# 2                     0.56057                      0.59621
#
#    Cells_AreaShape_Zernike_2_2  Cells_AreaShape_Zernike_3_1  \
# 0                      0.57370                      0.50690
# 1                      0.58096                      0.53694
# 2                      0.59116                      0.50418
#
#    Cells_AreaShape_Zernike_5_1  Cells_AreaShape_Zernike_6_2  \
# 0                      0.56160                      0.27321
# 1                      0.55009                      0.28114
# 2                      0.55679                      0.29305
#
#    Cells_AreaShape_Zernike_7_1  Cells_AreaShape_Zernike_7_7  \
# 0                      0.45448                      0.83747
# 1                      0.53594                      0.86929
# 2                      0.49221                      0.87813
#
#    Cells_AreaShape_Zernike_9_3  Cells_Correlation_Correlation_DNA_AGP  ...  \
# 0                      0.68635                                0.68973  ...
# 1                      0.66026                                0.71317  ...
# 2                      0.71747                                0.72229  ...
#
#    Nuclei_Texture_SumAverage_AGP_5_0  Nuclei_Texture_SumEntropy_AGP_10_0  \
# 0                            0.16426                             0.22701
# 1                            0.18411                             0.23932
# 2                            0.17564                             0.23366
#
#    Nuclei_Texture_SumEntropy_AGP_20_0  Nuclei_Texture_SumEntropy_AGP_5_0  \
# 0                             0.20854                            0.22897
# 1                             0.21854                            0.24763
# 2                             0.21743                            0.23448
#
#    Nuclei_Texture_SumEntropy_DNA_10_0  Nuclei_Texture_SumEntropy_DNA_20_0  \
# 0                             0.53738                             0.43547
# 1                             0.56995                             0.47084
# 2                             0.56980                             0.47254
#
#    Nuclei_Texture_SumEntropy_Mito_5_0  Nuclei_Texture_SumVariance_DNA_5_0  \
# 0                             0.41635                             0.28933
# 1                             0.37764                             0.32148
# 2                             0.39575                             0.31969
#
#    Nuclei_Texture_Variance_DNA_20_0  Nuclei_Texture_Variance_DNA_5_0
# 0                           0.34017                          0.31368
# 1                           0.36964                          0.34328
# 2                           0.36626                          0.34086
#
# [3 rows x 588 columns]

# %%
# VAE of one layer
encoder_architecture = [250]
decoder_architecture = [250]

# %%
# model from optimal hyperparameters for onelayer obtained from 1.optimize
cp_vae = VAE(
    input_dim=train_features_df.shape[1],
    latent_dim=10,
    batch_size=96,
    encoder_batch_norm=True,
    epochs=30,
    learning_rate=0.001,
    encoder_architecture=encoder_architecture,
    decoder_architecture=decoder_architecture,
    beta=0,
    lam=1000,
    verbose=True,
)
#100000
#10000
#200 ep 1000000 results in 1.20
cp_vae.compile_vae()

# %%
cp_vae.train(x_train=train_features_df, x_test=valid_features_df)
# Out:
# Epoch 1/30
# 78/78 [==============================] - 4s 17ms/step - loss: 80.2550 - recon: 31.0889 - kl: 0.0000e+00 - mmd: 10.9983 - val_loss: 87.0421 - val_recon: 19.0717 - val_kl: 0.0000e+00 - val_mmd: 69.2366
# Epoch 2/30
# 78/78 [==============================] - 0s 6ms/step - loss: 14.7262 - recon: 6.8189 - kl: 0.0000e+00 - mmd: 6.4200 - val_loss: 80.5994 - val_recon: 11.5772 - val_kl: 0.0000e+00 - val_mmd: 76.2274
# Epoch 3/30
# 78/78 [==============================] - 0s 5ms/step - loss: 10.1825 - recon: 5.1048 - kl: 0.0000e+00 - mmd: 5.0766 - val_loss: 68.9396 - val_recon: 8.9370 - val_kl: 0.0000e+00 - val_mmd: 58.0130
# Epoch 4/30
# 78/78 [==============================] - 0s 6ms/step - loss: 8.6544 - recon: 4.0633 - kl: 0.0000e+00 - mmd: 4.3904 - val_loss: 35.5430 - val_recon: 4.5995 - val_kl: 0.0000e+00 - val_mmd: 34.6823
# Epoch 5/30
# 78/78 [==============================] - 0s 6ms/step - loss: 7.7629 - recon: 3.4342 - kl: 0.0000e+00 - mmd: 3.9440 - val_loss: 36.9058 - val_recon: 5.2088 - val_kl: 0.0000e+00 - val_mmd: 32.4470
# Epoch 6/30
# 78/78 [==============================] - 0s 6ms/step - loss: 7.2946 - recon: 3.0397 - kl: 0.0000e+00 - mmd: 4.2634 - val_loss: 61.9007 - val_recon: 3.5178 - val_kl: 0.0000e+00 - val_mmd: 59.0290
# Epoch 7/30
# 78/78 [==============================] - 0s 6ms/step - loss: 7.1474 - recon: 2.8813 - kl: 0.0000e+00 - mmd: 3.7353 - val_loss: 17.8017 - val_recon: 2.7518 - val_kl: 0.0000e+00 - val_mmd: 15.5590
# Epoch 8/30
# 78/78 [==============================] - 0s 6ms/step - loss: 6.8442 - recon: 2.7674 - kl: 0.0000e+00 - mmd: 3.7844 - val_loss: 25.0678 - val_recon: 2.7139 - val_kl: 0.0000e+00 - val_mmd: 20.1439
# Epoch 9/30
# 78/78 [==============================] - 0s 5ms/step - loss: 6.7170 - recon: 2.6557 - kl: 0.0000e+00 - mmd: 3.7595 - val_loss: 56.1168 - val_recon: 3.0187 - val_kl: 0.0000e+00 - val_mmd: 56.4024
# Epoch 10/30
# 78/78 [==============================] - 0s 6ms/step - loss: 6.4113 - recon: 2.6194 - kl: 0.0000e+00 - mmd: 3.8743 - val_loss: 17.5050 - val_recon: 2.6465 - val_kl: 0.0000e+00 - val_mmd: 14.2651
# Epoch 11/30
# 78/78 [==============================] - 0s 6ms/step - loss: 6.1943 - recon: 2.6118 - kl: 0.0000e+00 - mmd: 3.6582 - val_loss: 17.2135 - val_recon: 2.5008 - val_kl: 0.0000e+00 - val_mmd: 14.7736
# Epoch 12/30
# 78/78 [==============================] - 0s 6ms/step - loss: 6.3810 - recon: 2.5595 - kl: 0.0000e+00 - mmd: 3.6886 - val_loss: 15.8760 - val_recon: 2.5012 - val_kl: 0.0000e+00 - val_mmd: 14.6125
# Epoch 13/30
# 78/78 [==============================] - 0s 6ms/step - loss: 6.2337 - recon: 2.4944 - kl: 0.0000e+00 - mmd: 3.6212 - val_loss: 20.0103 - val_recon: 2.4449 - val_kl: 0.0000e+00 - val_mmd: 16.8545
# Epoch 14/30
# 78/78 [==============================] - 0s 6ms/step - loss: 6.3555 - recon: 2.4680 - kl: 0.0000e+00 - mmd: 3.8204 - val_loss: 12.4778 - val_recon: 2.3775 - val_kl: 0.0000e+00 - val_mmd: 9.1561
# Epoch 15/30
# 78/78 [==============================] - 0s 6ms/step - loss: 6.2261 - recon: 2.4256 - kl: 0.0000e+00 - mmd: 3.8318 - val_loss: 9.5512 - val_recon: 2.4403 - val_kl: 0.0000e+00 - val_mmd: 5.4346
# Epoch 16/30
# 78/78 [==============================] - 0s 5ms/step - loss: 6.2756 - recon: 2.3818 - kl: 0.0000e+00 - mmd: 3.6931 - val_loss: 15.4966 - val_recon: 2.2698 - val_kl: 0.0000e+00 - val_mmd: 13.4355
# Epoch 17/30
# 78/78 [==============================] - 0s 6ms/step - loss: 6.1203 - recon: 2.3778 - kl: 0.0000e+00 - mmd: 3.6143 - val_loss: 8.6491 - val_recon: 2.2266 - val_kl: 0.0000e+00 - val_mmd: 7.7495
# Epoch 18/30
# 78/78 [==============================] - 0s 5ms/step - loss: 6.1446 - recon: 2.3391 - kl: 0.0000e+00 - mmd: 3.7402 - val_loss: 9.3016 - val_recon: 2.3547 - val_kl: 0.0000e+00 - val_mmd: 8.0256
# Epoch 19/30
# 78/78 [==============================] - 0s 6ms/step - loss: 6.1670 - recon: 2.3161 - kl: 0.0000e+00 - mmd: 3.9982 - val_loss: 9.2497 - val_recon: 2.1995 - val_kl: 0.0000e+00 - val_mmd: 7.8745
# Epoch 20/30
# 78/78 [==============================] - 0s 5ms/step - loss: 5.6885 - recon: 2.2981 - kl: 0.0000e+00 - mmd: 3.6688 - val_loss: 16.5246 - val_recon: 2.2023 - val_kl: 0.0000e+00 - val_mmd: 14.2418
# Epoch 21/30
# 78/78 [==============================] - 0s 5ms/step - loss: 6.0547 - recon: 2.2541 - kl: 0.0000e+00 - mmd: 3.7715 - val_loss: 7.8795 - val_recon: 2.2581 - val_kl: 0.0000e+00 - val_mmd: 5.6686
# Epoch 22/30
# 78/78 [==============================] - 0s 6ms/step - loss: 6.3063 - recon: 2.3130 - kl: 0.0000e+00 - mmd: 3.4803 - val_loss: 11.3193 - val_recon: 2.2139 - val_kl: 0.0000e+00 - val_mmd: 10.1404
# Epoch 23/30
# 78/78 [==============================] - 0s 6ms/step - loss: 5.7091 - recon: 2.2620 - kl: 0.0000e+00 - mmd: 3.7557 - val_loss: 8.2226 - val_recon: 2.0535 - val_kl: 0.0000e+00 - val_mmd: 6.5936
# Epoch 24/30
# 78/78 [==============================] - 0s 6ms/step - loss: 5.8229 - recon: 2.1966 - kl: 0.0000e+00 - mmd: 3.6958 - val_loss: 7.8659 - val_recon: 2.2280 - val_kl: 0.0000e+00 - val_mmd: 3.5878
# Epoch 25/30
# 78/78 [==============================] - 0s 6ms/step - loss: 6.0741 - recon: 2.2141 - kl: 0.0000e+00 - mmd: 3.6191 - val_loss: 6.8910 - val_recon: 2.2057 - val_kl: 0.0000e+00 - val_mmd: 6.6989
# Epoch 26/30
# 78/78 [==============================] - 0s 6ms/step - loss: 5.8157 - recon: 2.2344 - kl: 0.0000e+00 - mmd: 3.6781 - val_loss: 14.6909 - val_recon: 2.1112 - val_kl: 0.0000e+00 - val_mmd: 13.9721
# Epoch 27/30
# 78/78 [==============================] - 0s 6ms/step - loss: 5.7946 - recon: 2.1797 - kl: 0.0000e+00 - mmd: 3.8940 - val_loss: 21.5833 - val_recon: 2.2044 - val_kl: 0.0000e+00 - val_mmd: 20.2533
# Epoch 28/30
# 78/78 [==============================] - 0s 6ms/step - loss: 5.8790 - recon: 2.1510 - kl: 0.0000e+00 - mmd: 3.5696 - val_loss: 17.0170 - val_recon: 2.1452 - val_kl: 0.0000e+00 - val_mmd: 11.7004
# Epoch 29/30
# 78/78 [==============================] - 0s 6ms/step - loss: 5.8680 - recon: 2.1212 - kl: 0.0000e+00 - mmd: 3.4927 - val_loss: 9.2413 - val_recon: 2.1227 - val_kl: 0.0000e+00 - val_mmd: 9.4541
# Epoch 30/30
# 78/78 [==============================] - 0s 6ms/step - loss: 5.6792 - recon: 2.0990 - kl: 0.0000e+00 - mmd: 3.7589 - val_loss: 7.6198 - val_recon: 2.0824 - val_kl: 0.0000e+00 - val_mmd: 5.9163

# %%
cp_vae.vae

# %%
# cp_vae.vae.evaluate(test_features_df)

# %%
# Save training performance
history_df = pd.DataFrame(cp_vae.vae.history.history)
history_df
# Out:
#          loss      recon   kl        mmd   val_loss  val_recon  val_kl  \
# 0   41.820385  31.088850  0.0  10.998311  87.042130  19.071722     0.0
# 1   13.483415   6.818879  0.0   6.419995  80.599426  11.577157     0.0
# 2    9.984121   5.104762  0.0   5.076552  68.939613   8.936980     0.0
# 3    8.463908   4.063283  0.0   4.390364  35.543037   4.599531     0.0
# 4    7.567466   3.434248  0.0   3.944003  36.905827   5.208802     0.0
# 5    7.058690   3.039739  0.0   4.263436  61.900658   3.517805     0.0
# 6    6.930832   2.881315  0.0   3.735322  17.801685   2.751783     0.0
# 7    6.828012   2.767445  0.0   3.784448  25.067846   2.713866     0.0
# 8    6.658366   2.655691  0.0   3.759480  56.116760   3.018745     0.0
# 9    6.418894   2.619430  0.0   3.874251  17.505047   2.646516     0.0
# 10   6.259346   2.611754  0.0   3.658232  17.213524   2.500759     0.0
# 11   6.523540   2.559485  0.0   3.688612  15.875993   2.501160     0.0
# 12   6.245189   2.494372  0.0   3.621207  20.010317   2.444937     0.0
# 13   6.361957   2.467959  0.0   3.820431  12.477761   2.377499     0.0
# 14   6.224334   2.425646  0.0   3.831753   9.551231   2.440275     0.0
# 15   6.141468   2.381788  0.0   3.693071  15.496594   2.269846     0.0
# 16   6.117248   2.377750  0.0   3.614329   8.649142   2.226628     0.0
# 17   5.924884   2.339113  0.0   3.740207   9.301573   2.354691     0.0
# 18   6.124947   2.316058  0.0   3.998208   9.249651   2.199514     0.0
# 19   5.777027   2.298118  0.0   3.668850  16.524561   2.202329     0.0
# 20   6.002361   2.254095  0.0   3.771475   7.879465   2.258108     0.0
# 21   6.228396   2.312958  0.0   3.480292  11.319321   2.213907     0.0
# 22   5.672418   2.261994  0.0   3.755747   8.222616   2.053544     0.0
# 23   5.636194   2.196617  0.0   3.695775   7.865854   2.227956     0.0
# 24   6.137064   2.214072  0.0   3.619125   6.890967   2.205674     0.0
# 25   5.855956   2.234396  0.0   3.678104  14.690936   2.111212     0.0
# 26   5.710490   2.179738  0.0   3.894021  21.583267   2.204387     0.0
# 27   5.836096   2.151002  0.0   3.569601  17.017050   2.145167     0.0
# 28   5.758900   2.121242  0.0   3.492742   9.241293   2.122714     0.0
# 29   5.715091   2.098995  0.0   3.758919   7.619753   2.082431     0.0
#
#       val_mmd
# 0   69.236618
# 1   76.227371
# 2   58.013023
# 3   34.682346
# 4   32.446957
# 5   59.029030
# 6   15.558957
# 7   20.143902
# 8   56.402428
# 9   14.265144
# 10  14.773561
# 11  14.612518
# 12  16.854465
# 13   9.156132
# 14   5.434585
# 15  13.435506
# 16   7.749534
# 17   8.025622
# 18   7.874476
# 19  14.241803
# 20   5.668557
# 21  10.140394
# 22   6.593633
# 23   3.587794
# 24   6.698930
# 25  13.972056
# 26  20.253347
# 27  11.700356
# 28   9.454071
# 29   5.916333

# %%
history_df.to_csv('training_data/level5_training_mmd_leaveOut.csv')

# %%
plt.figure(figsize=(10, 5))
plt.plot(history_df["loss"], label="Training data")
plt.plot(history_df["val_loss"], label="Validation data")
plt.title("Loss for VAE training on Cell Painting Level 5 data")
plt.ylabel("MSE + MMD")
plt.xlabel("No. Epoch")
plt.legend()
plt.show()

# %%
reconstruction = pd.DataFrame(cp_vae.vae.predict(test_features_df), columns=cp_features)
(sum(sum((np.array(test_features_df) - np.array(reconstruction)) ** 2))) ** 0.5
# Out:
# 54.66225418985086

# %%
#latent space heatmap
fig, ax = plt.subplots(figsize=(10, 10))
encoder = cp_vae.encoder_block["encoder"]
latent = np.array(encoder.predict(test_features_df)[2])
seaborn.heatmap(latent, ax=ax)
# Out:
# <AxesSubplot:>

# %%
pd.DataFrame(encoder.predict(test_features_df)[2]).mean()
# Out:
# 0   -0.123747
# 1    0.193257
# 2   -0.099272
# 3   -0.153954
# 4   -0.053106
# 5   -0.221860
# 6   -0.119048
# 7   -0.079422
# 8   -0.154004
# 9   -0.084645
# dtype: float32

# %%
#original vs reconstructed heatmap
reconstruction = pd.DataFrame(cp_vae.vae.predict(test_features_df), columns=cp_features)
pca = PCA(n_components=2).fit(test_features_df)
pca_reconstructed_latent_df = pd.DataFrame(pca.transform(reconstruction))
pca_test_latent_df = pd.DataFrame(pca.transform(test_features_df))
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))
# seaborn.heatmap(test_features_df, ax=ax1)
# seaborn.heatmap(reconstruction, ax=ax2)
# plt.show()

# %%
figure(figsize=(10, 10), dpi=80)
plt.scatter(pca_test_latent_df[0],pca_test_latent_df[1], marker = ".", alpha = 0.5)
plt.scatter(pca_reconstructed_latent_df[0],pca_reconstructed_latent_df[1], marker = ".", alpha = 0.5)

# %%
pca = PCA(n_components=50).fit(test_features_df)
pca_reconstructed_latent_df = pd.DataFrame(pca.transform(reconstruction))
pca_test_latent_df = pd.DataFrame(pca.transform(test_features_df))

# %%
figure(figsize=(10, 10), dpi=80)
plt.scatter(pca_test_latent_df[2],pca_test_latent_df[3], marker = ".", alpha = 0.5)
plt.scatter(pca_reconstructed_latent_df[2],pca_reconstructed_latent_df[3], marker = ".", alpha = 0.5)

# %%
#difference between original and reconstructed heatmap
difference = abs(reconstruction - test_features_df)
fig, ax = plt.subplots(figsize=(10, 10))
seaborn.heatmap(difference, ax=ax, cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
#encoder heatmap
weights = cp_vae.encoder_block["encoder"].get_weights()
fig, ax = plt.subplots(figsize=(10, 10))
seaborn.heatmap(weights[0], ax=ax)
# Out:
# <AxesSubplot:>

# %%
decoder = cp_vae.decoder_block["decoder"]

# %%
pca_training = PCA(n_components=2).fit(train_features_df)

simulated_df = pd.DataFrame(np.random.normal(size=(8294, 10)), columns=np.arange(0,10))
reconstruction_of_simulated = decoder.predict(simulated_df)
pca_reconstruction_of_simulated = pd.DataFrame(pca_training.transform(reconstruction_of_simulated))
pca_train_latent_df = pd.DataFrame(pca_training.transform(train_features_df))

fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(16,8), sharey = True, sharex = True)
ax1.scatter(pca_train_latent_df[0],pca_train_latent_df[1], marker = ".", alpha = 0.5)
ax2.scatter(pca_reconstruction_of_simulated[0],pca_reconstruction_of_simulated[1], marker = ".", alpha = 0.5)

# %%
from scipy.spatial.distance import directed_hausdorff
max(directed_hausdorff(train_features_df, reconstruction_of_simulated)[0],directed_hausdorff(reconstruction_of_simulated,train_features_df)[0])
# Out:
# 6.4060268305060095

# %%
#NOTE: IF YOU RUN THIS, YOU WILL NOT BE ABLE TO REPRODUCE THE EXACT RESULTS IN THE EXPERIMENT
latent_complete = np.array(encoder.predict(complete_features_df)[2])
latent_df = pd.DataFrame(latent_complete)
latent_df.to_csv("../3.application/level5Latent_mmd_leaveOut.csv")

# %%
reducer = umap.UMAP()
latent_embedding = reducer.fit_transform(latent_df)

# %%
figure(figsize=(10, 10), dpi=80)
plt.scatter(
    latent_embedding[:, 0],
    latent_embedding[:, 1],
    marker = '.'
)

# %%
#NOTE: IF YOU RUN THIS, YOU WILL NOT BE ABLE TO REPRODUCE THE EXACT RESULTS IN THE EXPERIMENT
decoder.save("models/level5Decoder_mmd_leaveOut")
# Out:
# INFO:tensorflow:Assets written to: level5Decoder_mmd_leaveOut/assets

# %%
encoder.save("models/level5Encoder_mmd_leaveOut")
# Out:
# INFO:tensorflow:Assets written to: level5Encoder_mmd_leaveOut/assets
