# %% [markdown]
# # Train a VAE on Cell Painting LINCS Data

# %%
import sys
import pathlib
import numpy as np
import pandas as pd
sys.path.insert(0, "../../scripts")
from utils import load_data


from pycytominer.cyto_utils import infer_cp_features


import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

from sklearn.decomposition import PCA
from tensorflow import keras

from vae import VAE

from tensorflow.keras.models import Model, Sequential
import seaborn
import random as python_random
import tensorflow as tf
# import umap
# Out:
# /home/ubuntu/miniconda3/envs/cell-painting-vae/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:35: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps,
# /home/ubuntu/miniconda3/envs/cell-painting-vae/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:597: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /home/ubuntu/miniconda3/envs/cell-painting-vae/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:836: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /home/ubuntu/miniconda3/envs/cell-painting-vae/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:862: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, positive=False):
# /home/ubuntu/miniconda3/envs/cell-painting-vae/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1097: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /home/ubuntu/miniconda3/envs/cell-painting-vae/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1344: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /home/ubuntu/miniconda3/envs/cell-painting-vae/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1480: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, positive=False):
# /home/ubuntu/miniconda3/envs/cell-painting-vae/lib/python3.7/site-packages/sklearn/linear_model/randomized_l1.py:152: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   precompute=False, eps=np.finfo(np.float).eps,
# /home/ubuntu/miniconda3/envs/cell-painting-vae/lib/python3.7/site-packages/sklearn/linear_model/randomized_l1.py:320: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, random_state=None,
# /home/ubuntu/miniconda3/envs/cell-painting-vae/lib/python3.7/site-packages/sklearn/linear_model/randomized_l1.py:580: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=4 * np.finfo(np.float).eps, n_jobs=None,
# /home/ubuntu/miniconda3/envs/cell-painting-vae/lib/python3.7/site-packages/sklearn/decomposition/online_lda.py:31: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EPS = np.finfo(np.float).eps

# %%
def remove_moa(df):
    pipes = ['dopamine receptor agonist|serotonin receptor antagonist'
         'sodium channel blocker|T-type calcium channel blocker',
             'EGFR inhibitor|VEGFR inhibitor',
             'leukotriene receptor antagonist|lipoxygenase inhibitor',
            'acetylcholine receptor agonist|benzodiazepine receptor agonist']    
    moas =  []
    for pipe in pipes:
        moas.append(pipe)
        moas.append(pipe.split('|')[0])
        moas.append(pipe.split('|')[1])
    return df[~df.moa.isin(moas)]

# %%
data_splits = ["train", "test", "valid", "complete"]
data_dict = load_data(data_splits)

# %%
# Prepare data for training
meta_features = infer_cp_features(data_dict["train"], metadata=True)
cp_features = infer_cp_features(data_dict["train"])

moa_df_train = pd.read_csv("../3.application/repurposing_info_external_moa_map_resolved.tsv",sep='\t').set_index('broad_sample').reindex(index=data_dict['train']['Metadata_broad_sample']).reset_index().drop('Metadata_broad_sample',axis = 1)
data_dict['train'] = pd.concat([moa_df_train,data_dict['train']], axis=1)

moa_df_valid = pd.read_csv("../3.application/repurposing_info_external_moa_map_resolved.tsv",sep='\t').set_index('broad_sample').reindex(index=data_dict['valid']['Metadata_broad_sample']).reset_index().drop('Metadata_broad_sample',axis = 1)
data_dict['valid'] = pd.concat([moa_df_valid,data_dict['valid']], axis=1)

data_dict['train'] = remove_moa(data_dict['train'])
data_dict['valid'] = remove_moa(data_dict['valid'])

train_features_df = data_dict["train"].reindex(cp_features, axis="columns")
train_meta_df = data_dict["train"].reindex(meta_features, axis="columns")

test_features_df = data_dict["test"].reindex(cp_features, axis="columns")
test_meta_df = data_dict["test"].reindex(meta_features, axis="columns")

valid_features_df = data_dict["valid"].reindex(cp_features, axis="columns")
valid_meta_df = data_dict["valid"].reindex(meta_features, axis="columns")

complete_features_df = data_dict["complete"].reindex(cp_features, axis="columns")
complete_meta_df = data_dict["complete"].reindex(meta_features, axis="columns")

# %%
print(train_features_df.shape)
train_features_df.head(3)
# Out:
# (8029, 588)
#    Cells_AreaShape_FormFactor  Cells_AreaShape_Orientation  \
# 0                     0.56071                      0.63708
# 1                     0.59702                      0.55453
# 2                     0.64623                      0.59825
#
#    Cells_AreaShape_Zernike_2_2  Cells_AreaShape_Zernike_3_1  \
# 0                      0.57961                      0.51030
# 1                      0.62561                      0.47959
# 2                      0.62822                      0.52100
#
#    Cells_AreaShape_Zernike_5_1  Cells_AreaShape_Zernike_6_2  \
# 0                      0.61695                      0.30869
# 1                      0.59022                      0.33269
# 2                      0.57452                      0.26367
#
#    Cells_AreaShape_Zernike_7_1  Cells_AreaShape_Zernike_7_7  \
# 0                      0.43981                      0.79826
# 1                      0.49875                      0.88042
# 2                      0.48172                      0.86322
#
#    Cells_AreaShape_Zernike_9_3  Cells_Correlation_Correlation_DNA_AGP  ...  \
# 0                      0.72477                                0.68589  ...
# 1                      0.67159                                0.61703  ...
# 2                      0.67588                                0.69732  ...
#
#    Nuclei_Texture_SumAverage_AGP_5_0  Nuclei_Texture_SumEntropy_AGP_10_0  \
# 0                            0.17858                             0.29336
# 1                            0.09030                             0.15088
# 2                            0.18125                             0.23244
#
#    Nuclei_Texture_SumEntropy_AGP_20_0  Nuclei_Texture_SumEntropy_AGP_5_0  \
# 0                             0.26447                            0.30197
# 1                             0.13334                            0.14052
# 2                             0.20723                            0.24062
#
#    Nuclei_Texture_SumEntropy_DNA_10_0  Nuclei_Texture_SumEntropy_DNA_20_0  \
# 0                             0.64786                             0.49525
# 1                             0.59229                             0.49294
# 2                             0.54642                             0.43920
#
#    Nuclei_Texture_SumEntropy_Mito_5_0  Nuclei_Texture_SumVariance_DNA_5_0  \
# 0                             0.53512                             0.40495
# 1                             0.43221                             0.33969
# 2                             0.41183                             0.30375
#
#    Nuclei_Texture_Variance_DNA_20_0  Nuclei_Texture_Variance_DNA_5_0
# 0                           0.46056                          0.43647
# 1                           0.39208                          0.36205
# 2                           0.35385                          0.33266
#
# [3 rows x 588 columns]

# %%
print(test_features_df.shape)
test_features_df.head(3)
# Out:
# (1037, 588)
#    Cells_AreaShape_FormFactor  Cells_AreaShape_Orientation  \
# 0                     0.52664                      0.59293
# 1                     0.61343                      0.57882
# 2                     0.55123                      0.61050
#
#    Cells_AreaShape_Zernike_2_2  Cells_AreaShape_Zernike_3_1  \
# 0                      0.51636                      0.52824
# 1                      0.62454                      0.51049
# 2                      0.53085                      0.65280
#
#    Cells_AreaShape_Zernike_5_1  Cells_AreaShape_Zernike_6_2  \
# 0                      0.54415                      0.23948
# 1                      0.57508                      0.31691
# 2                      0.54356                      0.16767
#
#    Cells_AreaShape_Zernike_7_1  Cells_AreaShape_Zernike_7_7  \
# 0                      0.53361                      0.84625
# 1                      0.49077                      0.89145
# 2                      0.50521                      0.93703
#
#    Cells_AreaShape_Zernike_9_3  Cells_Correlation_Correlation_DNA_AGP  ...  \
# 0                      0.65881                                0.86971  ...
# 1                      0.65811                                0.66082  ...
# 2                      0.77958                                0.63413  ...
#
#    Nuclei_Texture_SumAverage_AGP_5_0  Nuclei_Texture_SumEntropy_AGP_10_0  \
# 0                            0.74413                             0.58353
# 1                            0.12499                             0.20488
# 2                            0.19249                             0.13665
#
#    Nuclei_Texture_SumEntropy_AGP_20_0  Nuclei_Texture_SumEntropy_AGP_5_0  \
# 0                             0.54654                            0.63600
# 1                             0.18676                            0.20580
# 2                             0.13293                            0.13816
#
#    Nuclei_Texture_SumEntropy_DNA_10_0  Nuclei_Texture_SumEntropy_DNA_20_0  \
# 0                             0.50501                             0.39338
# 1                             0.58773                             0.47783
# 2                             0.58333                             0.52931
#
#    Nuclei_Texture_SumEntropy_Mito_5_0  Nuclei_Texture_SumVariance_DNA_5_0  \
# 0                             0.46080                             0.25924
# 1                             0.42619                             0.34683
# 2                             0.31068                             0.40967
#
#    Nuclei_Texture_Variance_DNA_20_0  Nuclei_Texture_Variance_DNA_5_0
# 0                           0.29724                          0.27556
# 1                           0.39642                          0.37092
# 2                           0.48646                          0.45058
#
# [3 rows x 588 columns]

# %%
print(complete_features_df.shape)
complete_features_df.head(3)
# Out:
# (10368, 588)
#    Cells_AreaShape_FormFactor  Cells_AreaShape_Orientation  \
# 0                     0.57016                      0.59500
# 1                     0.54840                      0.53949
# 2                     0.56057                      0.59621
#
#    Cells_AreaShape_Zernike_2_2  Cells_AreaShape_Zernike_3_1  \
# 0                      0.57370                      0.50690
# 1                      0.58096                      0.53694
# 2                      0.59116                      0.50418
#
#    Cells_AreaShape_Zernike_5_1  Cells_AreaShape_Zernike_6_2  \
# 0                      0.56160                      0.27321
# 1                      0.55009                      0.28114
# 2                      0.55679                      0.29305
#
#    Cells_AreaShape_Zernike_7_1  Cells_AreaShape_Zernike_7_7  \
# 0                      0.45448                      0.83747
# 1                      0.53594                      0.86929
# 2                      0.49221                      0.87813
#
#    Cells_AreaShape_Zernike_9_3  Cells_Correlation_Correlation_DNA_AGP  ...  \
# 0                      0.68635                                0.68973  ...
# 1                      0.66026                                0.71317  ...
# 2                      0.71747                                0.72229  ...
#
#    Nuclei_Texture_SumAverage_AGP_5_0  Nuclei_Texture_SumEntropy_AGP_10_0  \
# 0                            0.16426                             0.22701
# 1                            0.18411                             0.23932
# 2                            0.17564                             0.23366
#
#    Nuclei_Texture_SumEntropy_AGP_20_0  Nuclei_Texture_SumEntropy_AGP_5_0  \
# 0                             0.20854                            0.22897
# 1                             0.21854                            0.24763
# 2                             0.21743                            0.23448
#
#    Nuclei_Texture_SumEntropy_DNA_10_0  Nuclei_Texture_SumEntropy_DNA_20_0  \
# 0                             0.53738                             0.43547
# 1                             0.56995                             0.47084
# 2                             0.56980                             0.47254
#
#    Nuclei_Texture_SumEntropy_Mito_5_0  Nuclei_Texture_SumVariance_DNA_5_0  \
# 0                             0.41635                             0.28933
# 1                             0.37764                             0.32148
# 2                             0.39575                             0.31969
#
#    Nuclei_Texture_Variance_DNA_20_0  Nuclei_Texture_Variance_DNA_5_0
# 0                           0.34017                          0.31368
# 1                           0.36964                          0.34328
# 2                           0.36626                          0.34086
#
# [3 rows x 588 columns]

# %%
# VAE of one layer
encoder_architecture = [250]
decoder_architecture = [250]

# %%
# model from optimal hyperparameters for onelayer obtained from 1.optimize
cp_vae = VAE(
    input_dim=train_features_df.shape[1],
    latent_dim=10,
    batch_size=96,
    encoder_batch_norm=True,
    epochs=100,
    learning_rate=0.001,
    encoder_architecture=encoder_architecture,
    decoder_architecture=decoder_architecture,
    beta=1,
    verbose=True,
)
cp_vae.compile_vae()
# Out:
# /home/ubuntu/miniconda3/envs/cell-painting-vae/lib/python3.7/site-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
cp_vae.train(x_train=train_features_df, x_test=valid_features_df)
# Out:
# Epoch 1/100
# 84/84 [==============================] - 3s 12ms/step - loss: 33.8366 - recon: 31.2544 - kl: 2.5822 - mmd: 0.0000e+00 - val_loss: 24.3519 - val_recon: 18.5942 - val_kl: 5.7577 - val_mmd: 0.0000e+00
# Epoch 2/100
# 84/84 [==============================] - 1s 7ms/step - loss: 9.7055 - recon: 7.9213 - kl: 1.7842 - mmd: 0.0000e+00 - val_loss: 15.3030 - val_recon: 10.6274 - val_kl: 4.6756 - val_mmd: 0.0000e+00
# Epoch 3/100
# 84/84 [==============================] - 1s 7ms/step - loss: 7.4154 - recon: 5.9901 - kl: 1.4253 - mmd: 0.0000e+00 - val_loss: 11.5911 - val_recon: 7.9310 - val_kl: 3.6600 - val_mmd: 0.0000e+00
# Epoch 4/100
# 84/84 [==============================] - 1s 7ms/step - loss: 6.0106 - recon: 4.8913 - kl: 1.1193 - mmd: 0.0000e+00 - val_loss: 6.1713 - val_recon: 4.8614 - val_kl: 1.3099 - val_mmd: 0.0000e+00
# Epoch 5/100
# 84/84 [==============================] - 1s 7ms/step - loss: 5.2706 - recon: 4.2819 - kl: 0.9887 - mmd: 0.0000e+00 - val_loss: 5.4654 - val_recon: 4.1963 - val_kl: 1.2690 - val_mmd: 0.0000e+00
# Epoch 6/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.8635 - recon: 3.9525 - kl: 0.9110 - mmd: 0.0000e+00 - val_loss: 4.7289 - val_recon: 3.7735 - val_kl: 0.9553 - val_mmd: 0.0000e+00
# Epoch 7/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.5614 - recon: 3.7026 - kl: 0.8588 - mmd: 0.0000e+00 - val_loss: 4.4840 - val_recon: 3.6523 - val_kl: 0.8317 - val_mmd: 0.0000e+00
# Epoch 8/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.4540 - recon: 3.6218 - kl: 0.8322 - mmd: 0.0000e+00 - val_loss: 4.3217 - val_recon: 3.5130 - val_kl: 0.8087 - val_mmd: 0.0000e+00
# Epoch 9/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.4368 - recon: 3.6180 - kl: 0.8188 - mmd: 0.0000e+00 - val_loss: 4.1512 - val_recon: 3.3372 - val_kl: 0.8140 - val_mmd: 0.0000e+00
# Epoch 10/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.3465 - recon: 3.5338 - kl: 0.8127 - mmd: 0.0000e+00 - val_loss: 4.2051 - val_recon: 3.3963 - val_kl: 0.8088 - val_mmd: 0.0000e+00
# Epoch 11/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.2713 - recon: 3.4527 - kl: 0.8186 - mmd: 0.0000e+00 - val_loss: 4.2024 - val_recon: 3.2860 - val_kl: 0.9164 - val_mmd: 0.0000e+00
# Epoch 12/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.2273 - recon: 3.4071 - kl: 0.8202 - mmd: 0.0000e+00 - val_loss: 4.1533 - val_recon: 3.3957 - val_kl: 0.7576 - val_mmd: 0.0000e+00
# Epoch 13/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.2083 - recon: 3.3837 - kl: 0.8246 - mmd: 0.0000e+00 - val_loss: 4.0753 - val_recon: 3.2767 - val_kl: 0.7986 - val_mmd: 0.0000e+00
# Epoch 14/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.1652 - recon: 3.3257 - kl: 0.8395 - mmd: 0.0000e+00 - val_loss: 4.0782 - val_recon: 3.1636 - val_kl: 0.9146 - val_mmd: 0.0000e+00
# Epoch 15/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.1687 - recon: 3.3423 - kl: 0.8264 - mmd: 0.0000e+00 - val_loss: 4.0786 - val_recon: 3.1547 - val_kl: 0.9239 - val_mmd: 0.0000e+00
# Epoch 16/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.1438 - recon: 3.3142 - kl: 0.8296 - mmd: 0.0000e+00 - val_loss: 4.0138 - val_recon: 3.0947 - val_kl: 0.9191 - val_mmd: 0.0000e+00
# Epoch 17/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.1365 - recon: 3.3053 - kl: 0.8312 - mmd: 0.0000e+00 - val_loss: 3.9871 - val_recon: 3.1534 - val_kl: 0.8336 - val_mmd: 0.0000e+00
# Epoch 18/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.1561 - recon: 3.2998 - kl: 0.8563 - mmd: 0.0000e+00 - val_loss: 4.1517 - val_recon: 3.3148 - val_kl: 0.8369 - val_mmd: 0.0000e+00
# Epoch 19/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.1253 - recon: 3.2755 - kl: 0.8497 - mmd: 0.0000e+00 - val_loss: 4.0588 - val_recon: 3.0956 - val_kl: 0.9632 - val_mmd: 0.0000e+00
# Epoch 20/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.1161 - recon: 3.2617 - kl: 0.8543 - mmd: 0.0000e+00 - val_loss: 4.1214 - val_recon: 3.3198 - val_kl: 0.8016 - val_mmd: 0.0000e+00
# Epoch 21/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.0958 - recon: 3.2262 - kl: 0.8696 - mmd: 0.0000e+00 - val_loss: 4.0167 - val_recon: 3.0381 - val_kl: 0.9786 - val_mmd: 0.0000e+00
# Epoch 22/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.0894 - recon: 3.2282 - kl: 0.8612 - mmd: 0.0000e+00 - val_loss: 3.9813 - val_recon: 3.0081 - val_kl: 0.9732 - val_mmd: 0.0000e+00
# Epoch 23/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.1673 - recon: 3.2941 - kl: 0.8732 - mmd: 0.0000e+00 - val_loss: 4.1030 - val_recon: 3.1381 - val_kl: 0.9649 - val_mmd: 0.0000e+00
# Epoch 24/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.0972 - recon: 3.2240 - kl: 0.8731 - mmd: 0.0000e+00 - val_loss: 3.8884 - val_recon: 2.9882 - val_kl: 0.9002 - val_mmd: 0.0000e+00
# Epoch 25/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.0823 - recon: 3.2067 - kl: 0.8756 - mmd: 0.0000e+00 - val_loss: 3.8865 - val_recon: 2.9437 - val_kl: 0.9428 - val_mmd: 0.0000e+00
# Epoch 26/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.0978 - recon: 3.2268 - kl: 0.8710 - mmd: 0.0000e+00 - val_loss: 4.0583 - val_recon: 3.2611 - val_kl: 0.7972 - val_mmd: 0.0000e+00
# Epoch 27/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.0365 - recon: 3.1715 - kl: 0.8650 - mmd: 0.0000e+00 - val_loss: 4.1389 - val_recon: 3.2672 - val_kl: 0.8717 - val_mmd: 0.0000e+00
# Epoch 28/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.0261 - recon: 3.1427 - kl: 0.8834 - mmd: 0.0000e+00 - val_loss: 3.9269 - val_recon: 3.0491 - val_kl: 0.8778 - val_mmd: 0.0000e+00
# Epoch 29/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.0609 - recon: 3.1723 - kl: 0.8886 - mmd: 0.0000e+00 - val_loss: 3.9355 - val_recon: 3.0911 - val_kl: 0.8444 - val_mmd: 0.0000e+00
# Epoch 30/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.0476 - recon: 3.1739 - kl: 0.8737 - mmd: 0.0000e+00 - val_loss: 3.8064 - val_recon: 2.8544 - val_kl: 0.9520 - val_mmd: 0.0000e+00
# Epoch 31/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.0259 - recon: 3.1441 - kl: 0.8818 - mmd: 0.0000e+00 - val_loss: 4.0079 - val_recon: 3.0337 - val_kl: 0.9741 - val_mmd: 0.0000e+00
# Epoch 32/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.0665 - recon: 3.1696 - kl: 0.8969 - mmd: 0.0000e+00 - val_loss: 3.9913 - val_recon: 2.8857 - val_kl: 1.1057 - val_mmd: 0.0000e+00
# Epoch 33/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.0002 - recon: 3.1071 - kl: 0.8931 - mmd: 0.0000e+00 - val_loss: 4.0203 - val_recon: 3.1596 - val_kl: 0.8607 - val_mmd: 0.0000e+00
# Epoch 34/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.0272 - recon: 3.1387 - kl: 0.8885 - mmd: 0.0000e+00 - val_loss: 3.8957 - val_recon: 2.9167 - val_kl: 0.9789 - val_mmd: 0.0000e+00
# Epoch 35/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.0339 - recon: 3.1214 - kl: 0.9125 - mmd: 0.0000e+00 - val_loss: 3.8558 - val_recon: 2.9330 - val_kl: 0.9228 - val_mmd: 0.0000e+00
# Epoch 36/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.9918 - recon: 3.0923 - kl: 0.8995 - mmd: 0.0000e+00 - val_loss: 3.8563 - val_recon: 2.9831 - val_kl: 0.8733 - val_mmd: 0.0000e+00
# Epoch 37/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.9730 - recon: 3.0610 - kl: 0.9120 - mmd: 0.0000e+00 - val_loss: 4.0518 - val_recon: 3.0978 - val_kl: 0.9539 - val_mmd: 0.0000e+00
# Epoch 38/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.9859 - recon: 3.0776 - kl: 0.9084 - mmd: 0.0000e+00 - val_loss: 3.8312 - val_recon: 2.9172 - val_kl: 0.9140 - val_mmd: 0.0000e+00
# Epoch 39/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.9966 - recon: 3.0778 - kl: 0.9188 - mmd: 0.0000e+00 - val_loss: 3.8578 - val_recon: 2.9859 - val_kl: 0.8719 - val_mmd: 0.0000e+00
# Epoch 40/100
# 84/84 [==============================] - 1s 7ms/step - loss: 4.0161 - recon: 3.0786 - kl: 0.9374 - mmd: 0.0000e+00 - val_loss: 3.9558 - val_recon: 2.8971 - val_kl: 1.0587 - val_mmd: 0.0000e+00
# Epoch 41/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.9499 - recon: 3.0209 - kl: 0.9291 - mmd: 0.0000e+00 - val_loss: 3.9753 - val_recon: 2.8826 - val_kl: 1.0927 - val_mmd: 0.0000e+00
# Epoch 42/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.9738 - recon: 3.0312 - kl: 0.9426 - mmd: 0.0000e+00 - val_loss: 3.8882 - val_recon: 2.8932 - val_kl: 0.9950 - val_mmd: 0.0000e+00
# Epoch 43/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.9131 - recon: 2.9680 - kl: 0.9451 - mmd: 0.0000e+00 - val_loss: 4.0115 - val_recon: 3.0666 - val_kl: 0.9449 - val_mmd: 0.0000e+00
# Epoch 44/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.9376 - recon: 2.9725 - kl: 0.9651 - mmd: 0.0000e+00 - val_loss: 3.7627 - val_recon: 2.6547 - val_kl: 1.1080 - val_mmd: 0.0000e+00
# Epoch 45/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.9484 - recon: 2.9739 - kl: 0.9745 - mmd: 0.0000e+00 - val_loss: 3.7751 - val_recon: 2.7227 - val_kl: 1.0524 - val_mmd: 0.0000e+00
# Epoch 46/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.9027 - recon: 2.9222 - kl: 0.9805 - mmd: 0.0000e+00 - val_loss: 3.7572 - val_recon: 2.7691 - val_kl: 0.9881 - val_mmd: 0.0000e+00
# Epoch 47/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.8830 - recon: 2.8878 - kl: 0.9952 - mmd: 0.0000e+00 - val_loss: 3.8857 - val_recon: 2.9531 - val_kl: 0.9326 - val_mmd: 0.0000e+00
# Epoch 48/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.9054 - recon: 2.9116 - kl: 0.9938 - mmd: 0.0000e+00 - val_loss: 3.8683 - val_recon: 2.8385 - val_kl: 1.0298 - val_mmd: 0.0000e+00
# Epoch 49/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.8939 - recon: 2.9012 - kl: 0.9927 - mmd: 0.0000e+00 - val_loss: 3.9082 - val_recon: 2.7806 - val_kl: 1.1275 - val_mmd: 0.0000e+00
# Epoch 50/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.8853 - recon: 2.8988 - kl: 0.9865 - mmd: 0.0000e+00 - val_loss: 3.9915 - val_recon: 2.7515 - val_kl: 1.2399 - val_mmd: 0.0000e+00
# Epoch 51/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.8500 - recon: 2.8473 - kl: 1.0027 - mmd: 0.0000e+00 - val_loss: 3.6724 - val_recon: 2.6062 - val_kl: 1.0663 - val_mmd: 0.0000e+00
# Epoch 52/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.8762 - recon: 2.8766 - kl: 0.9997 - mmd: 0.0000e+00 - val_loss: 3.7299 - val_recon: 2.7127 - val_kl: 1.0172 - val_mmd: 0.0000e+00
# Epoch 53/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.8743 - recon: 2.8741 - kl: 1.0002 - mmd: 0.0000e+00 - val_loss: 3.7076 - val_recon: 2.6221 - val_kl: 1.0855 - val_mmd: 0.0000e+00
# Epoch 54/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.8179 - recon: 2.8214 - kl: 0.9965 - mmd: 0.0000e+00 - val_loss: 3.6465 - val_recon: 2.6888 - val_kl: 0.9577 - val_mmd: 0.0000e+00
# Epoch 55/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.7996 - recon: 2.7986 - kl: 1.0010 - mmd: 0.0000e+00 - val_loss: 3.7307 - val_recon: 2.5968 - val_kl: 1.1338 - val_mmd: 0.0000e+00
# Epoch 56/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.7668 - recon: 2.7865 - kl: 0.9803 - mmd: 0.0000e+00 - val_loss: 3.7187 - val_recon: 2.6958 - val_kl: 1.0229 - val_mmd: 0.0000e+00
# Epoch 57/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.7854 - recon: 2.7874 - kl: 0.9979 - mmd: 0.0000e+00 - val_loss: 3.6531 - val_recon: 2.5225 - val_kl: 1.1306 - val_mmd: 0.0000e+00
# Epoch 58/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.8258 - recon: 2.8124 - kl: 1.0134 - mmd: 0.0000e+00 - val_loss: 3.8356 - val_recon: 2.7807 - val_kl: 1.0549 - val_mmd: 0.0000e+00
# Epoch 59/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.8096 - recon: 2.8067 - kl: 1.0029 - mmd: 0.0000e+00 - val_loss: 3.7070 - val_recon: 2.7434 - val_kl: 0.9636 - val_mmd: 0.0000e+00
# Epoch 60/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.7610 - recon: 2.7606 - kl: 1.0004 - mmd: 0.0000e+00 - val_loss: 3.6299 - val_recon: 2.5737 - val_kl: 1.0562 - val_mmd: 0.0000e+00
# Epoch 61/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.7719 - recon: 2.7738 - kl: 0.9982 - mmd: 0.0000e+00 - val_loss: 3.4744 - val_recon: 2.4547 - val_kl: 1.0197 - val_mmd: 0.0000e+00
# Epoch 62/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.7519 - recon: 2.7617 - kl: 0.9901 - mmd: 0.0000e+00 - val_loss: 3.8030 - val_recon: 2.4976 - val_kl: 1.3054 - val_mmd: 0.0000e+00
# Epoch 63/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.7286 - recon: 2.7346 - kl: 0.9940 - mmd: 0.0000e+00 - val_loss: 3.6906 - val_recon: 2.5940 - val_kl: 1.0965 - val_mmd: 0.0000e+00
# Epoch 64/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.7241 - recon: 2.7380 - kl: 0.9862 - mmd: 0.0000e+00 - val_loss: 3.8213 - val_recon: 2.9422 - val_kl: 0.8791 - val_mmd: 0.0000e+00
# Epoch 65/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.7396 - recon: 2.7648 - kl: 0.9748 - mmd: 0.0000e+00 - val_loss: 3.6314 - val_recon: 2.6581 - val_kl: 0.9734 - val_mmd: 0.0000e+00
# Epoch 66/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.7099 - recon: 2.7301 - kl: 0.9798 - mmd: 0.0000e+00 - val_loss: 3.5572 - val_recon: 2.5650 - val_kl: 0.9922 - val_mmd: 0.0000e+00
# Epoch 67/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.7310 - recon: 2.7444 - kl: 0.9866 - mmd: 0.0000e+00 - val_loss: 3.5089 - val_recon: 2.4810 - val_kl: 1.0279 - val_mmd: 0.0000e+00
# Epoch 68/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.6687 - recon: 2.6983 - kl: 0.9704 - mmd: 0.0000e+00 - val_loss: 3.5878 - val_recon: 2.6011 - val_kl: 0.9867 - val_mmd: 0.0000e+00
# Epoch 69/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.6808 - recon: 2.6981 - kl: 0.9827 - mmd: 0.0000e+00 - val_loss: 3.6462 - val_recon: 2.6179 - val_kl: 1.0283 - val_mmd: 0.0000e+00
# Epoch 70/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.6724 - recon: 2.6996 - kl: 0.9727 - mmd: 0.0000e+00 - val_loss: 3.5769 - val_recon: 2.5902 - val_kl: 0.9867 - val_mmd: 0.0000e+00
# Epoch 71/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.6166 - recon: 2.6534 - kl: 0.9632 - mmd: 0.0000e+00 - val_loss: 3.4466 - val_recon: 2.4383 - val_kl: 1.0084 - val_mmd: 0.0000e+00
# Epoch 72/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.6389 - recon: 2.6742 - kl: 0.9647 - mmd: 0.0000e+00 - val_loss: 3.5665 - val_recon: 2.4796 - val_kl: 1.0869 - val_mmd: 0.0000e+00
# Epoch 73/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.6037 - recon: 2.6349 - kl: 0.9688 - mmd: 0.0000e+00 - val_loss: 3.4005 - val_recon: 2.3957 - val_kl: 1.0048 - val_mmd: 0.0000e+00
# Epoch 74/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.6431 - recon: 2.6585 - kl: 0.9846 - mmd: 0.0000e+00 - val_loss: 3.4521 - val_recon: 2.4611 - val_kl: 0.9910 - val_mmd: 0.0000e+00
# Epoch 75/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.5709 - recon: 2.6088 - kl: 0.9621 - mmd: 0.0000e+00 - val_loss: 3.5139 - val_recon: 2.5182 - val_kl: 0.9956 - val_mmd: 0.0000e+00
# Epoch 76/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.6362 - recon: 2.6750 - kl: 0.9611 - mmd: 0.0000e+00 - val_loss: 3.3447 - val_recon: 2.3106 - val_kl: 1.0341 - val_mmd: 0.0000e+00
# Epoch 77/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.5969 - recon: 2.6327 - kl: 0.9642 - mmd: 0.0000e+00 - val_loss: 3.5264 - val_recon: 2.6047 - val_kl: 0.9217 - val_mmd: 0.0000e+00
# Epoch 78/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.6305 - recon: 2.6444 - kl: 0.9861 - mmd: 0.0000e+00 - val_loss: 3.6357 - val_recon: 2.7440 - val_kl: 0.8917 - val_mmd: 0.0000e+00
# Epoch 79/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.6025 - recon: 2.6271 - kl: 0.9753 - mmd: 0.0000e+00 - val_loss: 3.4815 - val_recon: 2.5008 - val_kl: 0.9807 - val_mmd: 0.0000e+00
# Epoch 80/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.5970 - recon: 2.6359 - kl: 0.9611 - mmd: 0.0000e+00 - val_loss: 3.4748 - val_recon: 2.4017 - val_kl: 1.0732 - val_mmd: 0.0000e+00
# Epoch 81/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.5766 - recon: 2.6112 - kl: 0.9654 - mmd: 0.0000e+00 - val_loss: 3.4824 - val_recon: 2.4879 - val_kl: 0.9945 - val_mmd: 0.0000e+00
# Epoch 82/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.6113 - recon: 2.6295 - kl: 0.9818 - mmd: 0.0000e+00 - val_loss: 3.4346 - val_recon: 2.4006 - val_kl: 1.0340 - val_mmd: 0.0000e+00
# Epoch 83/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.5535 - recon: 2.5780 - kl: 0.9755 - mmd: 0.0000e+00 - val_loss: 3.4652 - val_recon: 2.4722 - val_kl: 0.9930 - val_mmd: 0.0000e+00
# Epoch 84/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.6073 - recon: 2.6276 - kl: 0.9797 - mmd: 0.0000e+00 - val_loss: 3.4766 - val_recon: 2.5113 - val_kl: 0.9653 - val_mmd: 0.0000e+00
# Epoch 85/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.5703 - recon: 2.5957 - kl: 0.9746 - mmd: 0.0000e+00 - val_loss: 3.5011 - val_recon: 2.4194 - val_kl: 1.0817 - val_mmd: 0.0000e+00
# Epoch 86/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.5294 - recon: 2.5545 - kl: 0.9749 - mmd: 0.0000e+00 - val_loss: 3.4168 - val_recon: 2.4300 - val_kl: 0.9868 - val_mmd: 0.0000e+00
# Epoch 87/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.5299 - recon: 2.5523 - kl: 0.9776 - mmd: 0.0000e+00 - val_loss: 3.3610 - val_recon: 2.3331 - val_kl: 1.0280 - val_mmd: 0.0000e+00
# Epoch 88/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.5560 - recon: 2.5675 - kl: 0.9885 - mmd: 0.0000e+00 - val_loss: 3.3783 - val_recon: 2.2423 - val_kl: 1.1360 - val_mmd: 0.0000e+00
# Epoch 89/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.5356 - recon: 2.5432 - kl: 0.9924 - mmd: 0.0000e+00 - val_loss: 3.4066 - val_recon: 2.4373 - val_kl: 0.9693 - val_mmd: 0.0000e+00
# Epoch 90/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.5549 - recon: 2.5610 - kl: 0.9939 - mmd: 0.0000e+00 - val_loss: 3.4610 - val_recon: 2.4389 - val_kl: 1.0221 - val_mmd: 0.0000e+00
# Epoch 91/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.5334 - recon: 2.5553 - kl: 0.9782 - mmd: 0.0000e+00 - val_loss: 3.5271 - val_recon: 2.4982 - val_kl: 1.0289 - val_mmd: 0.0000e+00
# Epoch 92/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.5602 - recon: 2.5717 - kl: 0.9885 - mmd: 0.0000e+00 - val_loss: 3.5412 - val_recon: 2.4136 - val_kl: 1.1276 - val_mmd: 0.0000e+00
# Epoch 93/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.5278 - recon: 2.5516 - kl: 0.9762 - mmd: 0.0000e+00 - val_loss: 3.3513 - val_recon: 2.2871 - val_kl: 1.0642 - val_mmd: 0.0000e+00
# Epoch 94/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.5560 - recon: 2.5601 - kl: 0.9959 - mmd: 0.0000e+00 - val_loss: 3.3925 - val_recon: 2.4019 - val_kl: 0.9906 - val_mmd: 0.0000e+00
# Epoch 95/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.5587 - recon: 2.5704 - kl: 0.9883 - mmd: 0.0000e+00 - val_loss: 3.3142 - val_recon: 2.3521 - val_kl: 0.9621 - val_mmd: 0.0000e+00
# Epoch 96/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.4992 - recon: 2.5013 - kl: 0.9979 - mmd: 0.0000e+00 - val_loss: 3.8159 - val_recon: 2.6718 - val_kl: 1.1441 - val_mmd: 0.0000e+00
# Epoch 97/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.4814 - recon: 2.4886 - kl: 0.9928 - mmd: 0.0000e+00 - val_loss: 3.4248 - val_recon: 2.3710 - val_kl: 1.0538 - val_mmd: 0.0000e+00
# Epoch 98/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.5077 - recon: 2.4945 - kl: 1.0132 - mmd: 0.0000e+00 - val_loss: 3.3351 - val_recon: 2.2981 - val_kl: 1.0370 - val_mmd: 0.0000e+00
# Epoch 99/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.5447 - recon: 2.5441 - kl: 1.0006 - mmd: 0.0000e+00 - val_loss: 3.3559 - val_recon: 2.3431 - val_kl: 1.0129 - val_mmd: 0.0000e+00
# Epoch 100/100
# 84/84 [==============================] - 1s 7ms/step - loss: 3.5023 - recon: 2.4948 - kl: 1.0075 - mmd: 0.0000e+00 - val_loss: 3.3413 - val_recon: 2.3396 - val_kl: 1.0017 - val_mmd: 0.0000e+00

# %%
cp_vae.vae

# %%
cp_vae.vae.evaluate(test_features_df)
# Out:
# 33/33 [==============================] - 0s 2ms/step - loss: 3.3118 - recon: 2.3810 - kl: 0.9308 - mmd: 0.0000e+00
# [3.3118042945861816, 2.380993127822876, 0.9308114647865295, 0.0]

# %%
# Save training performance
history_df = pd.DataFrame(cp_vae.vae.history.history)
history_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
history_df.to_csv('training_data/level5_training_vanilla_leaveIntermediateOut.csv')

# %%
plt.figure(figsize=(10, 5))
plt.plot(history_df["loss"], label="Training data")
plt.plot(history_df["val_loss"], label="Validation data")
plt.title("Loss for VAE training on Cell Painting Level 5 data")
plt.ylabel("MSE + KL Divergence")
plt.xlabel("No. Epoch")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/cell-painting-vae/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/miniconda3/envs/cell-painting-vae/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/miniconda3/envs/cell-painting-vae/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'loss'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_7827/1127965018.py in <module>
#       1 plt.figure(figsize=(10, 5))
# ----> 2 plt.plot(history_df["loss"], label="Training data")
#       3 plt.plot(history_df["val_loss"], label="Validation data")
#       4 plt.title("Loss for VAE training on Cell Painting Level 5 data")
#       5 plt.ylabel("MSE + KL Divergence")
#
# ~/miniconda3/envs/cell-painting-vae/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/miniconda3/envs/cell-painting-vae/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'loss'

# %%
reconstruction = pd.DataFrame(cp_vae.vae.predict(test_features_df), columns=cp_features)
(sum(sum((np.array(test_features_df) - np.array(reconstruction)) ** 2))) ** 0.5
# Out:
# 47.86316166790343

# %%
#latent space heatmap
fig, ax = plt.subplots(figsize=(10, 10))
encoder = cp_vae.encoder_block["encoder"]
latent = np.array(encoder.predict(test_features_df)[2])
seaborn.heatmap(latent, ax=ax)
# Out:
# <AxesSubplot:>

# %%
#original vs reconstructed heatmap
reconstruction = pd.DataFrame(cp_vae.vae.predict(test_features_df), columns=cp_features)
pca = PCA(n_components=2).fit(test_features_df)
pca_reconstructed_latent_df = pd.DataFrame(pca.transform(reconstruction))
pca_test_latent_df = pd.DataFrame(pca.transform(test_features_df))

# %%
figure(figsize=(10, 10), dpi=80)
plt.scatter(pca_test_latent_df[0],pca_test_latent_df[1], marker = ".", alpha = 0.5)
plt.scatter(pca_reconstructed_latent_df[0],pca_reconstructed_latent_df[1], marker = ".", alpha = 0.5)

# %%
pca = PCA(n_components=50).fit(test_features_df)
pca_reconstructed_latent_df = pd.DataFrame(pca.transform(reconstruction))
pca_test_latent_df = pd.DataFrame(pca.transform(test_features_df))

# %%
figure(figsize=(10, 10), dpi=80)
plt.scatter(pca_test_latent_df[21],pca_test_latent_df[43], marker = ".", alpha = 0.5)
plt.scatter(pca_reconstructed_latent_df[21],pca_reconstructed_latent_df[43], marker = ".", alpha = 0.5)

# %%
#difference between original and reconstructed heatmap
difference = abs(reconstruction - test_features_df)
fig, ax = plt.subplots(figsize=(10, 10))
seaborn.heatmap(difference, ax=ax, cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
#encoder heatmap
weights = cp_vae.encoder_block["encoder"].get_weights()
fig, ax = plt.subplots(figsize=(10, 10))
seaborn.heatmap(weights[0], ax=ax)
# Out:
# <AxesSubplot:>

# %%
decoder = cp_vae.decoder_block["decoder"]

# %%
pca_training = PCA(n_components=2).fit(train_features_df)

simulated_df = pd.DataFrame(np.random.normal(size=(8294, 10)), columns=np.arange(0,10))
reconstruction_of_simulated = decoder.predict(simulated_df)
pca_reconstruction_of_simulated = pd.DataFrame(pca_training.transform(reconstruction_of_simulated))
pca_train_latent_df = pd.DataFrame(pca_training.transform(train_features_df))

fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(16,8), sharey = True, sharex = True)
ax1.scatter(pca_train_latent_df[0],pca_train_latent_df[1], marker = ".", alpha = 0.5)
ax2.scatter(pca_reconstruction_of_simulated[0],pca_reconstruction_of_simulated[1], marker = ".", alpha = 0.5)

# %%
from scipy.spatial.distance import directed_hausdorff
max(directed_hausdorff(reconstruction_of_simulated, train_features_df)[0],directed_hausdorff(train_features_df,reconstruction_of_simulated)[0])
# Out:
# 5.855550175784144

# %%
#NOTE: IF YOU RUN THIS, YOU WILL NOT BE ABLE TO REPRODUCE THE EXACT RESULTS IN THE EXPERIMENT
latent_complete = np.array(encoder.predict(complete_features_df)[2])
latent_df = pd.DataFrame(latent_complete)
latent_df.to_csv("../3.application/level5Latent_vanilla_leaveIntermediateOut.csv")

# %%
# reducer = umap.UMAP()
# latent_embedding = reducer.fit_transform(latent_df)

# %%
# figure(figsize=(10, 10), dpi=80)
# plt.scatter(
#     latent_embedding[:, 0],
#     latent_embedding[:, 1],
#     marker = '.'
# )

# %%
#NOTE: IF YOU RUN THIS, YOU WILL NOT BE ABLE TO REPRODUCE THE EXACT RESULTS IN THE EXPERIMENT
decoder.save("models/level5Decoder_vanilla_leaveIntermediateOut")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2021-12-23 18:01:38.653213: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: models/level5Decoder_vanilla_leaveIntermediateOut/assets

# %%
encoder.save("models/level5Encoder_vanilla_leaveIntermediateOut")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: models/level5Encoder_vanilla_leaveIntermediateOut/assets
