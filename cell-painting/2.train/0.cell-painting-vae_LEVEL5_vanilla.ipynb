# %% [markdown]
# # Train a VAE on Cell Painting LINCS Data

# %%
import sys
import pathlib
import numpy as np
import pandas as pd
sys.path.insert(0, "../../scripts")
from utils import load_data


from pycytominer.cyto_utils import infer_cp_features


import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

from sklearn.decomposition import PCA
from tensorflow import keras

from vae import VAE

from tensorflow.keras.models import Model, Sequential
import seaborn
import random as python_random
import tensorflow as tf
import umap

# %%
# %load_ext nb_black

# %%
# np.random.seed(123)
# python_random.seed(123)
# tf.random.set_random_seed(1234)

# %%
data_splits = ["train", "test", "valid", "complete"]
data_dict = load_data(data_splits)

# %%
# Prepare data for training
meta_features = infer_cp_features(data_dict["train"], metadata=True)
cp_features = infer_cp_features(data_dict["train"])

train_features_df = data_dict["train"].reindex(cp_features, axis="columns")
train_meta_df = data_dict["train"].reindex(meta_features, axis="columns")

test_features_df = data_dict["test"].reindex(cp_features, axis="columns")
test_meta_df = data_dict["test"].reindex(meta_features, axis="columns")

valid_features_df = data_dict["valid"].reindex(cp_features, axis="columns")
valid_meta_df = data_dict["valid"].reindex(meta_features, axis="columns")

complete_features_df = data_dict["complete"].reindex(cp_features, axis="columns")
complete_meta_df = data_dict["complete"].reindex(meta_features, axis="columns")

# %%
print(train_features_df.shape)
train_features_df.head(3)
# Out:
# (8294, 588)
#    Cells_AreaShape_FormFactor  Cells_AreaShape_Orientation  \
# 0                     0.56071                      0.63708
# 1                     0.59702                      0.55453
# 2                     0.64623                      0.59825
#
#    Cells_AreaShape_Zernike_2_2  Cells_AreaShape_Zernike_3_1  \
# 0                      0.57961                      0.51030
# 1                      0.62561                      0.47959
# 2                      0.62822                      0.52100
#
#    Cells_AreaShape_Zernike_5_1  Cells_AreaShape_Zernike_6_2  \
# 0                      0.61695                      0.30869
# 1                      0.59022                      0.33269
# 2                      0.57452                      0.26367
#
#    Cells_AreaShape_Zernike_7_1  Cells_AreaShape_Zernike_7_7  \
# 0                      0.43981                      0.79826
# 1                      0.49875                      0.88042
# 2                      0.48172                      0.86322
#
#    Cells_AreaShape_Zernike_9_3  Cells_Correlation_Correlation_DNA_AGP  ...  \
# 0                      0.72477                                0.68589  ...
# 1                      0.67159                                0.61703  ...
# 2                      0.67588                                0.69732  ...
#
#    Nuclei_Texture_SumAverage_AGP_5_0  Nuclei_Texture_SumEntropy_AGP_10_0  \
# 0                            0.17858                             0.29336
# 1                            0.09030                             0.15088
# 2                            0.18125                             0.23244
#
#    Nuclei_Texture_SumEntropy_AGP_20_0  Nuclei_Texture_SumEntropy_AGP_5_0  \
# 0                             0.26447                            0.30197
# 1                             0.13334                            0.14052
# 2                             0.20723                            0.24062
#
#    Nuclei_Texture_SumEntropy_DNA_10_0  Nuclei_Texture_SumEntropy_DNA_20_0  \
# 0                             0.64786                             0.49525
# 1                             0.59229                             0.49294
# 2                             0.54642                             0.43920
#
#    Nuclei_Texture_SumEntropy_Mito_5_0  Nuclei_Texture_SumVariance_DNA_5_0  \
# 0                             0.53512                             0.40495
# 1                             0.43221                             0.33969
# 2                             0.41183                             0.30375
#
#    Nuclei_Texture_Variance_DNA_20_0  Nuclei_Texture_Variance_DNA_5_0
# 0                           0.46056                          0.43647
# 1                           0.39208                          0.36205
# 2                           0.35385                          0.33266
#
# [3 rows x 588 columns]

# %%
print(test_features_df.shape)
test_features_df.head(3)
# Out:
# (1037, 588)
#    Cells_AreaShape_FormFactor  Cells_AreaShape_Orientation  \
# 0                     0.52664                      0.59293
# 1                     0.61343                      0.57882
# 2                     0.55123                      0.61050
#
#    Cells_AreaShape_Zernike_2_2  Cells_AreaShape_Zernike_3_1  \
# 0                      0.51636                      0.52824
# 1                      0.62454                      0.51049
# 2                      0.53085                      0.65280
#
#    Cells_AreaShape_Zernike_5_1  Cells_AreaShape_Zernike_6_2  \
# 0                      0.54415                      0.23948
# 1                      0.57508                      0.31691
# 2                      0.54356                      0.16767
#
#    Cells_AreaShape_Zernike_7_1  Cells_AreaShape_Zernike_7_7  \
# 0                      0.53361                      0.84625
# 1                      0.49077                      0.89145
# 2                      0.50521                      0.93703
#
#    Cells_AreaShape_Zernike_9_3  Cells_Correlation_Correlation_DNA_AGP  ...  \
# 0                      0.65881                                0.86971  ...
# 1                      0.65811                                0.66082  ...
# 2                      0.77958                                0.63413  ...
#
#    Nuclei_Texture_SumAverage_AGP_5_0  Nuclei_Texture_SumEntropy_AGP_10_0  \
# 0                            0.74413                             0.58353
# 1                            0.12499                             0.20488
# 2                            0.19249                             0.13665
#
#    Nuclei_Texture_SumEntropy_AGP_20_0  Nuclei_Texture_SumEntropy_AGP_5_0  \
# 0                             0.54654                            0.63600
# 1                             0.18676                            0.20580
# 2                             0.13293                            0.13816
#
#    Nuclei_Texture_SumEntropy_DNA_10_0  Nuclei_Texture_SumEntropy_DNA_20_0  \
# 0                             0.50501                             0.39338
# 1                             0.58773                             0.47783
# 2                             0.58333                             0.52931
#
#    Nuclei_Texture_SumEntropy_Mito_5_0  Nuclei_Texture_SumVariance_DNA_5_0  \
# 0                             0.46080                             0.25924
# 1                             0.42619                             0.34683
# 2                             0.31068                             0.40967
#
#    Nuclei_Texture_Variance_DNA_20_0  Nuclei_Texture_Variance_DNA_5_0
# 0                           0.29724                          0.27556
# 1                           0.39642                          0.37092
# 2                           0.48646                          0.45058
#
# [3 rows x 588 columns]

# %%
print(complete_features_df.shape)
complete_features_df.head(3)
# Out:
# (10368, 588)
#    Cells_AreaShape_FormFactor  Cells_AreaShape_Orientation  \
# 0                     0.57016                      0.59500
# 1                     0.54840                      0.53949
# 2                     0.56057                      0.59621
#
#    Cells_AreaShape_Zernike_2_2  Cells_AreaShape_Zernike_3_1  \
# 0                      0.57370                      0.50690
# 1                      0.58096                      0.53694
# 2                      0.59116                      0.50418
#
#    Cells_AreaShape_Zernike_5_1  Cells_AreaShape_Zernike_6_2  \
# 0                      0.56160                      0.27321
# 1                      0.55009                      0.28114
# 2                      0.55679                      0.29305
#
#    Cells_AreaShape_Zernike_7_1  Cells_AreaShape_Zernike_7_7  \
# 0                      0.45448                      0.83747
# 1                      0.53594                      0.86929
# 2                      0.49221                      0.87813
#
#    Cells_AreaShape_Zernike_9_3  Cells_Correlation_Correlation_DNA_AGP  ...  \
# 0                      0.68635                                0.68973  ...
# 1                      0.66026                                0.71317  ...
# 2                      0.71747                                0.72229  ...
#
#    Nuclei_Texture_SumAverage_AGP_5_0  Nuclei_Texture_SumEntropy_AGP_10_0  \
# 0                            0.16426                             0.22701
# 1                            0.18411                             0.23932
# 2                            0.17564                             0.23366
#
#    Nuclei_Texture_SumEntropy_AGP_20_0  Nuclei_Texture_SumEntropy_AGP_5_0  \
# 0                             0.20854                            0.22897
# 1                             0.21854                            0.24763
# 2                             0.21743                            0.23448
#
#    Nuclei_Texture_SumEntropy_DNA_10_0  Nuclei_Texture_SumEntropy_DNA_20_0  \
# 0                             0.53738                             0.43547
# 1                             0.56995                             0.47084
# 2                             0.56980                             0.47254
#
#    Nuclei_Texture_SumEntropy_Mito_5_0  Nuclei_Texture_SumVariance_DNA_5_0  \
# 0                             0.41635                             0.28933
# 1                             0.37764                             0.32148
# 2                             0.39575                             0.31969
#
#    Nuclei_Texture_Variance_DNA_20_0  Nuclei_Texture_Variance_DNA_5_0
# 0                           0.34017                          0.31368
# 1                           0.36964                          0.34328
# 2                           0.36626                          0.34086
#
# [3 rows x 588 columns]

# %%
# VAE of one layer
encoder_architecture = [250]
decoder_architecture = [250]

# %%
# model from optimal hyperparameters for onelayer obtained from 1.optimize
cp_vae = VAE(
    input_dim=train_features_df.shape[1],
    latent_dim=10,
    batch_size=96,
    encoder_batch_norm=True,
    epochs=100,
    learning_rate=0.001,
    encoder_architecture=encoder_architecture,
    decoder_architecture=decoder_architecture,
    beta=1,
    verbose=True,
)
cp_vae.compile_vae()

# %%
cp_vae.train(x_train=train_features_df, x_test=valid_features_df)
# Out:
# Epoch 1/100
# 87/87 [==============================] - 3s 12ms/step - loss: 69.8342 - recon: 30.6702 - kl: 2.8091 - val_loss: 15.9021 - val_recon: 12.4134 - val_kl: 3.4887
# Epoch 2/100
# 87/87 [==============================] - 0s 5ms/step - loss: 10.2461 - recon: 7.6886 - kl: 1.7436 - val_loss: 12.4925 - val_recon: 8.8230 - val_kl: 3.6695
# Epoch 3/100
# 87/87 [==============================] - 0s 5ms/step - loss: 7.4665 - recon: 5.6936 - kl: 1.3355 - val_loss: 8.3335 - val_recon: 5.8617 - val_kl: 2.4718
# Epoch 4/100
# 87/87 [==============================] - 0s 5ms/step - loss: 6.1023 - recon: 4.6997 - kl: 1.1150 - val_loss: 5.8273 - val_recon: 4.4025 - val_kl: 1.4248
# Epoch 5/100
# 87/87 [==============================] - 0s 5ms/step - loss: 5.2908 - recon: 4.1323 - kl: 0.9852 - val_loss: 5.0561 - val_recon: 3.9477 - val_kl: 1.1084
# Epoch 6/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.8435 - recon: 3.8350 - kl: 0.9012 - val_loss: 4.6388 - val_recon: 3.6004 - val_kl: 1.0384
# Epoch 7/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.6107 - recon: 3.7128 - kl: 0.8610 - val_loss: 4.4700 - val_recon: 3.5953 - val_kl: 0.8746
# Epoch 8/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.5284 - recon: 3.5942 - kl: 0.8337 - val_loss: 4.2889 - val_recon: 3.3934 - val_kl: 0.8955
# Epoch 9/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.2474 - recon: 3.5163 - kl: 0.8185 - val_loss: 4.2406 - val_recon: 3.4140 - val_kl: 0.8266
# Epoch 10/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.1189 - recon: 3.4564 - kl: 0.8063 - val_loss: 4.2352 - val_recon: 3.4295 - val_kl: 0.8057
# Epoch 11/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.2225 - recon: 3.4262 - kl: 0.8079 - val_loss: 4.2329 - val_recon: 3.3980 - val_kl: 0.8349
# Epoch 12/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.2416 - recon: 3.4522 - kl: 0.8086 - val_loss: 4.0767 - val_recon: 3.2584 - val_kl: 0.8183
# Epoch 13/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.2708 - recon: 3.4507 - kl: 0.8211 - val_loss: 4.1557 - val_recon: 3.2731 - val_kl: 0.8826
# Epoch 14/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.2829 - recon: 3.4000 - kl: 0.8180 - val_loss: 4.1481 - val_recon: 3.3354 - val_kl: 0.8127
# Epoch 15/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.2767 - recon: 3.3504 - kl: 0.8269 - val_loss: 4.0150 - val_recon: 3.2205 - val_kl: 0.7945
# Epoch 16/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.1591 - recon: 3.2979 - kl: 0.8263 - val_loss: 4.0485 - val_recon: 3.2022 - val_kl: 0.8463
# Epoch 17/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.2312 - recon: 3.3125 - kl: 0.8418 - val_loss: 4.0663 - val_recon: 3.1384 - val_kl: 0.9279
# Epoch 18/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.1200 - recon: 3.2886 - kl: 0.8358 - val_loss: 3.9388 - val_recon: 3.0510 - val_kl: 0.8879
# Epoch 19/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.1604 - recon: 3.2438 - kl: 0.8479 - val_loss: 3.9788 - val_recon: 3.0433 - val_kl: 0.9355
# Epoch 20/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.0753 - recon: 3.2460 - kl: 0.8435 - val_loss: 4.0505 - val_recon: 3.2547 - val_kl: 0.7958
# Epoch 21/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.0142 - recon: 3.2232 - kl: 0.8414 - val_loss: 4.0907 - val_recon: 3.2054 - val_kl: 0.8852
# Epoch 22/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.1730 - recon: 3.2466 - kl: 0.8488 - val_loss: 4.0103 - val_recon: 3.0868 - val_kl: 0.9235
# Epoch 23/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.1824 - recon: 3.2491 - kl: 0.8489 - val_loss: 4.1246 - val_recon: 3.2858 - val_kl: 0.8388
# Epoch 24/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.9083 - recon: 3.2013 - kl: 0.8417 - val_loss: 4.0917 - val_recon: 3.0982 - val_kl: 0.9934
# Epoch 25/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.0512 - recon: 3.2374 - kl: 0.8565 - val_loss: 3.9912 - val_recon: 3.0661 - val_kl: 0.9251
# Epoch 26/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.0135 - recon: 3.1785 - kl: 0.8505 - val_loss: 4.0350 - val_recon: 3.1033 - val_kl: 0.9317
# Epoch 27/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.9556 - recon: 3.1973 - kl: 0.8508 - val_loss: 3.9974 - val_recon: 3.1288 - val_kl: 0.8686
# Epoch 28/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.0304 - recon: 3.2333 - kl: 0.8481 - val_loss: 3.8981 - val_recon: 3.0079 - val_kl: 0.8903
# Epoch 29/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.0679 - recon: 3.1483 - kl: 0.8598 - val_loss: 3.8429 - val_recon: 3.0235 - val_kl: 0.8194
# Epoch 30/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.0698 - recon: 3.1547 - kl: 0.8462 - val_loss: 3.8842 - val_recon: 2.8986 - val_kl: 0.9857
# Epoch 31/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.0423 - recon: 3.1498 - kl: 0.8535 - val_loss: 3.9245 - val_recon: 2.9444 - val_kl: 0.9801
# Epoch 32/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.0538 - recon: 3.1715 - kl: 0.8525 - val_loss: 3.8439 - val_recon: 2.9608 - val_kl: 0.8831
# Epoch 33/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.0218 - recon: 3.1650 - kl: 0.8588 - val_loss: 3.9023 - val_recon: 2.9725 - val_kl: 0.9298
# Epoch 34/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.1100 - recon: 3.1272 - kl: 0.8734 - val_loss: 4.0075 - val_recon: 3.0309 - val_kl: 0.9766
# Epoch 35/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.0336 - recon: 3.1274 - kl: 0.8660 - val_loss: 3.9187 - val_recon: 2.9115 - val_kl: 1.0073
# Epoch 36/100
# 87/87 [==============================] - 0s 5ms/step - loss: 4.0075 - recon: 3.0885 - kl: 0.8671 - val_loss: 3.8527 - val_recon: 2.9933 - val_kl: 0.8594
# Epoch 37/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.9306 - recon: 3.0554 - kl: 0.8609 - val_loss: 3.9015 - val_recon: 3.1324 - val_kl: 0.7691
# Epoch 38/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.9582 - recon: 3.0781 - kl: 0.8749 - val_loss: 3.8325 - val_recon: 2.8909 - val_kl: 0.9415
# Epoch 39/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.9310 - recon: 3.1039 - kl: 0.8782 - val_loss: 3.8643 - val_recon: 2.9413 - val_kl: 0.9230
# Epoch 40/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.9899 - recon: 3.0799 - kl: 0.8854 - val_loss: 3.8022 - val_recon: 2.8511 - val_kl: 0.9510
# Epoch 41/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.9524 - recon: 3.0327 - kl: 0.8867 - val_loss: 3.8728 - val_recon: 2.9113 - val_kl: 0.9615
# Epoch 42/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.9956 - recon: 3.0520 - kl: 0.8891 - val_loss: 3.7536 - val_recon: 2.7438 - val_kl: 1.0099
# Epoch 43/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.8458 - recon: 3.0201 - kl: 0.8854 - val_loss: 3.8406 - val_recon: 2.8868 - val_kl: 0.9537
# Epoch 44/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.8632 - recon: 3.0263 - kl: 0.8865 - val_loss: 3.6843 - val_recon: 2.7514 - val_kl: 0.9329
# Epoch 45/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.9325 - recon: 3.0092 - kl: 0.9173 - val_loss: 3.8185 - val_recon: 2.9355 - val_kl: 0.8830
# Epoch 46/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.8936 - recon: 2.9892 - kl: 0.9140 - val_loss: 3.8714 - val_recon: 2.8306 - val_kl: 1.0408
# Epoch 47/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.8229 - recon: 2.9778 - kl: 0.9165 - val_loss: 3.7635 - val_recon: 2.7327 - val_kl: 1.0308
# Epoch 48/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.7357 - recon: 2.9661 - kl: 0.9056 - val_loss: 3.8176 - val_recon: 2.6700 - val_kl: 1.1477
# Epoch 49/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.8372 - recon: 2.9264 - kl: 0.9416 - val_loss: 3.7383 - val_recon: 2.7810 - val_kl: 0.9573
# Epoch 50/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.7719 - recon: 2.8887 - kl: 0.9405 - val_loss: 3.7542 - val_recon: 2.8373 - val_kl: 0.9169
# Epoch 51/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.7612 - recon: 2.8256 - kl: 0.9521 - val_loss: 3.8299 - val_recon: 2.8549 - val_kl: 0.9750
# Epoch 52/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.7944 - recon: 2.8409 - kl: 0.9445 - val_loss: 3.7142 - val_recon: 2.6055 - val_kl: 1.1087
# Epoch 53/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.8481 - recon: 2.8147 - kl: 0.9474 - val_loss: 3.6249 - val_recon: 2.6004 - val_kl: 1.0245
# Epoch 54/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.8450 - recon: 2.8315 - kl: 0.9581 - val_loss: 3.6417 - val_recon: 2.6168 - val_kl: 1.0249
# Epoch 55/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.7535 - recon: 2.7672 - kl: 0.9586 - val_loss: 3.6451 - val_recon: 2.6051 - val_kl: 1.0399
# Epoch 56/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.8438 - recon: 2.8113 - kl: 0.9642 - val_loss: 3.7359 - val_recon: 2.4722 - val_kl: 1.2636
# Epoch 57/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.6854 - recon: 2.7699 - kl: 0.9420 - val_loss: 3.5858 - val_recon: 2.5920 - val_kl: 0.9938
# Epoch 58/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.6444 - recon: 2.7082 - kl: 0.9474 - val_loss: 3.5951 - val_recon: 2.6435 - val_kl: 0.9516
# Epoch 59/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.6328 - recon: 2.7551 - kl: 0.9427 - val_loss: 3.6588 - val_recon: 2.7004 - val_kl: 0.9584
# Epoch 60/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.6288 - recon: 2.7036 - kl: 0.9611 - val_loss: 3.5586 - val_recon: 2.6105 - val_kl: 0.9481
# Epoch 61/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.6776 - recon: 2.7209 - kl: 0.9511 - val_loss: 3.5007 - val_recon: 2.5464 - val_kl: 0.9543
# Epoch 62/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.7345 - recon: 2.7260 - kl: 0.9441 - val_loss: 3.7095 - val_recon: 2.7292 - val_kl: 0.9803
# Epoch 63/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.5668 - recon: 2.6833 - kl: 0.9418 - val_loss: 3.5039 - val_recon: 2.5548 - val_kl: 0.9491
# Epoch 64/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.6786 - recon: 2.7203 - kl: 0.9470 - val_loss: 3.5882 - val_recon: 2.4930 - val_kl: 1.0952
# Epoch 65/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.6738 - recon: 2.6958 - kl: 0.9599 - val_loss: 3.5571 - val_recon: 2.4641 - val_kl: 1.0930
# Epoch 66/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.7088 - recon: 2.6643 - kl: 0.9624 - val_loss: 3.4892 - val_recon: 2.5145 - val_kl: 0.9747
# Epoch 67/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.6018 - recon: 2.6559 - kl: 0.9412 - val_loss: 3.5666 - val_recon: 2.5288 - val_kl: 1.0378
# Epoch 68/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.6079 - recon: 2.6690 - kl: 0.9524 - val_loss: 3.6832 - val_recon: 2.5794 - val_kl: 1.1037
# Epoch 69/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.5344 - recon: 2.6345 - kl: 0.9528 - val_loss: 3.5224 - val_recon: 2.5821 - val_kl: 0.9404
# Epoch 70/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.6306 - recon: 2.6585 - kl: 0.9461 - val_loss: 3.4363 - val_recon: 2.3808 - val_kl: 1.0555
# Epoch 71/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.4949 - recon: 2.6306 - kl: 0.9519 - val_loss: 3.5033 - val_recon: 2.5771 - val_kl: 0.9263
# Epoch 72/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.6166 - recon: 2.6290 - kl: 0.9562 - val_loss: 3.6050 - val_recon: 2.7061 - val_kl: 0.8990
# Epoch 73/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.5693 - recon: 2.6173 - kl: 0.9549 - val_loss: 3.4791 - val_recon: 2.4906 - val_kl: 0.9885
# Epoch 74/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.6979 - recon: 2.6424 - kl: 0.9525 - val_loss: 3.3945 - val_recon: 2.3836 - val_kl: 1.0108
# Epoch 75/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.5767 - recon: 2.6066 - kl: 0.9666 - val_loss: 3.5021 - val_recon: 2.5768 - val_kl: 0.9254
# Epoch 76/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.5338 - recon: 2.5996 - kl: 0.9552 - val_loss: 3.3855 - val_recon: 2.4435 - val_kl: 0.9420
# Epoch 77/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.5574 - recon: 2.5888 - kl: 0.9529 - val_loss: 3.3772 - val_recon: 2.4035 - val_kl: 0.9737
# Epoch 78/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.5654 - recon: 2.5723 - kl: 0.9603 - val_loss: 3.4869 - val_recon: 2.6106 - val_kl: 0.8763
# Epoch 79/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.5341 - recon: 2.5681 - kl: 0.9547 - val_loss: 3.4834 - val_recon: 2.5085 - val_kl: 0.9749
# Epoch 80/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.6028 - recon: 2.5520 - kl: 0.9648 - val_loss: 3.5203 - val_recon: 2.4027 - val_kl: 1.1177
# Epoch 81/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.5992 - recon: 2.6060 - kl: 0.9553 - val_loss: 3.5090 - val_recon: 2.5674 - val_kl: 0.9416
# Epoch 82/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.4597 - recon: 2.5923 - kl: 0.9653 - val_loss: 3.3192 - val_recon: 2.2819 - val_kl: 1.0373
# Epoch 83/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.4583 - recon: 2.5231 - kl: 0.9655 - val_loss: 3.4469 - val_recon: 2.5360 - val_kl: 0.9109
# Epoch 84/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.4756 - recon: 2.5155 - kl: 0.9771 - val_loss: 3.2657 - val_recon: 2.2996 - val_kl: 0.9661
# Epoch 85/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.4552 - recon: 2.5426 - kl: 0.9682 - val_loss: 3.4084 - val_recon: 2.3492 - val_kl: 1.0592
# Epoch 86/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.5079 - recon: 2.5250 - kl: 0.9722 - val_loss: 3.4931 - val_recon: 2.3137 - val_kl: 1.1794
# Epoch 87/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.4893 - recon: 2.5469 - kl: 0.9779 - val_loss: 3.4182 - val_recon: 2.5055 - val_kl: 0.9128
# Epoch 88/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.4342 - recon: 2.5196 - kl: 0.9714 - val_loss: 3.5564 - val_recon: 2.6431 - val_kl: 0.9133
# Epoch 89/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.4810 - recon: 2.5111 - kl: 0.9822 - val_loss: 3.4779 - val_recon: 2.4504 - val_kl: 1.0275
# Epoch 90/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.5478 - recon: 2.5164 - kl: 0.9916 - val_loss: 3.4692 - val_recon: 2.3801 - val_kl: 1.0890
# Epoch 91/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.4376 - recon: 2.4963 - kl: 0.9819 - val_loss: 3.3256 - val_recon: 2.3731 - val_kl: 0.9526
# Epoch 92/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.4907 - recon: 2.5309 - kl: 0.9894 - val_loss: 3.3185 - val_recon: 2.3582 - val_kl: 0.9602
# Epoch 93/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.5312 - recon: 2.4586 - kl: 0.9896 - val_loss: 3.4074 - val_recon: 2.5118 - val_kl: 0.8957
# Epoch 94/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.4070 - recon: 2.4704 - kl: 0.9841 - val_loss: 3.4914 - val_recon: 2.5080 - val_kl: 0.9834
# Epoch 95/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.5024 - recon: 2.4675 - kl: 0.9840 - val_loss: 3.4758 - val_recon: 2.4989 - val_kl: 0.9769
# Epoch 96/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.5246 - recon: 2.5103 - kl: 0.9960 - val_loss: 3.3103 - val_recon: 2.3006 - val_kl: 1.0097
# Epoch 97/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.4678 - recon: 2.4548 - kl: 0.9968 - val_loss: 3.3904 - val_recon: 2.3841 - val_kl: 1.0064
# Epoch 98/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.5105 - recon: 2.4790 - kl: 0.9887 - val_loss: 3.3790 - val_recon: 2.3024 - val_kl: 1.0766
# Epoch 99/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.4824 - recon: 2.4566 - kl: 1.0020 - val_loss: 3.3419 - val_recon: 2.3019 - val_kl: 1.0400
# Epoch 100/100
# 87/87 [==============================] - 0s 5ms/step - loss: 3.4775 - recon: 2.5129 - kl: 0.9948 - val_loss: 3.3669 - val_recon: 2.3041 - val_kl: 1.0628

# %%
cp_vae.vae

# %%
# cp_vae.vae.evaluate(test_features_df)

# %%
# Save training performance
history_df = pd.DataFrame(cp_vae.vae.history.history)
history_df
# Out:
#          loss      recon        kl   val_loss  val_recon    val_kl
# 0   33.479343  30.670206  2.809134  15.902123  12.413400  3.488723
# 1    9.432255   7.688606  1.743649  12.492504   8.823027  3.669478
# 2    7.029122   5.693624  1.335498   8.333543   5.861746  2.471798
# 3    5.814744   4.699711  1.115032   5.827280   4.402496  1.424783
# 4    5.117502   4.132313  0.985189   5.056069   3.947675  1.108394
# ..        ...        ...       ...        ...        ...       ...
# 95   3.506211   2.510251  0.995960   3.310254   2.300593  1.009662
# 96   3.451513   2.454751  0.996762   3.390445   2.384076  1.006369
# 97   3.467688   2.479002  0.988686   3.379050   2.302411  1.076639
# 98   3.458620   2.456575  1.002044   3.341861   2.301862  1.039998
# 99   3.507632   2.512852  0.994780   3.366862   2.304085  1.062778
#
# [100 rows x 6 columns]

# %%
history_df.to_csv('training_data/level5_training_vanilla.csv')

# %%
plt.figure(figsize=(10, 5))
plt.plot(history_df["loss"], label="Training data")
plt.plot(history_df["val_loss"], label="Validation data")
plt.title("Loss for VAE training on Cell Painting Level 5 data")
plt.ylabel("MSE + KL Divergence")
plt.xlabel("No. Epoch")
plt.legend()
plt.show()

# %%
reconstruction = pd.DataFrame(cp_vae.vae.predict(test_features_df), columns=cp_features)
(sum(sum((np.array(test_features_df) - np.array(reconstruction)) ** 2))) ** 0.5
# Out:
# 49.493420518887504

# %%
#latent space heatmap
fig, ax = plt.subplots(figsize=(10, 10))
encoder = cp_vae.encoder_block["encoder"]
latent = np.array(encoder.predict(test_features_df)[2])
seaborn.heatmap(latent, ax=ax)
# Out:
# <AxesSubplot:>

# %%
#original vs reconstructed heatmap
reconstruction = pd.DataFrame(cp_vae.vae.predict(test_features_df), columns=cp_features)
pca = PCA(n_components=2).fit(test_features_df)
pca_reconstructed_latent_df = pd.DataFrame(pca.transform(reconstruction))
pca_test_latent_df = pd.DataFrame(pca.transform(test_features_df))

# %%
figure(figsize=(10, 10), dpi=80)
plt.scatter(pca_test_latent_df[0],pca_test_latent_df[1], marker = ".", alpha = 0.5)
plt.scatter(pca_reconstructed_latent_df[0],pca_reconstructed_latent_df[1], marker = ".", alpha = 0.5)

# %%
pca = PCA(n_components=50).fit(test_features_df)
pca_reconstructed_latent_df = pd.DataFrame(pca.transform(reconstruction))
pca_test_latent_df = pd.DataFrame(pca.transform(test_features_df))

# %%
figure(figsize=(10, 10), dpi=80)
plt.scatter(pca_test_latent_df[21],pca_test_latent_df[43], marker = ".", alpha = 0.5)
plt.scatter(pca_reconstructed_latent_df[21],pca_reconstructed_latent_df[43], marker = ".", alpha = 0.5)

# %%
#difference between original and reconstructed heatmap
difference = abs(reconstruction - test_features_df)
fig, ax = plt.subplots(figsize=(10, 10))
seaborn.heatmap(difference, ax=ax, cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
#encoder heatmap
weights = cp_vae.encoder_block["encoder"].get_weights()
fig, ax = plt.subplots(figsize=(10, 10))
seaborn.heatmap(weights[0], ax=ax)
# Out:
# <AxesSubplot:>

# %%
decoder = cp_vae.decoder_block["decoder"]

# %%
pca_training = PCA(n_components=2).fit(train_features_df)

simulated_df = pd.DataFrame(np.random.normal(size=(8294, 10)), columns=np.arange(0,10))
reconstruction_of_simulated = decoder.predict(simulated_df)
pca_reconstruction_of_simulated = pd.DataFrame(pca_training.transform(reconstruction_of_simulated))
pca_train_latent_df = pd.DataFrame(pca_training.transform(train_features_df))

fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(16,8), sharey = True, sharex = True)
ax1.scatter(pca_train_latent_df[0],pca_train_latent_df[1], marker = ".", alpha = 0.5)
ax2.scatter(pca_reconstruction_of_simulated[0],pca_reconstruction_of_simulated[1], marker = ".", alpha = 0.5)

# %%
from scipy.spatial.distance import directed_hausdorff
max(directed_hausdorff(reconstruction_of_simulated, train_features_df)[0],directed_hausdorff(train_features_df,reconstruction_of_simulated)[0])
# Out:
# 6.1153968569401265

# %%
#NOTE: IF YOU RUN THIS, YOU WILL NOT BE ABLE TO REPRODUCE THE EXACT RESULTS IN THE EXPERIMENT
latent_complete = np.array(encoder.predict(complete_features_df)[2])
latent_df = pd.DataFrame(latent_complete)
latent_df.to_csv("../3.application/level5Latent_vanilla.csv")

# %%
reducer = umap.UMAP()
latent_embedding = reducer.fit_transform(latent_df)

# %%
figure(figsize=(10, 10), dpi=80)
plt.scatter(
    latent_embedding[:, 0],
    latent_embedding[:, 1],
    marker = '.'
)

# %%
#NOTE: IF YOU RUN THIS, YOU WILL NOT BE ABLE TO REPRODUCE THE EXACT RESULTS IN THE EXPERIMENT
decoder.save("models/level5Decoder_vanilla")
# Out:
# INFO:tensorflow:Assets written to: level5Decoder_vanilla/assets

# %%
encoder.save("models/level5Encoder_vanilla")
# Out:
# INFO:tensorflow:Assets written to: level5Encoder_vanilla/assets
