# %% [markdown]
# # Train a VAE on Cell Painting LINCS Data

# %%
import sys
import pathlib
import numpy as np
import pandas as pd
sys.path.insert(0, "../../scripts")
from utils import load_data


from pycytominer.cyto_utils import infer_cp_features


import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

from sklearn.decomposition import PCA
from tensorflow import keras

from vae import VAE

from tensorflow.keras.models import Model, Sequential
import seaborn
import random as python_random
import tensorflow as tf

# %%
data_splits = ["train", "test", "valid","complete"]
data_dict = load_data(data_splits)
# Out:
# /home/ubuntu/miniconda3/envs/cell-painting-vae/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3361: DtypeWarning: Columns (18,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
# Prepare data for training
meta_features = infer_cp_features(data_dict["train"], metadata=True)
cp_features = infer_cp_features(data_dict["train"])

train_features_df = data_dict["train"].reindex(cp_features, axis="columns")
train_meta_df = data_dict["train"].reindex(meta_features, axis="columns")

test_features_df = data_dict["test"].reindex(cp_features, axis="columns")
test_meta_df = data_dict["test"].reindex(meta_features, axis="columns")

valid_features_df = data_dict["valid"].reindex(cp_features, axis="columns")
Valid_meta_df = data_dict["valid"].reindex(meta_features, axis="columns")


complete_features_df = data_dict["complete"].reindex(cp_features, axis="columns")
complete_meta_df = data_dict["complete"].reindex(meta_features, axis="columns")

# %%
print(train_features_df.shape)
train_features_df.head(3)
# Out:
# (40242, 685)
#    Cells_AreaShape_Compactness  Cells_AreaShape_Eccentricity  \
# 0                      0.19790                       0.69605
# 1                      0.18605                       0.68873
# 2                      0.19083                       0.66276
#
#    Cells_AreaShape_Extent  Cells_AreaShape_FormFactor  \
# 0                 0.40400                     0.30834
# 1                 0.41051                     0.31982
# 2                 0.38585                     0.31437
#
#    Cells_AreaShape_MedianRadius  Cells_AreaShape_Orientation  \
# 0                       0.19317                      0.71895
# 1                       0.19885                      0.72510
# 2                       0.20415                      0.71380
#
#    Cells_AreaShape_Solidity  Cells_AreaShape_Zernike_0_0  \
# 0                   0.38837                      0.38668
# 1                   0.39552                      0.38362
# 2                   0.38701                      0.36699
#
#    Cells_AreaShape_Zernike_1_1  Cells_AreaShape_Zernike_2_0  ...  \
# 0                      0.62494                      0.87362  ...
# 1                      0.65094                      0.89679  ...
# 2                      0.60932                      0.88492  ...
#
#    Nuclei_Texture_SumEntropy_DNA_5_0  Nuclei_Texture_SumEntropy_Mito_5_0  \
# 0                            0.61045                             0.41907
# 1                            0.61393                             0.38269
# 2                            0.60850                             0.41850
#
#    Nuclei_Texture_SumEntropy_RNA_20_0  Nuclei_Texture_SumEntropy_RNA_5_0  \
# 0                             0.64945                            0.65199
# 1                             0.63814                            0.68204
# 2                             0.63529                            0.65208
#
#    Nuclei_Texture_SumVariance_DNA_20_0  Nuclei_Texture_SumVariance_RNA_20_0  \
# 0                              0.22660                              0.32108
# 1                              0.23700                              0.32808
# 2                              0.22852                              0.32710
#
#    Nuclei_Texture_Variance_DNA_20_0  Nuclei_Texture_Variance_ER_20_0  \
# 0                           0.29776                          0.26173
# 1                           0.27981                          0.26893
# 2                           0.29371                          0.27159
#
#    Nuclei_Texture_Variance_RNA_10_0  Nuclei_Texture_Variance_RNA_20_0
# 0                           0.34524                           0.32151
# 1                           0.34938                           0.33179
# 2                           0.33871                           0.31965
#
# [3 rows x 685 columns]

# %%
print(test_features_df.shape)
test_features_df.head(3)
# Out:
# (5030, 685)
#    Cells_AreaShape_Compactness  Cells_AreaShape_Eccentricity  \
# 0                      0.19050                       0.68937
# 1                      0.18661                       0.67731
# 2                      0.18626                       0.67036
#
#    Cells_AreaShape_Extent  Cells_AreaShape_FormFactor  \
# 0                 0.39383                     0.33072
# 1                 0.39621                     0.32318
# 2                 0.41101                     0.31863
#
#    Cells_AreaShape_MedianRadius  Cells_AreaShape_Orientation  \
# 0                       0.20185                      0.72292
# 1                       0.20716                      0.70964
# 2                       0.20182                      0.71139
#
#    Cells_AreaShape_Solidity  Cells_AreaShape_Zernike_0_0  \
# 0                   0.38085                      0.37504
# 1                   0.39401                      0.37779
# 2                   0.40302                      0.38979
#
#    Cells_AreaShape_Zernike_1_1  Cells_AreaShape_Zernike_2_0  ...  \
# 0                      0.61905                      0.88361  ...
# 1                      0.60275                      0.88912  ...
# 2                      0.59188                      0.86857  ...
#
#    Nuclei_Texture_SumEntropy_DNA_5_0  Nuclei_Texture_SumEntropy_Mito_5_0  \
# 0                            0.60356                             0.39345
# 1                            0.60936                             0.40380
# 2                            0.61009                             0.40904
#
#    Nuclei_Texture_SumEntropy_RNA_20_0  Nuclei_Texture_SumEntropy_RNA_5_0  \
# 0                             0.63470                            0.63406
# 1                             0.64406                            0.64859
# 2                             0.64250                            0.63285
#
#    Nuclei_Texture_SumVariance_DNA_20_0  Nuclei_Texture_SumVariance_RNA_20_0  \
# 0                              0.23588                              0.36061
# 1                              0.22752                              0.29811
# 2                              0.23931                              0.33179
#
#    Nuclei_Texture_Variance_DNA_20_0  Nuclei_Texture_Variance_ER_20_0  \
# 0                           0.30092                          0.23638
# 1                           0.29430                          0.25475
# 2                           0.28571                          0.24980
#
#    Nuclei_Texture_Variance_RNA_10_0  Nuclei_Texture_Variance_RNA_20_0
# 0                           0.36015                           0.32779
# 1                           0.34154                           0.32013
# 2                           0.34516                           0.32968
#
# [3 rows x 685 columns]

# %%
print(complete_features_df.shape)
complete_features_df.head(3)
# Out:
# (50303, 685)
#    Cells_AreaShape_Compactness  Cells_AreaShape_Eccentricity  \
# 0                      0.19575                       0.67566
# 1                      0.18472                       0.66556
# 2                      0.18254                       0.69650
#
#    Cells_AreaShape_Extent  Cells_AreaShape_FormFactor  \
# 0                 0.40288                     0.32633
# 1                 0.39721                     0.30968
# 2                 0.39596                     0.33502
#
#    Cells_AreaShape_MedianRadius  Cells_AreaShape_Orientation  \
# 0                       0.20267                      0.71477
# 1                       0.20009                      0.71345
# 2                       0.20420                      0.72770
#
#    Cells_AreaShape_Solidity  Cells_AreaShape_Zernike_0_0  \
# 0                   0.39122                      0.38048
# 1                   0.39953                      0.37314
# 2                   0.39590                      0.37023
#
#    Cells_AreaShape_Zernike_1_1  Cells_AreaShape_Zernike_2_0  ...  \
# 0                      0.61184                      0.88375  ...
# 1                      0.61074                      0.87695  ...
# 2                      0.60264                      0.88038  ...
#
#    Nuclei_Texture_SumEntropy_DNA_5_0  Nuclei_Texture_SumEntropy_Mito_5_0  \
# 0                            0.60865                             0.38869
# 1                            0.60682                             0.39779
# 2                            0.60665                             0.39705
#
#    Nuclei_Texture_SumEntropy_RNA_20_0  Nuclei_Texture_SumEntropy_RNA_5_0  \
# 0                             0.65364                            0.65716
# 1                             0.64013                            0.63120
# 2                             0.66616                            0.62889
#
#    Nuclei_Texture_SumVariance_DNA_20_0  Nuclei_Texture_SumVariance_RNA_20_0  \
# 0                              0.24912                              0.33129
# 1                              0.24380                              0.30471
# 2                              0.25125                              0.33549
#
#    Nuclei_Texture_Variance_DNA_20_0  Nuclei_Texture_Variance_ER_20_0  \
# 0                           0.28864                          0.27106
# 1                           0.28554                          0.27852
# 2                           0.29656                          0.25706
#
#    Nuclei_Texture_Variance_RNA_10_0  Nuclei_Texture_Variance_RNA_20_0
# 0                           0.35254                           0.32675
# 1                           0.35157                           0.31637
# 2                           0.33868                           0.31901
#
# [3 rows x 685 columns]

# %%
encoder_architecture = [250]
decoder_architecture = [250]

# %%
cp_vae = VAE(
    input_dim=train_features_df.shape[1],
    latent_dim=90,
    batch_size=32,
    encoder_batch_norm=True,
    epochs=58,
    learning_rate=0.0001,
    encoder_architecture=encoder_architecture,
    decoder_architecture=decoder_architecture,
    beta=1,
    verbose=True,
)

cp_vae.compile_vae()

# %%
cp_vae.train(x_train=train_features_df, x_test=valid_features_df)
# Out:
# Epoch 1/58
# 1258/1258 [==============================] - 8s 5ms/step - loss: 126.0757 - recon: 52.4382 - kl: 9.2754 - val_loss: 18.1324 - val_recon: 10.8175 - val_kl: 7.3149
# Epoch 2/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 12.8737 - recon: 6.9005 - kl: 3.9831 - val_loss: 8.1065 - val_recon: 4.9796 - val_kl: 3.1269
# Epoch 3/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 6.8315 - recon: 4.1045 - kl: 2.0128 - val_loss: 5.0443 - val_recon: 3.3111 - val_kl: 1.7332
# Epoch 4/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 4.3840 - recon: 2.8638 - kl: 1.1270 - val_loss: 3.4624 - val_recon: 2.3996 - val_kl: 1.0628
# Epoch 5/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 3.0319 - recon: 2.1313 - kl: 0.6859 - val_loss: 2.5959 - val_recon: 1.8200 - val_kl: 0.7760
# Epoch 6/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 2.2398 - recon: 1.6897 - kl: 0.4387 - val_loss: 2.3255 - val_recon: 1.5012 - val_kl: 0.8243
# Epoch 7/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.8018 - recon: 1.4298 - kl: 0.2779 - val_loss: 1.5900 - val_recon: 1.2892 - val_kl: 0.3007
# Epoch 8/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.5105 - recon: 1.2825 - kl: 0.1669 - val_loss: 1.4606 - val_recon: 1.1765 - val_kl: 0.2841
# Epoch 9/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.3137 - recon: 1.1894 - kl: 0.0943 - val_loss: 1.2804 - val_recon: 1.1051 - val_kl: 0.1753
# Epoch 10/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.2012 - recon: 1.1351 - kl: 0.0517 - val_loss: 1.4419 - val_recon: 1.0687 - val_kl: 0.3732
# Epoch 11/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.1399 - recon: 1.0999 - kl: 0.0292 - val_loss: 1.1705 - val_recon: 1.0389 - val_kl: 0.1316
# Epoch 12/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.1052 - recon: 1.0813 - kl: 0.0162 - val_loss: 1.3428 - val_recon: 1.0269 - val_kl: 0.3159
# Epoch 13/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0816 - recon: 1.0675 - kl: 0.0099 - val_loss: 1.7454 - val_recon: 1.0201 - val_kl: 0.7253
# Epoch 14/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0842 - recon: 1.0609 - kl: 0.0064 - val_loss: 1.2292 - val_recon: 1.0118 - val_kl: 0.2174
# Epoch 15/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0499 - recon: 1.0564 - kl: 0.0043 - val_loss: 1.5693 - val_recon: 1.0072 - val_kl: 0.5621
# Epoch 16/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0694 - recon: 1.0532 - kl: 0.0034 - val_loss: 1.3102 - val_recon: 0.9998 - val_kl: 0.3104
# Epoch 17/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0695 - recon: 1.0516 - kl: 0.0024 - val_loss: 1.2110 - val_recon: 1.0030 - val_kl: 0.2080
# Epoch 18/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0404 - recon: 1.0510 - kl: 0.0019 - val_loss: 1.0731 - val_recon: 1.0020 - val_kl: 0.0712
# Epoch 19/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0681 - recon: 1.0490 - kl: 0.0014 - val_loss: 1.0355 - val_recon: 1.0015 - val_kl: 0.0339
# Epoch 20/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0381 - recon: 1.0483 - kl: 0.0013 - val_loss: 1.0187 - val_recon: 0.9951 - val_kl: 0.0237
# Epoch 21/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0505 - recon: 1.0477 - kl: 0.0010 - val_loss: 1.0242 - val_recon: 0.9937 - val_kl: 0.0304
# Epoch 22/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0632 - recon: 1.0463 - kl: 9.2715e-04 - val_loss: 1.0455 - val_recon: 1.0085 - val_kl: 0.0371
# Epoch 23/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0543 - recon: 1.0459 - kl: 0.0010 - val_loss: 1.0128 - val_recon: 0.9964 - val_kl: 0.0164
# Epoch 24/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0456 - recon: 1.0463 - kl: 7.4546e-04 - val_loss: 1.0059 - val_recon: 0.9956 - val_kl: 0.0103
# Epoch 25/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0630 - recon: 1.0457 - kl: 5.5344e-04 - val_loss: 1.0003 - val_recon: 0.9937 - val_kl: 0.0066
# Epoch 26/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0280 - recon: 1.0449 - kl: 5.9299e-04 - val_loss: 1.0006 - val_recon: 0.9935 - val_kl: 0.0071
# Epoch 27/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0540 - recon: 1.0447 - kl: 5.7659e-04 - val_loss: 1.0004 - val_recon: 0.9978 - val_kl: 0.0025
# Epoch 28/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0515 - recon: 1.0450 - kl: 5.2172e-04 - val_loss: 0.9999 - val_recon: 0.9970 - val_kl: 0.0029
# Epoch 29/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0564 - recon: 1.0446 - kl: 4.8172e-04 - val_loss: 0.9979 - val_recon: 0.9948 - val_kl: 0.0031
# Epoch 30/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0257 - recon: 1.0439 - kl: 5.7570e-04 - val_loss: 0.9939 - val_recon: 0.9922 - val_kl: 0.0017
# Epoch 31/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0490 - recon: 1.0435 - kl: 5.0962e-04 - val_loss: 0.9947 - val_recon: 0.9931 - val_kl: 0.0016
# Epoch 32/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0492 - recon: 1.0436 - kl: 4.0793e-04 - val_loss: 1.0094 - val_recon: 1.0082 - val_kl: 0.0012
# Epoch 33/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0307 - recon: 1.0441 - kl: 3.8157e-04 - val_loss: 0.9919 - val_recon: 0.9905 - val_kl: 0.0014
# Epoch 34/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0532 - recon: 1.0427 - kl: 5.5058e-04 - val_loss: 0.9952 - val_recon: 0.9945 - val_kl: 7.1853e-04
# Epoch 35/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0466 - recon: 1.0433 - kl: 3.5338e-04 - val_loss: 0.9978 - val_recon: 0.9958 - val_kl: 0.0020
# Epoch 36/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0500 - recon: 1.0430 - kl: 3.7450e-04 - val_loss: 1.0088 - val_recon: 1.0075 - val_kl: 0.0013
# Epoch 37/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0426 - recon: 1.0435 - kl: 2.8958e-04 - val_loss: 1.0039 - val_recon: 1.0028 - val_kl: 0.0011
# Epoch 38/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0395 - recon: 1.0425 - kl: 3.2760e-04 - val_loss: 0.9946 - val_recon: 0.9937 - val_kl: 9.0509e-04
# Epoch 39/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0594 - recon: 1.0431 - kl: 3.3030e-04 - val_loss: 0.9928 - val_recon: 0.9918 - val_kl: 9.8338e-04
# Epoch 40/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0514 - recon: 1.0427 - kl: 3.0725e-04 - val_loss: 0.9930 - val_recon: 0.9919 - val_kl: 0.0011
# Epoch 41/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0356 - recon: 1.0424 - kl: 2.5124e-04 - val_loss: 0.9942 - val_recon: 0.9936 - val_kl: 5.8613e-04
# Epoch 42/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0653 - recon: 1.0426 - kl: 2.6316e-04 - val_loss: 0.9963 - val_recon: 0.9953 - val_kl: 0.0010
# Epoch 43/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0401 - recon: 1.0420 - kl: 2.5538e-04 - val_loss: 1.0073 - val_recon: 1.0068 - val_kl: 4.5031e-04
# Epoch 44/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0361 - recon: 1.0419 - kl: 1.9781e-04 - val_loss: 0.9930 - val_recon: 0.9918 - val_kl: 0.0012
# Epoch 45/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0234 - recon: 1.0421 - kl: 1.6838e-04 - val_loss: 0.9915 - val_recon: 0.9903 - val_kl: 0.0012
# Epoch 46/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0490 - recon: 1.0419 - kl: 2.7259e-04 - val_loss: 0.9931 - val_recon: 0.9919 - val_kl: 0.0012
# Epoch 47/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0109 - recon: 1.0422 - kl: 2.3529e-04 - val_loss: 0.9918 - val_recon: 0.9911 - val_kl: 7.2014e-04
# Epoch 48/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0221 - recon: 1.0413 - kl: 1.5127e-04 - val_loss: 1.0049 - val_recon: 1.0047 - val_kl: 2.5414e-04
# Epoch 49/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0288 - recon: 1.0420 - kl: 1.4922e-04 - val_loss: 1.0032 - val_recon: 1.0007 - val_kl: 0.0025
# Epoch 50/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0428 - recon: 1.0415 - kl: 2.2649e-04 - val_loss: 0.9935 - val_recon: 0.9925 - val_kl: 9.5175e-04
# Epoch 51/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0516 - recon: 1.0416 - kl: 1.5856e-04 - val_loss: 0.9925 - val_recon: 0.9920 - val_kl: 5.4374e-04
# Epoch 52/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0599 - recon: 1.0414 - kl: 1.3517e-04 - val_loss: 0.9923 - val_recon: 0.9916 - val_kl: 6.6294e-04
# Epoch 53/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0361 - recon: 1.0415 - kl: 1.2005e-04 - val_loss: 0.9900 - val_recon: 0.9897 - val_kl: 3.5508e-04
# Epoch 54/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0520 - recon: 1.0412 - kl: 2.3481e-04 - val_loss: 0.9946 - val_recon: 0.9933 - val_kl: 0.0013
# Epoch 55/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0184 - recon: 1.0412 - kl: 1.8052e-04 - val_loss: 0.9915 - val_recon: 0.9895 - val_kl: 0.0020
# Epoch 56/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0431 - recon: 1.0413 - kl: 2.2729e-04 - val_loss: 0.9912 - val_recon: 0.9908 - val_kl: 3.5920e-04
# Epoch 57/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0414 - recon: 1.0403 - kl: 2.6480e-04 - val_loss: 0.9905 - val_recon: 0.9891 - val_kl: 0.0014
# Epoch 58/58
# 1258/1258 [==============================] - 5s 4ms/step - loss: 1.0346 - recon: 1.0408 - kl: 2.0955e-04 - val_loss: 0.9968 - val_recon: 0.9961 - val_kl: 7.4401e-04

# %%
cp_vae.vae

# %%
# Save training performance
history_df = pd.DataFrame(cp_vae.vae.history.history)
history_df
# Out:
#          loss      recon        kl   val_loss  val_recon    val_kl
# 0   61.713570  52.438210  9.275378  18.132429  10.817516  7.314918
# 1   10.883592   6.900471  3.983102   8.106513   4.979610  3.126904
# 2    6.117237   4.104456  2.012779   5.044339   3.311099  1.733239
# 3    3.990814   2.863768  1.127050   3.462379   2.399555  1.062824
# 4    2.817169   2.131252  0.685917   2.595939   1.819976  0.775961
# 5    2.128380   1.689676  0.438703   2.325505   1.501199  0.824306
# 6    1.707771   1.429844  0.277927   1.589963   1.289226  0.300737
# 7    1.449400   1.282467  0.166932   1.460604   1.176477  0.284127
# 8    1.283736   1.189440  0.094298   1.280380   1.105052  0.175327
# 9    1.186810   1.135126  0.051684   1.441907   1.068678  0.373229
# 10   1.129063   1.099909  0.029154   1.170496   1.038905  0.131590
# 11   1.097493   1.081274  0.016218   1.342774   1.026883  0.315891
# 12   1.077365   1.067460  0.009906   1.745442   1.020112  0.725329
# 13   1.067227   1.060859  0.006368   1.229201   1.011768  0.217434
# 14   1.060664   1.056396  0.004269   1.569289   1.007183  0.562105
# 15   1.056663   1.053221  0.003441   1.310230   0.999812  0.310418
# 16   1.054008   1.051575  0.002433   1.211032   1.003001  0.208031
# 17   1.052846   1.050979  0.001867   1.073136   1.001985  0.071152
# 18   1.050482   1.049044  0.001436   1.035481   1.001542  0.033939
# 19   1.049564   1.048277  0.001288   1.018747   0.995062  0.023685
# 20   1.048780   1.047747  0.001033   1.024169   0.993730  0.030439
# 21   1.047262   1.046335  0.000927   1.045537   1.008453  0.037084
# 22   1.046934   1.045893  0.001042   1.012785   0.996380  0.016404
# 23   1.047095   1.046349  0.000745   1.005897   0.995644  0.010253
# 24   1.046226   1.045675  0.000553   1.000343   0.993743  0.006600
# 25   1.045456   1.044863  0.000593   1.000556   0.993493  0.007063
# 26   1.045237   1.044661  0.000577   1.000353   0.997844  0.002510
# 27   1.045503   1.044981  0.000522   0.999863   0.996965  0.002898
# 28   1.045108   1.044626  0.000482   0.997924   0.994814  0.003110
# 29   1.044502   1.043927  0.000576   0.993926   0.992220  0.001706
# 30   1.044030   1.043520  0.000510   0.994702   0.993062  0.001640
# 31   1.044015   1.043607  0.000408   1.009445   1.008248  0.001198
# 32   1.044524   1.044142  0.000382   0.991924   0.990533  0.001391
# 33   1.043231   1.042680  0.000551   0.995202   0.994483  0.000719
# 34   1.043628   1.043275  0.000353   0.997799   0.995776  0.002024
# 35   1.043351   1.042976  0.000375   1.008813   1.007501  0.001313
# 36   1.043761   1.043472  0.000290   1.003909   1.002797  0.001112
# 37   1.042866   1.042540  0.000328   0.994612   0.993707  0.000905
# 38   1.043388   1.043058  0.000330   0.992789   0.991805  0.000983
# 39   1.042989   1.042682  0.000307   0.992985   0.991907  0.001079
# 40   1.042693   1.042441  0.000251   0.994200   0.993614  0.000586
# 41   1.042858   1.042593  0.000263   0.996319   0.995318  0.001001
# 42   1.042237   1.041982  0.000255   1.007280   1.006829  0.000450
# 43   1.042052   1.041854  0.000198   0.993038   0.991831  0.001207
# 44   1.042282   1.042114  0.000168   0.991473   0.990306  0.001167
# 45   1.042146   1.041874  0.000273   0.993052   0.991877  0.001175
# 46   1.042394   1.042159  0.000235   0.991810   0.991090  0.000720
# 47   1.041481   1.041330  0.000151   1.004936   1.004681  0.000254
# 48   1.042127   1.041978  0.000149   1.003163   1.000685  0.002478
# 49   1.041681   1.041453  0.000226   0.993471   0.992519  0.000952
# 50   1.041736   1.041579  0.000159   0.992541   0.991997  0.000544
# 51   1.041577   1.041442  0.000135   0.992272   0.991608  0.000663
# 52   1.041622   1.041503  0.000120   0.990018   0.989662  0.000355
# 53   1.041391   1.041157  0.000235   0.994610   0.993297  0.001314
# 54   1.041428   1.041248  0.000181   0.991522   0.989515  0.002007
# 55   1.041495   1.041268  0.000227   0.991184   0.990825  0.000359
# 56   1.040606   1.040341  0.000265   0.990470   0.989059  0.001411
# 57   1.041015   1.040806  0.000210   0.996809   0.996064  0.000744

# %%
history_df.to_csv('training_data/level4_training_vanilla.csv')

# %%
plt.figure(figsize=(10, 5))
plt.plot(history_df["loss"], label="Training data")
plt.plot(history_df["val_loss"], label="Validation data")
plt.title("Loss for VAE training on Cell Painting Level 4 data")
plt.ylabel("MSE + KL Divergence")
plt.xlabel("No. Epoch")
plt.legend()
plt.show()

# %%
cp_vae.vae.evaluate(test_features_df)
# Out:
# 158/158 [==============================] - 0s 2ms/step - loss: 0.9928 - recon: 0.9921 - kl: 7.3087e-04
# [0.9928119778633118, 0.9920812249183655, 0.0007308730273507535]

# %%
reconstruction = pd.DataFrame(cp_vae.vae.predict(test_features_df), columns=cp_features)
(sum(sum((np.array(test_features_df) - np.array(reconstruction)) ** 2))) ** 0.5
# Out:
# 70.63997829999167

# %%
#latent space heatmap
fig, ax = plt.subplots(figsize=(10, 10))
encoder = cp_vae.encoder_block["encoder"]
latent = np.array(encoder.predict(test_features_df)[2])
seaborn.heatmap(latent, ax=ax)
# Out:
# <AxesSubplot:>

# %%
reconstruction = pd.DataFrame(cp_vae.vae.predict(test_features_df), columns=cp_features)
pca = PCA(n_components=2).fit(test_features_df)
pca_reconstructed_latent_df = pd.DataFrame(pca.transform(reconstruction))
pca_test_latent_df = pd.DataFrame(pca.transform(test_features_df))

# %%
figure(figsize=(10, 10), dpi=80)
plt.scatter(pca_test_latent_df[0],pca_test_latent_df[1], marker = ".", alpha = 0.5)
plt.scatter(pca_reconstructed_latent_df[0],pca_reconstructed_latent_df[1], marker = ".", alpha = 0.5)

# %%
decoder = cp_vae.decoder_block["decoder"]

# %%
pca_training = PCA(n_components=2).fit(train_features_df)

simulated_df = pd.DataFrame(np.random.normal(size=(40242, 90)), columns=np.arange(0,90))
reconstruction_of_simulated = decoder.predict(simulated_df)
pca_reconstruction_of_simulated = pd.DataFrame(pca_training.transform(reconstruction_of_simulated))
pca_train_latent_df = pd.DataFrame(pca_training.transform(train_features_df))

fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(16,8), sharey = True, sharex = True)
ax1.scatter(pca_train_latent_df[0],pca_train_latent_df[1], marker = ".", alpha = 0.5)
ax2.scatter(pca_reconstruction_of_simulated[0],pca_reconstruction_of_simulated[1], marker = ".", alpha = 0.5)

# %%
from scipy.spatial.distance import directed_hausdorff
max(directed_hausdorff(reconstruction_of_simulated, train_features_df)[0],directed_hausdorff(train_features_df,reconstruction_of_simulated)[0])
# Out:
# 9.266833694926369

# %%
#NOTE: IF YOU RUN THIS, YOU WILL NOT BE ABLE TO REPRODUCE THE EXACT RESULTS IN THE EXPERIMENT
latent_complete = np.array(encoder.predict(complete_features_df)[2])
latent_df = pd.DataFrame(latent)
latent_df.to_csv("../3.application/level4Latent_vanilla.csv")

# %%
#NOTE: IF YOU RUN THIS, YOU WILL NOT BE ABLE TO REPRODUCE THE EXACT RESULTS IN THE EXPERIMENT
decoder.save("models/level4Decoder_vanilla")
# Out:
# INFO:tensorflow:Assets written to: level4Decoder_vanilla/assets

# %%
encoder.save("models/level4Encoder_vanilla")
# Out:
# INFO:tensorflow:Assets written to: level4Encoder_vanilla/assets
