# %% [markdown]
# # Train a VAE on Cell Painting LINCS Data

# %%
import sys
import pathlib
import numpy as np
import pandas as pd
sys.path.insert(0, "../../scripts")
from utils import load_data


from pycytominer.cyto_utils import infer_cp_features


import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

from sklearn.decomposition import PCA
from tensorflow import keras

from vae import VAE

from tensorflow.keras.models import Model, Sequential
import seaborn
import random as python_random
import tensorflow as tf
import umap

# %%
# %load_ext nb_black

# %%
# np.random.seed(123)
# python_random.seed(123)
# tf.random.set_random_seed(1234)

# %%
data_splits = ["train", "test", "valid", "complete"]
data_dict = load_data(data_splits)

# %%
# Prepare data for training
meta_features = infer_cp_features(data_dict["train"], metadata=True)
cp_features = infer_cp_features(data_dict["train"])

train_features_df = data_dict["train"].reindex(cp_features, axis="columns")
train_meta_df = data_dict["train"].reindex(meta_features, axis="columns")

test_features_df = data_dict["test"].reindex(cp_features, axis="columns")
test_meta_df = data_dict["test"].reindex(meta_features, axis="columns")

valid_features_df = data_dict["valid"].reindex(cp_features, axis="columns")
valid_meta_df = data_dict["valid"].reindex(meta_features, axis="columns")

complete_features_df = data_dict["complete"].reindex(cp_features, axis="columns")
complete_meta_df = data_dict["complete"].reindex(meta_features, axis="columns")

# %%
print(train_features_df.shape)
train_features_df.head(3)
# Out:
# (8294, 588)
#    Cells_AreaShape_FormFactor  Cells_AreaShape_Orientation  \
# 0                     0.56071                      0.63708
# 1                     0.59702                      0.55453
# 2                     0.64623                      0.59825
#
#    Cells_AreaShape_Zernike_2_2  Cells_AreaShape_Zernike_3_1  \
# 0                      0.57961                      0.51030
# 1                      0.62561                      0.47959
# 2                      0.62822                      0.52100
#
#    Cells_AreaShape_Zernike_5_1  Cells_AreaShape_Zernike_6_2  \
# 0                      0.61695                      0.30869
# 1                      0.59022                      0.33269
# 2                      0.57452                      0.26367
#
#    Cells_AreaShape_Zernike_7_1  Cells_AreaShape_Zernike_7_7  \
# 0                      0.43981                      0.79826
# 1                      0.49875                      0.88042
# 2                      0.48172                      0.86322
#
#    Cells_AreaShape_Zernike_9_3  Cells_Correlation_Correlation_DNA_AGP  ...  \
# 0                      0.72477                                0.68589  ...
# 1                      0.67159                                0.61703  ...
# 2                      0.67588                                0.69732  ...
#
#    Nuclei_Texture_SumAverage_AGP_5_0  Nuclei_Texture_SumEntropy_AGP_10_0  \
# 0                            0.17858                             0.29336
# 1                            0.09030                             0.15088
# 2                            0.18125                             0.23244
#
#    Nuclei_Texture_SumEntropy_AGP_20_0  Nuclei_Texture_SumEntropy_AGP_5_0  \
# 0                             0.26447                            0.30197
# 1                             0.13334                            0.14052
# 2                             0.20723                            0.24062
#
#    Nuclei_Texture_SumEntropy_DNA_10_0  Nuclei_Texture_SumEntropy_DNA_20_0  \
# 0                             0.64786                             0.49525
# 1                             0.59229                             0.49294
# 2                             0.54642                             0.43920
#
#    Nuclei_Texture_SumEntropy_Mito_5_0  Nuclei_Texture_SumVariance_DNA_5_0  \
# 0                             0.53512                             0.40495
# 1                             0.43221                             0.33969
# 2                             0.41183                             0.30375
#
#    Nuclei_Texture_Variance_DNA_20_0  Nuclei_Texture_Variance_DNA_5_0
# 0                           0.46056                          0.43647
# 1                           0.39208                          0.36205
# 2                           0.35385                          0.33266
#
# [3 rows x 588 columns]

# %%
print(test_features_df.shape)
test_features_df.head(3)
# Out:
# (1037, 588)
#    Cells_AreaShape_FormFactor  Cells_AreaShape_Orientation  \
# 0                     0.52664                      0.59293
# 1                     0.61343                      0.57882
# 2                     0.55123                      0.61050
#
#    Cells_AreaShape_Zernike_2_2  Cells_AreaShape_Zernike_3_1  \
# 0                      0.51636                      0.52824
# 1                      0.62454                      0.51049
# 2                      0.53085                      0.65280
#
#    Cells_AreaShape_Zernike_5_1  Cells_AreaShape_Zernike_6_2  \
# 0                      0.54415                      0.23948
# 1                      0.57508                      0.31691
# 2                      0.54356                      0.16767
#
#    Cells_AreaShape_Zernike_7_1  Cells_AreaShape_Zernike_7_7  \
# 0                      0.53361                      0.84625
# 1                      0.49077                      0.89145
# 2                      0.50521                      0.93703
#
#    Cells_AreaShape_Zernike_9_3  Cells_Correlation_Correlation_DNA_AGP  ...  \
# 0                      0.65881                                0.86971  ...
# 1                      0.65811                                0.66082  ...
# 2                      0.77958                                0.63413  ...
#
#    Nuclei_Texture_SumAverage_AGP_5_0  Nuclei_Texture_SumEntropy_AGP_10_0  \
# 0                            0.74413                             0.58353
# 1                            0.12499                             0.20488
# 2                            0.19249                             0.13665
#
#    Nuclei_Texture_SumEntropy_AGP_20_0  Nuclei_Texture_SumEntropy_AGP_5_0  \
# 0                             0.54654                            0.63600
# 1                             0.18676                            0.20580
# 2                             0.13293                            0.13816
#
#    Nuclei_Texture_SumEntropy_DNA_10_0  Nuclei_Texture_SumEntropy_DNA_20_0  \
# 0                             0.50501                             0.39338
# 1                             0.58773                             0.47783
# 2                             0.58333                             0.52931
#
#    Nuclei_Texture_SumEntropy_Mito_5_0  Nuclei_Texture_SumVariance_DNA_5_0  \
# 0                             0.46080                             0.25924
# 1                             0.42619                             0.34683
# 2                             0.31068                             0.40967
#
#    Nuclei_Texture_Variance_DNA_20_0  Nuclei_Texture_Variance_DNA_5_0
# 0                           0.29724                          0.27556
# 1                           0.39642                          0.37092
# 2                           0.48646                          0.45058
#
# [3 rows x 588 columns]

# %%
print(complete_features_df.shape)
complete_features_df.head(3)
# Out:
# (10368, 588)
#    Cells_AreaShape_FormFactor  Cells_AreaShape_Orientation  \
# 0                     0.57016                      0.59500
# 1                     0.54840                      0.53949
# 2                     0.56057                      0.59621
#
#    Cells_AreaShape_Zernike_2_2  Cells_AreaShape_Zernike_3_1  \
# 0                      0.57370                      0.50690
# 1                      0.58096                      0.53694
# 2                      0.59116                      0.50418
#
#    Cells_AreaShape_Zernike_5_1  Cells_AreaShape_Zernike_6_2  \
# 0                      0.56160                      0.27321
# 1                      0.55009                      0.28114
# 2                      0.55679                      0.29305
#
#    Cells_AreaShape_Zernike_7_1  Cells_AreaShape_Zernike_7_7  \
# 0                      0.45448                      0.83747
# 1                      0.53594                      0.86929
# 2                      0.49221                      0.87813
#
#    Cells_AreaShape_Zernike_9_3  Cells_Correlation_Correlation_DNA_AGP  ...  \
# 0                      0.68635                                0.68973  ...
# 1                      0.66026                                0.71317  ...
# 2                      0.71747                                0.72229  ...
#
#    Nuclei_Texture_SumAverage_AGP_5_0  Nuclei_Texture_SumEntropy_AGP_10_0  \
# 0                            0.16426                             0.22701
# 1                            0.18411                             0.23932
# 2                            0.17564                             0.23366
#
#    Nuclei_Texture_SumEntropy_AGP_20_0  Nuclei_Texture_SumEntropy_AGP_5_0  \
# 0                             0.20854                            0.22897
# 1                             0.21854                            0.24763
# 2                             0.21743                            0.23448
#
#    Nuclei_Texture_SumEntropy_DNA_10_0  Nuclei_Texture_SumEntropy_DNA_20_0  \
# 0                             0.53738                             0.43547
# 1                             0.56995                             0.47084
# 2                             0.56980                             0.47254
#
#    Nuclei_Texture_SumEntropy_Mito_5_0  Nuclei_Texture_SumVariance_DNA_5_0  \
# 0                             0.41635                             0.28933
# 1                             0.37764                             0.32148
# 2                             0.39575                             0.31969
#
#    Nuclei_Texture_Variance_DNA_20_0  Nuclei_Texture_Variance_DNA_5_0
# 0                           0.34017                          0.31368
# 1                           0.36964                          0.34328
# 2                           0.36626                          0.34086
#
# [3 rows x 588 columns]

# %%
# VAE of one layer
encoder_architecture = [250]
decoder_architecture = [250]

# %%
# model from optimal hyperparameters for onelayer obtained from 1.optimize
cp_vae = VAE(
    input_dim=train_features_df.shape[1],
    latent_dim=10,
    batch_size=96,
    encoder_batch_norm=True,
    epochs=30,
    learning_rate=0.001,
    encoder_architecture=encoder_architecture,
    decoder_architecture=decoder_architecture,
    beta=0,
    lam=1000,
    verbose=True,
)
#100000
#10000
#200 ep 1000000 results in 1.20
cp_vae.compile_vae()

# %%
cp_vae.train(x_train=train_features_df, x_test=valid_features_df)
# Out:
# Epoch 1/30
# 87/87 [==============================] - 3s 11ms/step - loss: 77.7165 - recon: 29.9398 - kl: 0.0000e+00 - mmd: 11.0873 - val_loss: 84.1976 - val_recon: 16.7908 - val_kl: 0.0000e+00 - val_mmd: 64.4255
# Epoch 2/30
# 87/87 [==============================] - 0s 5ms/step - loss: 15.4244 - recon: 7.7640 - kl: 0.0000e+00 - mmd: 7.0310 - val_loss: 28.7462 - val_recon: 8.9807 - val_kl: 0.0000e+00 - val_mmd: 21.4165
# Epoch 3/30
# 87/87 [==============================] - 0s 5ms/step - loss: 11.6400 - recon: 6.0420 - kl: 0.0000e+00 - mmd: 5.0135 - val_loss: 17.0108 - val_recon: 5.6688 - val_kl: 0.0000e+00 - val_mmd: 12.0636
# Epoch 4/30
# 87/87 [==============================] - 0s 5ms/step - loss: 9.9400 - recon: 5.0197 - kl: 0.0000e+00 - mmd: 4.7361 - val_loss: 14.1893 - val_recon: 4.6506 - val_kl: 0.0000e+00 - val_mmd: 8.8202
# Epoch 5/30
# 87/87 [==============================] - 0s 5ms/step - loss: 8.8841 - recon: 4.4805 - kl: 0.0000e+00 - mmd: 4.0855 - val_loss: 14.9256 - val_recon: 4.0556 - val_kl: 0.0000e+00 - val_mmd: 14.1182
# Epoch 6/30
# 87/87 [==============================] - 0s 5ms/step - loss: 7.8743 - recon: 4.0903 - kl: 0.0000e+00 - mmd: 3.9326 - val_loss: 16.1891 - val_recon: 3.8231 - val_kl: 0.0000e+00 - val_mmd: 11.6713
# Epoch 7/30
# 87/87 [==============================] - 0s 5ms/step - loss: 7.9039 - recon: 3.8912 - kl: 0.0000e+00 - mmd: 3.9643 - val_loss: 12.8489 - val_recon: 3.6877 - val_kl: 0.0000e+00 - val_mmd: 8.7189
# Epoch 8/30
# 87/87 [==============================] - 0s 5ms/step - loss: 7.3747 - recon: 3.7501 - kl: 0.0000e+00 - mmd: 3.8904 - val_loss: 13.3973 - val_recon: 3.6598 - val_kl: 0.0000e+00 - val_mmd: 8.9277
# Epoch 9/30
# 87/87 [==============================] - 0s 5ms/step - loss: 7.5719 - recon: 3.6665 - kl: 0.0000e+00 - mmd: 3.9753 - val_loss: 9.5594 - val_recon: 3.5768 - val_kl: 0.0000e+00 - val_mmd: 5.0356
# Epoch 10/30
# 87/87 [==============================] - 0s 5ms/step - loss: 7.6538 - recon: 3.6114 - kl: 0.0000e+00 - mmd: 4.1017 - val_loss: 8.5830 - val_recon: 3.3931 - val_kl: 0.0000e+00 - val_mmd: 6.3070
# Epoch 11/30
# 87/87 [==============================] - 0s 5ms/step - loss: 7.0957 - recon: 3.5753 - kl: 0.0000e+00 - mmd: 3.7360 - val_loss: 10.3232 - val_recon: 3.3437 - val_kl: 0.0000e+00 - val_mmd: 6.5767
# Epoch 12/30
# 87/87 [==============================] - 0s 5ms/step - loss: 7.1536 - recon: 3.5178 - kl: 0.0000e+00 - mmd: 3.7013 - val_loss: 8.2862 - val_recon: 3.2525 - val_kl: 0.0000e+00 - val_mmd: 5.1462
# Epoch 13/30
# 87/87 [==============================] - 0s 5ms/step - loss: 7.3454 - recon: 3.5013 - kl: 0.0000e+00 - mmd: 3.9873 - val_loss: 9.4293 - val_recon: 3.1747 - val_kl: 0.0000e+00 - val_mmd: 6.8885
# Epoch 14/30
# 87/87 [==============================] - 0s 5ms/step - loss: 7.5887 - recon: 3.3681 - kl: 0.0000e+00 - mmd: 4.0015 - val_loss: 8.6156 - val_recon: 3.1460 - val_kl: 0.0000e+00 - val_mmd: 5.9468
# Epoch 15/30
# 87/87 [==============================] - 0s 5ms/step - loss: 7.3862 - recon: 3.3251 - kl: 0.0000e+00 - mmd: 3.9025 - val_loss: 11.9675 - val_recon: 3.2655 - val_kl: 0.0000e+00 - val_mmd: 8.5499
# Epoch 16/30
# 87/87 [==============================] - 0s 5ms/step - loss: 7.5449 - recon: 3.3282 - kl: 0.0000e+00 - mmd: 3.8939 - val_loss: 9.1943 - val_recon: 3.1085 - val_kl: 0.0000e+00 - val_mmd: 5.5690
# Epoch 17/30
# 87/87 [==============================] - 0s 5ms/step - loss: 6.9879 - recon: 3.3372 - kl: 0.0000e+00 - mmd: 3.6661 - val_loss: 7.9252 - val_recon: 3.1699 - val_kl: 0.0000e+00 - val_mmd: 5.6607
# Epoch 18/30
# 87/87 [==============================] - 0s 5ms/step - loss: 6.8858 - recon: 3.2668 - kl: 0.0000e+00 - mmd: 3.9564 - val_loss: 7.2826 - val_recon: 3.0520 - val_kl: 0.0000e+00 - val_mmd: 5.2961
# Epoch 19/30
# 87/87 [==============================] - 0s 5ms/step - loss: 7.1139 - recon: 3.2404 - kl: 0.0000e+00 - mmd: 3.7589 - val_loss: 8.6902 - val_recon: 3.0066 - val_kl: 0.0000e+00 - val_mmd: 7.0385
# Epoch 20/30
# 87/87 [==============================] - 0s 5ms/step - loss: 7.0349 - recon: 3.2143 - kl: 0.0000e+00 - mmd: 3.5464 - val_loss: 10.5125 - val_recon: 2.9989 - val_kl: 0.0000e+00 - val_mmd: 8.0572
# Epoch 21/30
# 87/87 [==============================] - 0s 5ms/step - loss: 6.5434 - recon: 3.1647 - kl: 0.0000e+00 - mmd: 3.9763 - val_loss: 7.9145 - val_recon: 2.9141 - val_kl: 0.0000e+00 - val_mmd: 5.9200
# Epoch 22/30
# 87/87 [==============================] - 0s 5ms/step - loss: 6.5540 - recon: 3.1453 - kl: 0.0000e+00 - mmd: 3.9013 - val_loss: 8.4278 - val_recon: 2.8624 - val_kl: 0.0000e+00 - val_mmd: 6.2462
# Epoch 23/30
# 87/87 [==============================] - 0s 5ms/step - loss: 6.5964 - recon: 3.1129 - kl: 0.0000e+00 - mmd: 3.4071 - val_loss: 6.9367 - val_recon: 2.9986 - val_kl: 0.0000e+00 - val_mmd: 3.9724
# Epoch 24/30
# 87/87 [==============================] - 0s 5ms/step - loss: 6.5991 - recon: 3.0726 - kl: 0.0000e+00 - mmd: 3.6378 - val_loss: 7.3134 - val_recon: 2.8058 - val_kl: 0.0000e+00 - val_mmd: 5.5157
# Epoch 25/30
# 87/87 [==============================] - 0s 5ms/step - loss: 6.4338 - recon: 3.0686 - kl: 0.0000e+00 - mmd: 3.8514 - val_loss: 7.5482 - val_recon: 2.9444 - val_kl: 0.0000e+00 - val_mmd: 5.2353
# Epoch 26/30
# 87/87 [==============================] - 0s 5ms/step - loss: 6.4319 - recon: 3.0219 - kl: 0.0000e+00 - mmd: 3.7833 - val_loss: 6.7793 - val_recon: 2.9475 - val_kl: 0.0000e+00 - val_mmd: 3.9095
# Epoch 27/30
# 87/87 [==============================] - 0s 5ms/step - loss: 6.7890 - recon: 2.9628 - kl: 0.0000e+00 - mmd: 3.8086 - val_loss: 8.9243 - val_recon: 2.7433 - val_kl: 0.0000e+00 - val_mmd: 6.5610
# Epoch 28/30
# 87/87 [==============================] - 0s 5ms/step - loss: 6.6281 - recon: 2.9981 - kl: 0.0000e+00 - mmd: 3.8578 - val_loss: 7.7861 - val_recon: 2.7820 - val_kl: 0.0000e+00 - val_mmd: 4.5500
# Epoch 29/30
# 87/87 [==============================] - 0s 5ms/step - loss: 6.5011 - recon: 2.8636 - kl: 0.0000e+00 - mmd: 3.9739 - val_loss: 7.8733 - val_recon: 2.7382 - val_kl: 0.0000e+00 - val_mmd: 6.0305
# Epoch 30/30
# 87/87 [==============================] - 0s 5ms/step - loss: 6.6136 - recon: 2.8677 - kl: 0.0000e+00 - mmd: 3.8069 - val_loss: 14.9922 - val_recon: 2.6273 - val_kl: 0.0000e+00 - val_mmd: 11.0788

# %%
cp_vae.vae

# %%
# cp_vae.vae.evaluate(test_features_df)

# %%
# Save training performance
history_df = pd.DataFrame(cp_vae.vae.history.history)
history_df
# Out:
#          loss      recon   kl        mmd   val_loss  val_recon  val_kl  \
# 0   40.546684  29.939829  0.0  11.087311  84.197556  16.790825     0.0
# 1   14.617631   7.764007  0.0   7.031021  28.746227   8.980696     0.0
# 2   11.057851   6.041999  0.0   5.013541  17.010773   5.668807     0.0
# 3    9.718275   5.019685  0.0   4.736140  14.189341   4.650591     0.0
# 4    8.704604   4.480525  0.0   4.085529  14.925645   4.055581     0.0
# 5    8.046390   4.090334  0.0   3.932575  16.189095   3.823100     0.0
# 6    7.935841   3.891229  0.0   3.964302  12.848927   3.687715     0.0
# 7    7.382927   3.750054  0.0   3.890360  13.397330   3.659762     0.0
# 8    7.558379   3.666493  0.0   3.975267   9.559366   3.576767     0.0
# 9    7.619995   3.611426  0.0   4.101668   8.583013   3.393129     0.0
# 10   7.248723   3.575342  0.0   3.736013  10.323241   3.343711     0.0
# 11   7.264777   3.517840  0.0   3.701280   8.286174   3.252462     0.0
# 12   7.492180   3.501282  0.0   3.987318   9.429262   3.174675     0.0
# 13   7.228165   3.368062  0.0   4.001501   8.615624   3.146044     0.0
# 14   7.107304   3.325116  0.0   3.902457  11.967517   3.265511     0.0
# 15   7.180416   3.328192  0.0   3.893924   9.194343   3.108483     0.0
# 16   7.112811   3.337222  0.0   3.666128   7.925223   3.169891     0.0
# 17   7.094236   3.266837  0.0   3.956448   7.282612   3.051990     0.0
# 18   6.985127   3.240386  0.0   3.758923   8.690217   3.006602     0.0
# 19   7.069225   3.214297  0.0   3.546385  10.512502   2.998928     0.0
# 20   6.766970   3.164731  0.0   3.976312   7.914482   2.914073     0.0
# 21   6.815655   3.145261  0.0   3.901309   8.427781   2.862449     0.0
# 22   6.712559   3.112876  0.0   3.407145   6.936730   2.998629     0.0
# 23   6.610270   3.072605  0.0   3.637830   7.313425   2.805823     0.0
# 24   6.736174   3.068596  0.0   3.851435   7.548151   2.944369     0.0
# 25   6.562194   3.021881  0.0   3.783330   6.779350   2.947486     0.0
# 26   6.877467   2.962799  0.0   3.808587   8.924283   2.743279     0.0
# 27   6.712346   2.998070  0.0   3.857787   7.786143   2.781990     0.0
# 28   6.547011   2.863630  0.0   3.973882   7.873331   2.738234     0.0
# 29   6.447211   2.867723  0.0   3.806900  14.992210   2.627312     0.0
#
#       val_mmd
# 0   64.425522
# 1   21.416527
# 2   12.063633
# 3    8.820166
# 4   14.118217
# 5   11.671305
# 6    8.718859
# 7    8.927713
# 8    5.035649
# 9    6.307016
# 10   6.576723
# 11   5.146222
# 12   6.888487
# 13   5.946810
# 14   8.549852
# 15   5.568971
# 16   5.660718
# 17   5.296133
# 18   7.038539
# 19   8.057225
# 20   5.919998
# 21   6.246220
# 22   3.972389
# 23   5.515749
# 24   5.235292
# 25   3.909458
# 26   6.561041
# 27   4.549969
# 28   6.030451
# 29  11.078845

# %%
history_df.to_csv('training_data/level5_training_mmd.csv')

# %%
plt.figure(figsize=(10, 5))
plt.plot(history_df["loss"], label="Training data")
plt.plot(history_df["val_loss"], label="Validation data")
plt.title("Loss for VAE training on Cell Painting Level 5 data")
plt.ylabel("MSE + MMD")
plt.xlabel("No. Epoch")
plt.legend()
plt.show()

# %%
reconstruction = pd.DataFrame(cp_vae.vae.predict(test_features_df), columns=cp_features)
(sum(sum((np.array(test_features_df) - np.array(reconstruction)) ** 2))) ** 0.5
# Out:
# 52.259470380080096

# %%
#latent space heatmap
fig, ax = plt.subplots(figsize=(10, 10))
encoder = cp_vae.encoder_block["encoder"]
latent = np.array(encoder.predict(test_features_df)[2])
seaborn.heatmap(latent, ax=ax)
# Out:
# <AxesSubplot:>

# %%
#original vs reconstructed heatmap
reconstruction = pd.DataFrame(cp_vae.vae.predict(test_features_df), columns=cp_features)
pca = PCA(n_components=2).fit(test_features_df)
pca_reconstructed_latent_df = pd.DataFrame(pca.transform(reconstruction))
pca_test_latent_df = pd.DataFrame(pca.transform(test_features_df))
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))
# seaborn.heatmap(test_features_df, ax=ax1)
# seaborn.heatmap(reconstruction, ax=ax2)
# plt.show()

# %%
figure(figsize=(10, 10), dpi=80)
plt.scatter(pca_test_latent_df[0],pca_test_latent_df[1], marker = ".", alpha = 0.5)
plt.scatter(pca_reconstructed_latent_df[0],pca_reconstructed_latent_df[1], marker = ".", alpha = 0.5)

# %%
pca = PCA(n_components=50).fit(test_features_df)
pca_reconstructed_latent_df = pd.DataFrame(pca.transform(reconstruction))
pca_test_latent_df = pd.DataFrame(pca.transform(test_features_df))

# %%
figure(figsize=(10, 10), dpi=80)
plt.scatter(pca_test_latent_df[2],pca_test_latent_df[3], marker = ".", alpha = 0.5)
plt.scatter(pca_reconstructed_latent_df[2],pca_reconstructed_latent_df[3], marker = ".", alpha = 0.5)

# %%
#difference between original and reconstructed heatmap
difference = abs(reconstruction - test_features_df)
fig, ax = plt.subplots(figsize=(10, 10))
seaborn.heatmap(difference, ax=ax, cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
#encoder heatmap
weights = cp_vae.encoder_block["encoder"].get_weights()
fig, ax = plt.subplots(figsize=(10, 10))
seaborn.heatmap(weights[0], ax=ax)
# Out:
# <AxesSubplot:>

# %%
decoder = cp_vae.decoder_block["decoder"]

# %%
pca_training = PCA(n_components=2).fit(train_features_df)

simulated_df = pd.DataFrame(np.random.normal(size=(8294, 10)), columns=np.arange(0,10))
reconstruction_of_simulated = decoder.predict(simulated_df)
pca_reconstruction_of_simulated = pd.DataFrame(pca_training.transform(reconstruction_of_simulated))
pca_train_latent_df = pd.DataFrame(pca_training.transform(train_features_df))

fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(16,8), sharey = True, sharex = True)
ax1.scatter(pca_train_latent_df[0],pca_train_latent_df[1], marker = ".", alpha = 0.5)
ax2.scatter(pca_reconstruction_of_simulated[0],pca_reconstruction_of_simulated[1], marker = ".", alpha = 0.5)

# %%
from scipy.spatial.distance import directed_hausdorff
max(directed_hausdorff(train_features_df, reconstruction_of_simulated)[0],directed_hausdorff(reconstruction_of_simulated,train_features_df)[0])
# Out:
# 6.051922545470614

# %%
#NOTE: IF YOU RUN THIS, YOU WILL NOT BE ABLE TO REPRODUCE THE EXACT RESULTS IN THE EXPERIMENT
latent_complete = np.array(encoder.predict(complete_features_df)[2])
latent_df = pd.DataFrame(latent_complete)
latent_df.to_csv("../3.application/level5Latent_mmd.csv")

# %%
reducer = umap.UMAP()
latent_embedding = reducer.fit_transform(latent_df)

# %%
figure(figsize=(10, 10), dpi=80)
plt.scatter(
    latent_embedding[:, 0],
    latent_embedding[:, 1],
    marker = '.'
)

# %%
#NOTE: IF YOU RUN THIS, YOU WILL NOT BE ABLE TO REPRODUCE THE EXACT RESULTS IN THE EXPERIMENT
decoder.save("models/level5Decoder_mmd")
# Out:
# INFO:tensorflow:Assets written to: level5Decoder_mmd/assets

# %%
encoder.save("models/level5Encoder_mmd")
# Out:
# INFO:tensorflow:Assets written to: level5Encoder_mmd/assets
