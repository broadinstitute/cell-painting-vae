# %% [markdown]
# # Train a VAE on Cell Painting LINCS Data

# %%
import sys
import pathlib
import numpy as np
import pandas as pd
sys.path.insert(0, "../../scripts")
from utils import load_data


from pycytominer.cyto_utils import infer_cp_features


import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

from sklearn.decomposition import PCA
from tensorflow import keras

from vae import VAE

from tensorflow.keras.models import Model, Sequential
import seaborn
import random as python_random
import tensorflow as tf
# import umap

# %%
# %load_ext nb_black

# %%
# np.random.seed(123)
# python_random.seed(123)
# tf.random.set_random_seed(1234)

# %%
data_splits = ["train", "test", "valid", "complete"]
data_dict = load_data(data_splits)

# %%
def remove_moa(df):
    pipes = ['estrogen receptor antagonist|progesterone receptor agonist',
             'histamine receptor agonist|histamine receptor antagonist',
             'cyclooxygenase inhibitor|lipoxygenase inhibitor',
             'RAF inhibitor|VEGFR inhibitor',
            'insulin sensitizer|PPAR receptor agonist']    
    moas =  []
    for pipe in pipes:
        moas.append(pipe)
        moas.append(pipe.split('|')[0])
        moas.append(pipe.split('|')[1])
    return df[~df.moa.isin(moas)]

# %%
# Prepare data for training
meta_features = infer_cp_features(data_dict["train"], metadata=True)
cp_features = infer_cp_features(data_dict["train"])

moa_df_train = pd.read_csv("../3.application/repurposing_info_external_moa_map_resolved.tsv",sep='\t').set_index('broad_sample').reindex(index=data_dict['train']['Metadata_broad_sample']).reset_index().drop('Metadata_broad_sample',axis = 1)
data_dict['train'] = pd.concat([moa_df_train,data_dict['train']], axis=1)

moa_df_valid = pd.read_csv("../3.application/repurposing_info_external_moa_map_resolved.tsv",sep='\t').set_index('broad_sample').reindex(index=data_dict['valid']['Metadata_broad_sample']).reset_index().drop('Metadata_broad_sample',axis = 1)
data_dict['valid'] = pd.concat([moa_df_valid,data_dict['valid']], axis=1)

data_dict['train'] = remove_moa(data_dict['train'])
data_dict['valid'] = remove_moa(data_dict['valid'])

train_features_df = data_dict["train"].reindex(cp_features, axis="columns")
train_meta_df = data_dict["train"].reindex(meta_features, axis="columns")

test_features_df = data_dict["test"].reindex(cp_features, axis="columns")
test_meta_df = data_dict["test"].reindex(meta_features, axis="columns")

valid_features_df = data_dict["valid"].reindex(cp_features, axis="columns")
valid_meta_df = data_dict["valid"].reindex(meta_features, axis="columns")

complete_features_df = data_dict["complete"].reindex(cp_features, axis="columns")
complete_meta_df = data_dict["complete"].reindex(meta_features, axis="columns")

# %%
print(train_features_df.shape)
train_features_df.head(3)
# Out:
# (7852, 588)
#    Cells_AreaShape_FormFactor  Cells_AreaShape_Orientation  \
# 0                     0.56071                      0.63708
# 1                     0.59702                      0.55453
# 2                     0.64623                      0.59825
#
#    Cells_AreaShape_Zernike_2_2  Cells_AreaShape_Zernike_3_1  \
# 0                      0.57961                      0.51030
# 1                      0.62561                      0.47959
# 2                      0.62822                      0.52100
#
#    Cells_AreaShape_Zernike_5_1  Cells_AreaShape_Zernike_6_2  \
# 0                      0.61695                      0.30869
# 1                      0.59022                      0.33269
# 2                      0.57452                      0.26367
#
#    Cells_AreaShape_Zernike_7_1  Cells_AreaShape_Zernike_7_7  \
# 0                      0.43981                      0.79826
# 1                      0.49875                      0.88042
# 2                      0.48172                      0.86322
#
#    Cells_AreaShape_Zernike_9_3  Cells_Correlation_Correlation_DNA_AGP  ...  \
# 0                      0.72477                                0.68589  ...
# 1                      0.67159                                0.61703  ...
# 2                      0.67588                                0.69732  ...
#
#    Nuclei_Texture_SumAverage_AGP_5_0  Nuclei_Texture_SumEntropy_AGP_10_0  \
# 0                            0.17858                             0.29336
# 1                            0.09030                             0.15088
# 2                            0.18125                             0.23244
#
#    Nuclei_Texture_SumEntropy_AGP_20_0  Nuclei_Texture_SumEntropy_AGP_5_0  \
# 0                             0.26447                            0.30197
# 1                             0.13334                            0.14052
# 2                             0.20723                            0.24062
#
#    Nuclei_Texture_SumEntropy_DNA_10_0  Nuclei_Texture_SumEntropy_DNA_20_0  \
# 0                             0.64786                             0.49525
# 1                             0.59229                             0.49294
# 2                             0.54642                             0.43920
#
#    Nuclei_Texture_SumEntropy_Mito_5_0  Nuclei_Texture_SumVariance_DNA_5_0  \
# 0                             0.53512                             0.40495
# 1                             0.43221                             0.33969
# 2                             0.41183                             0.30375
#
#    Nuclei_Texture_Variance_DNA_20_0  Nuclei_Texture_Variance_DNA_5_0
# 0                           0.46056                          0.43647
# 1                           0.39208                          0.36205
# 2                           0.35385                          0.33266
#
# [3 rows x 588 columns]

# %%
print(test_features_df.shape)
test_features_df.head(3)
# Out:
# (1037, 588)
#    Cells_AreaShape_FormFactor  Cells_AreaShape_Orientation  \
# 0                     0.52664                      0.59293
# 1                     0.61343                      0.57882
# 2                     0.55123                      0.61050
#
#    Cells_AreaShape_Zernike_2_2  Cells_AreaShape_Zernike_3_1  \
# 0                      0.51636                      0.52824
# 1                      0.62454                      0.51049
# 2                      0.53085                      0.65280
#
#    Cells_AreaShape_Zernike_5_1  Cells_AreaShape_Zernike_6_2  \
# 0                      0.54415                      0.23948
# 1                      0.57508                      0.31691
# 2                      0.54356                      0.16767
#
#    Cells_AreaShape_Zernike_7_1  Cells_AreaShape_Zernike_7_7  \
# 0                      0.53361                      0.84625
# 1                      0.49077                      0.89145
# 2                      0.50521                      0.93703
#
#    Cells_AreaShape_Zernike_9_3  Cells_Correlation_Correlation_DNA_AGP  ...  \
# 0                      0.65881                                0.86971  ...
# 1                      0.65811                                0.66082  ...
# 2                      0.77958                                0.63413  ...
#
#    Nuclei_Texture_SumAverage_AGP_5_0  Nuclei_Texture_SumEntropy_AGP_10_0  \
# 0                            0.74413                             0.58353
# 1                            0.12499                             0.20488
# 2                            0.19249                             0.13665
#
#    Nuclei_Texture_SumEntropy_AGP_20_0  Nuclei_Texture_SumEntropy_AGP_5_0  \
# 0                             0.54654                            0.63600
# 1                             0.18676                            0.20580
# 2                             0.13293                            0.13816
#
#    Nuclei_Texture_SumEntropy_DNA_10_0  Nuclei_Texture_SumEntropy_DNA_20_0  \
# 0                             0.50501                             0.39338
# 1                             0.58773                             0.47783
# 2                             0.58333                             0.52931
#
#    Nuclei_Texture_SumEntropy_Mito_5_0  Nuclei_Texture_SumVariance_DNA_5_0  \
# 0                             0.46080                             0.25924
# 1                             0.42619                             0.34683
# 2                             0.31068                             0.40967
#
#    Nuclei_Texture_Variance_DNA_20_0  Nuclei_Texture_Variance_DNA_5_0
# 0                           0.29724                          0.27556
# 1                           0.39642                          0.37092
# 2                           0.48646                          0.45058
#
# [3 rows x 588 columns]

# %%
print(complete_features_df.shape)
complete_features_df.head(3)
# Out:
# (10368, 588)
#    Cells_AreaShape_FormFactor  Cells_AreaShape_Orientation  \
# 0                     0.57016                      0.59500
# 1                     0.54840                      0.53949
# 2                     0.56057                      0.59621
#
#    Cells_AreaShape_Zernike_2_2  Cells_AreaShape_Zernike_3_1  \
# 0                      0.57370                      0.50690
# 1                      0.58096                      0.53694
# 2                      0.59116                      0.50418
#
#    Cells_AreaShape_Zernike_5_1  Cells_AreaShape_Zernike_6_2  \
# 0                      0.56160                      0.27321
# 1                      0.55009                      0.28114
# 2                      0.55679                      0.29305
#
#    Cells_AreaShape_Zernike_7_1  Cells_AreaShape_Zernike_7_7  \
# 0                      0.45448                      0.83747
# 1                      0.53594                      0.86929
# 2                      0.49221                      0.87813
#
#    Cells_AreaShape_Zernike_9_3  Cells_Correlation_Correlation_DNA_AGP  ...  \
# 0                      0.68635                                0.68973  ...
# 1                      0.66026                                0.71317  ...
# 2                      0.71747                                0.72229  ...
#
#    Nuclei_Texture_SumAverage_AGP_5_0  Nuclei_Texture_SumEntropy_AGP_10_0  \
# 0                            0.16426                             0.22701
# 1                            0.18411                             0.23932
# 2                            0.17564                             0.23366
#
#    Nuclei_Texture_SumEntropy_AGP_20_0  Nuclei_Texture_SumEntropy_AGP_5_0  \
# 0                             0.20854                            0.22897
# 1                             0.21854                            0.24763
# 2                             0.21743                            0.23448
#
#    Nuclei_Texture_SumEntropy_DNA_10_0  Nuclei_Texture_SumEntropy_DNA_20_0  \
# 0                             0.53738                             0.43547
# 1                             0.56995                             0.47084
# 2                             0.56980                             0.47254
#
#    Nuclei_Texture_SumEntropy_Mito_5_0  Nuclei_Texture_SumVariance_DNA_5_0  \
# 0                             0.41635                             0.28933
# 1                             0.37764                             0.32148
# 2                             0.39575                             0.31969
#
#    Nuclei_Texture_Variance_DNA_20_0  Nuclei_Texture_Variance_DNA_5_0
# 0                           0.34017                          0.31368
# 1                           0.36964                          0.34328
# 2                           0.36626                          0.34086
#
# [3 rows x 588 columns]

# %%
# VAE of one layer
encoder_architecture = [250]
decoder_architecture = [250]

# %%
# model from optimal hyperparameters for onelayer obtained from 1.optimize
cp_vae = VAE(
    input_dim=train_features_df.shape[1],
    latent_dim=10,
    batch_size=96,
    encoder_batch_norm=True,
    epochs=30,
    learning_rate=0.001,
    encoder_architecture=encoder_architecture,
    decoder_architecture=decoder_architecture,
    beta=0,
    lam=1000,
    verbose=True,
)
#100000
#10000
#200 ep 1000000 results in 1.20
cp_vae.compile_vae()
# Out:
# 2021-12-23 17:52:31.966618: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-12-23 17:52:31.966657: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-23 17:52:31.966684: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ip-10-0-3-81): /proc/driver/nvidia/version does not exist
# 2021-12-23 17:52:31.966949: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/ubuntu/miniconda3/envs/cell-painting-vae/lib/python3.7/site-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
cp_vae.train(x_train=train_features_df, x_test=valid_features_df)
# Out:
# 2021-12-23 17:52:33.564080: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/30
# 82/82 [==============================] - 3s 13ms/step - loss: 42.1577 - recon: 31.0670 - kl: 0.0000e+00 - mmd: 11.6154 - val_loss: 150.5683 - val_recon: 27.7257 - val_kl: 0.0000e+00 - val_mmd: 117.4196
# Epoch 2/30
# 82/82 [==============================] - 1s 7ms/step - loss: 15.1009 - recon: 8.1311 - kl: 0.0000e+00 - mmd: 7.0693 - val_loss: 18.7110 - val_recon: 7.4452 - val_kl: 0.0000e+00 - val_mmd: 15.6674
# Epoch 3/30
# 82/82 [==============================] - 1s 7ms/step - loss: 11.5901 - recon: 6.5701 - kl: 0.0000e+00 - mmd: 4.9567 - val_loss: 24.0715 - val_recon: 6.8374 - val_kl: 0.0000e+00 - val_mmd: 17.6602
# Epoch 4/30
# 82/82 [==============================] - 1s 7ms/step - loss: 9.8230 - recon: 5.5419 - kl: 0.0000e+00 - mmd: 4.2669 - val_loss: 19.3298 - val_recon: 5.1934 - val_kl: 0.0000e+00 - val_mmd: 14.0371
# Epoch 5/30
# 82/82 [==============================] - 1s 7ms/step - loss: 8.9901 - recon: 4.8340 - kl: 0.0000e+00 - mmd: 4.0716 - val_loss: 16.8947 - val_recon: 4.7041 - val_kl: 0.0000e+00 - val_mmd: 14.3767
# Epoch 6/30
# 82/82 [==============================] - 1s 7ms/step - loss: 8.4420 - recon: 4.4845 - kl: 0.0000e+00 - mmd: 3.9977 - val_loss: 11.7359 - val_recon: 4.2494 - val_kl: 0.0000e+00 - val_mmd: 8.0968
# Epoch 7/30
# 82/82 [==============================] - 1s 7ms/step - loss: 8.4380 - recon: 4.2915 - kl: 0.0000e+00 - mmd: 3.9420 - val_loss: 12.7442 - val_recon: 4.0527 - val_kl: 0.0000e+00 - val_mmd: 8.3768
# Epoch 8/30
# 82/82 [==============================] - 1s 7ms/step - loss: 7.9234 - recon: 4.0888 - kl: 0.0000e+00 - mmd: 3.9059 - val_loss: 11.8628 - val_recon: 3.8261 - val_kl: 0.0000e+00 - val_mmd: 9.4181
# Epoch 9/30
# 82/82 [==============================] - 1s 7ms/step - loss: 7.6102 - recon: 3.9604 - kl: 0.0000e+00 - mmd: 3.6445 - val_loss: 15.5793 - val_recon: 3.6363 - val_kl: 0.0000e+00 - val_mmd: 15.2663
# Epoch 10/30
# 82/82 [==============================] - 1s 7ms/step - loss: 7.7675 - recon: 3.9163 - kl: 0.0000e+00 - mmd: 4.0470 - val_loss: 10.1408 - val_recon: 3.9185 - val_kl: 0.0000e+00 - val_mmd: 8.5588
# Epoch 11/30
# 82/82 [==============================] - 1s 7ms/step - loss: 7.7676 - recon: 3.8587 - kl: 0.0000e+00 - mmd: 3.7660 - val_loss: 9.1313 - val_recon: 3.7554 - val_kl: 0.0000e+00 - val_mmd: 6.5147
# Epoch 12/30
# 82/82 [==============================] - 1s 7ms/step - loss: 7.7026 - recon: 3.7820 - kl: 0.0000e+00 - mmd: 4.1070 - val_loss: 11.2067 - val_recon: 3.4722 - val_kl: 0.0000e+00 - val_mmd: 6.9886
# Epoch 13/30
# 82/82 [==============================] - 1s 7ms/step - loss: 7.4513 - recon: 3.7936 - kl: 0.0000e+00 - mmd: 3.8569 - val_loss: 9.7134 - val_recon: 3.7294 - val_kl: 0.0000e+00 - val_mmd: 6.3243
# Epoch 14/30
# 82/82 [==============================] - 1s 7ms/step - loss: 7.6206 - recon: 3.7551 - kl: 0.0000e+00 - mmd: 3.8017 - val_loss: 8.0905 - val_recon: 3.6949 - val_kl: 0.0000e+00 - val_mmd: 5.7514
# Epoch 15/30
# 82/82 [==============================] - 1s 7ms/step - loss: 7.4274 - recon: 3.7240 - kl: 0.0000e+00 - mmd: 3.7526 - val_loss: 9.2465 - val_recon: 3.6312 - val_kl: 0.0000e+00 - val_mmd: 7.8480
# Epoch 16/30
# 82/82 [==============================] - 1s 7ms/step - loss: 7.7323 - recon: 3.6386 - kl: 0.0000e+00 - mmd: 3.6784 - val_loss: 8.8140 - val_recon: 3.5969 - val_kl: 0.0000e+00 - val_mmd: 5.8271
# Epoch 17/30
# 82/82 [==============================] - 1s 7ms/step - loss: 7.3854 - recon: 3.5803 - kl: 0.0000e+00 - mmd: 4.0118 - val_loss: 7.9504 - val_recon: 3.4219 - val_kl: 0.0000e+00 - val_mmd: 6.2305
# Epoch 18/30
# 82/82 [==============================] - 1s 7ms/step - loss: 7.4105 - recon: 3.5910 - kl: 0.0000e+00 - mmd: 3.5860 - val_loss: 7.5301 - val_recon: 3.3939 - val_kl: 0.0000e+00 - val_mmd: 5.0508
# Epoch 19/30
# 82/82 [==============================] - 1s 7ms/step - loss: 7.4407 - recon: 3.4792 - kl: 0.0000e+00 - mmd: 3.8188 - val_loss: 8.2917 - val_recon: 3.4964 - val_kl: 0.0000e+00 - val_mmd: 6.2298
# Epoch 20/30
# 82/82 [==============================] - 1s 7ms/step - loss: 7.0367 - recon: 3.4649 - kl: 0.0000e+00 - mmd: 3.6410 - val_loss: 8.8806 - val_recon: 3.2734 - val_kl: 0.0000e+00 - val_mmd: 8.3266
# Epoch 21/30
# 82/82 [==============================] - 1s 7ms/step - loss: 7.0541 - recon: 3.4402 - kl: 0.0000e+00 - mmd: 3.6739 - val_loss: 11.8524 - val_recon: 3.1733 - val_kl: 0.0000e+00 - val_mmd: 9.0959
# Epoch 22/30
# 82/82 [==============================] - 1s 7ms/step - loss: 7.2637 - recon: 3.4348 - kl: 0.0000e+00 - mmd: 3.4728 - val_loss: 10.0217 - val_recon: 3.0905 - val_kl: 0.0000e+00 - val_mmd: 9.8571
# Epoch 23/30
# 82/82 [==============================] - 1s 7ms/step - loss: 6.9552 - recon: 3.2997 - kl: 0.0000e+00 - mmd: 3.8203 - val_loss: 8.1823 - val_recon: 3.1744 - val_kl: 0.0000e+00 - val_mmd: 5.6963
# Epoch 24/30
# 82/82 [==============================] - 1s 7ms/step - loss: 7.1615 - recon: 3.4039 - kl: 0.0000e+00 - mmd: 3.4201 - val_loss: 9.1160 - val_recon: 3.2870 - val_kl: 0.0000e+00 - val_mmd: 6.3021
# Epoch 25/30
# 82/82 [==============================] - 1s 7ms/step - loss: 7.2650 - recon: 3.3945 - kl: 0.0000e+00 - mmd: 3.5835 - val_loss: 10.7389 - val_recon: 3.2398 - val_kl: 0.0000e+00 - val_mmd: 7.7500
# Epoch 26/30
# 82/82 [==============================] - 1s 7ms/step - loss: 7.0602 - recon: 3.3845 - kl: 0.0000e+00 - mmd: 3.7108 - val_loss: 8.9542 - val_recon: 3.1540 - val_kl: 0.0000e+00 - val_mmd: 5.5734
# Epoch 27/30
# 82/82 [==============================] - 1s 7ms/step - loss: 6.6870 - recon: 3.3182 - kl: 0.0000e+00 - mmd: 3.4763 - val_loss: 8.9189 - val_recon: 3.0577 - val_kl: 0.0000e+00 - val_mmd: 4.5220
# Epoch 28/30
# 82/82 [==============================] - 1s 7ms/step - loss: 7.0278 - recon: 3.2625 - kl: 0.0000e+00 - mmd: 3.6671 - val_loss: 8.7309 - val_recon: 2.9454 - val_kl: 0.0000e+00 - val_mmd: 6.6591
# Epoch 29/30
# 82/82 [==============================] - 1s 7ms/step - loss: 7.0392 - recon: 3.2294 - kl: 0.0000e+00 - mmd: 3.7634 - val_loss: 8.7108 - val_recon: 3.2748 - val_kl: 0.0000e+00 - val_mmd: 6.4230
# Epoch 30/30
# 82/82 [==============================] - 1s 7ms/step - loss: 6.8946 - recon: 3.1937 - kl: 0.0000e+00 - mmd: 3.7957 - val_loss: 10.9585 - val_recon: 3.0990 - val_kl: 0.0000e+00 - val_mmd: 7.5233

# %%
cp_vae.vae

# %%
# cp_vae.vae.evaluate(test_features_df)

# %%
# Save training performance
history_df = pd.DataFrame(cp_vae.vae.history.history)
history_df
# Out:
#          loss      recon   kl        mmd    val_loss  val_recon  val_kl  \
# 0   42.157688  31.067011  0.0  11.615371  150.568298  27.725742     0.0
# 1   15.100865   8.131070  0.0   7.069325   18.710966   7.445159     0.0
# 2   11.590097   6.570098  0.0   4.956656   24.071499   6.837424     0.0
# 3    9.823024   5.541920  0.0   4.266914   19.329805   5.193391     0.0
# 4    8.990052   4.834012  0.0   4.071645   16.894728   4.704095     0.0
# 5    8.441973   4.484458  0.0   3.997724   11.735898   4.249404     0.0
# 6    8.437955   4.291478  0.0   3.942009   12.744198   4.052685     0.0
# 7    7.923426   4.088797  0.0   3.905856   11.862762   3.826128     0.0
# 8    7.610209   3.960353  0.0   3.644522   15.579300   3.636277     0.0
# 9    7.767460   3.916276  0.0   4.046960   10.140756   3.918464     0.0
# 10   7.767625   3.858682  0.0   3.766001    9.131293   3.755388     0.0
# 11   7.702563   3.782016  0.0   4.106972   11.206676   3.472167     0.0
# 12   7.451346   3.793567  0.0   3.856887    9.713389   3.729425     0.0
# 13   7.620633   3.755057  0.0   3.801711    8.090468   3.694934     0.0
# 14   7.427366   3.723995  0.0   3.752604    9.246530   3.631236     0.0
# 15   7.732344   3.638618  0.0   3.678360    8.814045   3.596855     0.0
# 16   7.385402   3.580333  0.0   4.011768    7.950414   3.421909     0.0
# 17   7.410483   3.590981  0.0   3.586013    7.530058   3.393863     0.0
# 18   7.440748   3.479175  0.0   3.818844    8.291714   3.496405     0.0
# 19   7.036718   3.464927  0.0   3.641015    8.880558   3.273361     0.0
# 20   7.054066   3.440194  0.0   3.673913   11.852447   3.173262     0.0
# 21   7.263699   3.434822  0.0   3.472782   10.021718   3.090528     0.0
# 22   6.955221   3.299746  0.0   3.820333    8.182280   3.174374     0.0
# 23   7.161521   3.403868  0.0   3.420074    9.116026   3.287025     0.0
# 24   7.264954   3.394506  0.0   3.583462   10.738871   3.239823     0.0
# 25   7.060160   3.384456  0.0   3.710768    8.954235   3.154024     0.0
# 26   6.687003   3.318217  0.0   3.476313    8.918918   3.057655     0.0
# 27   7.027805   3.262543  0.0   3.667136    8.730863   2.945438     0.0
# 28   7.039248   3.229352  0.0   3.763415    8.710769   3.274848     0.0
# 29   6.894636   3.193713  0.0   3.795693   10.958473   3.099024     0.0
#
#        val_mmd
# 0   117.419632
# 1    15.667352
# 2    17.660240
# 3    14.037143
# 4    14.376739
# 5     8.096836
# 6     8.376815
# 7     9.418064
# 8    15.266333
# 9     8.558750
# 10    6.514668
# 11    6.988579
# 12    6.324280
# 13    5.751371
# 14    7.847981
# 15    5.827091
# 16    6.230506
# 17    5.050778
# 18    6.229845
# 19    8.326629
# 20    9.095885
# 21    9.857070
# 22    5.696329
# 23    6.302096
# 24    7.749969
# 25    5.573359
# 26    4.522009
# 27    6.659063
# 28    6.422974
# 29    7.523331

# %%
history_df.to_csv('training_data/level5_training_mmd_leaveIntermediateOut.csv')

# %%
plt.figure(figsize=(10, 5))
plt.plot(history_df["loss"], label="Training data")
plt.plot(history_df["val_loss"], label="Validation data")
plt.title("Loss for VAE training on Cell Painting Level 5 data")
plt.ylabel("MSE + MMD")
plt.xlabel("No. Epoch")
plt.legend()
plt.show()

# %%
reconstruction = pd.DataFrame(cp_vae.vae.predict(test_features_df), columns=cp_features)
(sum(sum((np.array(test_features_df) - np.array(reconstruction)) ** 2))) ** 0.5
# Out:
# 55.781942933308414

# %%
#latent space heatmap
fig, ax = plt.subplots(figsize=(10, 10))
encoder = cp_vae.encoder_block["encoder"]
latent = np.array(encoder.predict(test_features_df)[2])
seaborn.heatmap(latent, ax=ax)
# Out:
# <AxesSubplot:>

# %%
pd.DataFrame(encoder.predict(test_features_df)[2]).mean()
# Out:
# 0    0.143763
# 1    0.057872
# 2    0.105994
# 3   -0.129827
# 4    0.092714
# 5    0.032963
# 6    0.142026
# 7   -0.034820
# 8    0.248286
# 9    0.032163
# dtype: float32

# %%
#original vs reconstructed heatmap
reconstruction = pd.DataFrame(cp_vae.vae.predict(test_features_df), columns=cp_features)
pca = PCA(n_components=2).fit(test_features_df)
pca_reconstructed_latent_df = pd.DataFrame(pca.transform(reconstruction))
pca_test_latent_df = pd.DataFrame(pca.transform(test_features_df))
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))
# seaborn.heatmap(test_features_df, ax=ax1)
# seaborn.heatmap(reconstruction, ax=ax2)
# plt.show()

# %%
figure(figsize=(10, 10), dpi=80)
plt.scatter(pca_test_latent_df[0],pca_test_latent_df[1], marker = ".", alpha = 0.5)
plt.scatter(pca_reconstructed_latent_df[0],pca_reconstructed_latent_df[1], marker = ".", alpha = 0.5)

# %%
pca = PCA(n_components=50).fit(test_features_df)
pca_reconstructed_latent_df = pd.DataFrame(pca.transform(reconstruction))
pca_test_latent_df = pd.DataFrame(pca.transform(test_features_df))

# %%
figure(figsize=(10, 10), dpi=80)
plt.scatter(pca_test_latent_df[2],pca_test_latent_df[3], marker = ".", alpha = 0.5)
plt.scatter(pca_reconstructed_latent_df[2],pca_reconstructed_latent_df[3], marker = ".", alpha = 0.5)

# %%
#difference between original and reconstructed heatmap
difference = abs(reconstruction - test_features_df)
fig, ax = plt.subplots(figsize=(10, 10))
seaborn.heatmap(difference, ax=ax, cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
#encoder heatmap
weights = cp_vae.encoder_block["encoder"].get_weights()
fig, ax = plt.subplots(figsize=(10, 10))
seaborn.heatmap(weights[0], ax=ax)
# Out:
# <AxesSubplot:>

# %%
decoder = cp_vae.decoder_block["decoder"]

# %%
pca_training = PCA(n_components=2).fit(train_features_df)

simulated_df = pd.DataFrame(np.random.normal(size=(8294, 10)), columns=np.arange(0,10))
reconstruction_of_simulated = decoder.predict(simulated_df)
pca_reconstruction_of_simulated = pd.DataFrame(pca_training.transform(reconstruction_of_simulated))
pca_train_latent_df = pd.DataFrame(pca_training.transform(train_features_df))

fig, (ax1,ax2) = plt.subplots(1, 2, figsize=(16,8), sharey = True, sharex = True)
ax1.scatter(pca_train_latent_df[0],pca_train_latent_df[1], marker = ".", alpha = 0.5)
ax2.scatter(pca_reconstruction_of_simulated[0],pca_reconstruction_of_simulated[1], marker = ".", alpha = 0.5)

# %%
from scipy.spatial.distance import directed_hausdorff
max(directed_hausdorff(train_features_df, reconstruction_of_simulated)[0],directed_hausdorff(reconstruction_of_simulated,train_features_df)[0])
# Out:
# 6.073154946145626

# %%
#NOTE: IF YOU RUN THIS, YOU WILL NOT BE ABLE TO REPRODUCE THE EXACT RESULTS IN THE EXPERIMENT
latent_complete = np.array(encoder.predict(complete_features_df)[2])
latent_df = pd.DataFrame(latent_complete)
latent_df.to_csv("../3.application/level5Latent_mmd_leaveIntermediateOut.csv")

# %%
# reducer = umap.UMAP()
# latent_embedding = reducer.fit_transform(latent_df)

# %%
figure(figsize=(10, 10), dpi=80)
plt.scatter(
    latent_embedding[:, 0],
    latent_embedding[:, 1],
    marker = '.'
)

# %%
#NOTE: IF YOU RUN THIS, YOU WILL NOT BE ABLE TO REPRODUCE THE EXACT RESULTS IN THE EXPERIMENT
decoder.save("models/level5Decoder_mmd_leaveIntermediateOut")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2021-12-23 17:53:15.467643: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: models/level5Decoder_mmd_leaveIntermediateOut/assets

# %%
encoder.save("models/level5Encoder_mmd_leaveIntermediateOut")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: models/level5Encoder_mmd_leaveIntermediateOut/assets
